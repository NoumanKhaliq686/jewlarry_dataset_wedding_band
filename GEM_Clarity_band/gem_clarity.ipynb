# %%
import os
import requests
from google.cloud import vision
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError
from PIL import Image
from io import BytesIO

# Ensure the image storage directory exists
IMAGE_DIR = "GEM_CLARITY"
os.makedirs(IMAGE_DIR, exist_ok=True)

# List of shink design for which we will fetch images
gem_clarity=[

   "FL",
"IF",
"VVS1 - VVs2",
"VVS1",
"VVS2",
"VS",
"VS1",
"VS2",
"SI",
"SI1",
"SI2",
"SI3",
"I1",
"I2",
"I3"
    
 ]


def search_image(query, api_key, cse_id):
    """Search for images using Google Custom Search JSON API."""
    try:
        # Format query to avoid invalid characters
        formatted_query = query.replace(" ", "+").replace("-", "_").replace(".", "")  # Remove dots
        
        service = build("customsearch", "v1", developerKey=api_key)
        res = service.cse().list(
            q=formatted_query + "wedding+band+diamond",
            cx=cse_id,
            searchType="image",
            num=10 # Reduced to 10 as per Google API limits
        ).execute()

        if "items" in res:
            return [item["link"] for item in res["items"]]
        else:
            print(f"No images found for query: {query}")
    except HttpError as e:
        print(f"Google Search API Error: {e}")
    return []

def analyze_image(image_url):
    """Analyze image using Google Cloud Vision API."""
    try:
        client = vision.ImageAnnotatorClient()
        image = vision.Image()
        image.source.image_uri = image_url
        response = client.label_detection(image=image)
        labels = [label.description.lower() for label in response.label_annotations]
        return labels
    except Exception as e:
        print(f"Vision API Error: {e}")
        return []

def download_image(image_url, save_path):
    """Download and save an image if it's valid."""
    try:
        response = requests.get(image_url, timeout=10)
        if response.status_code == 200:
            img = Image.open(BytesIO(response.content))
            img.verify()  # Ensure it's a valid image
            img = Image.open(BytesIO(response.content))  # Reopen after verification
            img = img.convert("RGB")  # Convert to standard format
            img.save(save_path, format="JPEG")  # Save as JPEG
            return save_path
        else:
            print(f"Failed to download image: {image_url} (Status Code: {response.status_code})")
    except Exception as e:
        print(f"Error downloading or verifying image: {e} - URL: {image_url}")
    return None

def create_folder_structure():
    """Create subfolders for each gem color."""
    for cat in gem_clarity:
        folder_path = os.path.join(IMAGE_DIR, cat)
        os.makedirs(folder_path, exist_ok=True)

def fetch_and_save_images(api_key, cse_id):
    """Fetch and save images for each gem color, using Google Custom Search and Vision API."""
    for cat in gem_clarity:
        print(f"Fetching images for {cat}...")

        # Create subfolder for the current gem color
        color_folder = os.path.join(IMAGE_DIR, cat)
        
        # Search for images related to the gem color
        image_urls = search_image(cat, api_key, cse_id)

        if image_urls:
            downloaded_images = 0  # Track successfully downloaded images

            for image_url in image_urls:
                if downloaded_images >= 20:  # Stop if we have downloaded 20 images
                    break
                
                # Generate unique file name for each image
                image_filename = f"{cat.replace(' ', '_')}_{downloaded_images + 1}.jpg"
                image_path = os.path.join(color_folder, image_filename)

                # Attempt to download and save the image
                saved_image = download_image(image_url, image_path)

                if saved_image:
                    print(f"Image saved: {saved_image}")

                    # Analyze image with Vision API and get labels
                    labels = analyze_image(image_url)
                    print(f"Labels for {image_filename}: {', '.join(labels)}")
                    
                    downloaded_images += 1
        else:
            print(f"No images found for {cat}")

# Google API credentials (Replace these with your actual credentials)
API_KEY = "AIzaSyAo5M5HXAXSkVxBzHRG0bUMRJf3RltEhJw"  # Replace with your actual API key
CSE_ID = "d63ff1141028241de"  # Replace with your actual CSE ID

# Set Google Cloud credentials
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = r"C:/Users/TechAir\Desktop/GEM_CLARITY/jewelry-449211-b1561756ae8d.json"  

# Create the folder structure for Gem Color categories
create_folder_structure()

# Fetch and save images for each gem color
fetch_and_save_images(API_KEY, CSE_ID)
# Out:
# Fetching images for FL...
# Error downloading or verifying image: cannot identify image file <_io.BytesIO object at 0x0000029720111DB0> - URL: https://lookaside.instagram.com/seo/google_widget/crawler/?media_id=3337348134885943948
# Image saved: GEM_CLARITY\FL\FL_1.jpg
# Labels for FL_1.jpg: engagement ring, jewellery, body jewelry, ring, wedding ring, wedding ceremony supply, pre-engagement ring, diamond, gemstone, natural material
# Image saved: GEM_CLARITY\FL\FL_2.jpg
# Labels for FL_2.jpg: engagement ring, ring, jewellery, body jewelry, wedding ring, gemstone, diamond, pre-engagement ring, silver, metal
# Image saved: GEM_CLARITY\FL\FL_3.jpg
# Labels for FL_3.jpg: body jewelry, jewellery, gemstone, diamond, ring, pre-engagement ring, natural material, jewelry making, wedding ceremony supply, bangle
# Image saved: GEM_CLARITY\FL\FL_4.jpg
# Labels for FL_4.jpg: engagement ring, ring, jewellery, wedding ring, body jewelry, wedding ceremony supply, pre-engagement ring, gemstone, diamond, natural material
# Image saved: GEM_CLARITY\FL\FL_5.jpg
# Labels for FL_5.jpg: engagement ring, ring, wedding ring, natural material, wedding ceremony supply, body jewelry, pre-engagement ring, diamond, gemstone, macro photography
# Image saved: GEM_CLARITY\FL\FL_6.jpg
# Labels for FL_6.jpg: engagement ring, ring, event, wedding ring, jewellery, wedding ceremony supply, pre-engagement ring, gemstone, diamond, ceremony
# Image saved: GEM_CLARITY\FL\FL_7.jpg
# Labels for FL_7.jpg: engagement ring, ring, wedding ring, jewellery, wedding ceremony supply, diamond, gemstone, pre-engagement ring, body jewelry, natural material
# Image saved: GEM_CLARITY\FL\FL_8.jpg
# Labels for FL_8.jpg: ring, engagement ring, wedding ring, jewellery, body jewelry, gemstone, wedding ceremony supply, pre-engagement ring, diamond, natural material
# Image saved: GEM_CLARITY\FL\FL_9.jpg
# Labels for FL_9.jpg: ring, engagement ring, jewellery, body jewelry, diamond, silver, gemstone, wedding ceremony supply, pre-engagement ring, wedding ring
# Fetching images for IF...
# Image saved: GEM_CLARITY\IF\IF_1.jpg
# Labels for IF_1.jpg: jewellery, ring, engagement ring, body jewelry, wedding ceremony supply, wedding ring, gemstone, pre-engagement ring, natural material, metal
# Image saved: GEM_CLARITY\IF\IF_2.jpg
# Labels for IF_2.jpg:
# Image saved: GEM_CLARITY\IF\IF_3.jpg
# Labels for IF_3.jpg: costume, fictional character, cosplay, hime cut, anime, costume design, animation, fiction
# Image saved: GEM_CLARITY\IF\IF_4.jpg
# Labels for IF_4.jpg: fictional character, cg artwork, cartoon, fiction, animation, anime, long hair, animated cartoon, hime cut
# Failed to download image: https://www.cleanorigin.com/blog/wp-content/uploads/2019/07/gabriela-emerald-eternity-bands-solitaire-white-gold-1200x900-1.jpg (Status Code: 403)
# Image saved: GEM_CLARITY\IF\IF_5.jpg
# Labels for IF_5.jpg: engagement ring, body jewelry, gemstone, natural material, ring, nail, pre-engagement ring, triangle, wedding ring, wedding ceremony supply
# Image saved: GEM_CLARITY\IF\IF_6.jpg
# Labels for IF_6.jpg: engagement ring, ring, wedding ring, pre-engagement ring, body jewelry, diamond, natural material, gemstone, silver, nail
# Failed to download image: https://cdn0.weddingwire.com/article/7712/3_2/960/jpg/22177-asia-pimentel-photography-history-of-wedding-rings.jpeg (Status Code: 403)
# Image saved: GEM_CLARITY\IF\IF_7.jpg
# Labels for IF_7.jpg: hairstyle, cartoon, animation, fashion illustration, fictional character, costume design, anime, cg artwork, bangs, hime cut
# Image saved: GEM_CLARITY\IF\IF_8.jpg
# Labels for IF_8.jpg: fiction, anime, animation, animated cartoon, publication, cg artwork, fictional character
# Fetching images for VVS1 - VVs2...
# Image saved: GEM_CLARITY\VVS1 - VVs2\VVS1_-_VVs2_1.jpg
# Labels for VVS1_-_VVs2_1.jpg: gemstone, diamond, body jewelry, ring, jewellery, natural material, crystal, engagement ring, pre-engagement ring, silver
# Image saved: GEM_CLARITY\VVS1 - VVs2\VVS1_-_VVs2_2.jpg
# Labels for VVS1_-_VVs2_2.jpg: watch, white, analog watch, diamond, gemstone, crystal, natural material, silver, mineral, metal
# Image saved: GEM_CLARITY\VVS1 - VVs2\VVS1_-_VVs2_3.jpg
# Labels for VVS1_-_VVs2_3.jpg: watch, gemstone, jewellery, natural material, diamond, silver, ring, crystal, body jewelry, engagement ring
# Image saved: GEM_CLARITY\VVS1 - VVs2\VVS1_-_VVs2_4.jpg
# Labels for VVS1_-_VVs2_4.jpg: watch, white, diamond, silver, crystal, natural material, metal, analog watch, mineral, platinum
# Image saved: GEM_CLARITY\VVS1 - VVs2\VVS1_-_VVs2_5.jpg
# Labels for VVS1_-_VVs2_5.jpg: white, engagement ring, gemstone, fashion, crystal, ring, jewellery, diamond, body jewelry, wedding ring
# Image saved: GEM_CLARITY\VVS1 - VVs2\VVS1_-_VVs2_6.jpg
# Labels for VVS1_-_VVs2_6.jpg: watch, white, diamond, gemstone, crystal, natural material, metal, silver, analog watch, mineral
# Image saved: GEM_CLARITY\VVS1 - VVs2\VVS1_-_VVs2_7.jpg
# Labels for VVS1_-_VVs2_7.jpg: engagement ring, gemstone, jewellery, ring, diamond, crystal, body jewelry, wedding ring, pre-engagement ring, natural material
# Error downloading or verifying image: HTTPSConnectionPool(host='images-na.ssl-images-amazon.com', port=443): Read timed out. (read timeout=10) - URL: https://images-na.ssl-images-amazon.com/images/I/61Ekb1u6w-L._SLDPMOBCAROUSELAUTOCROP288221_MCnd_AC_SR308,462_.jpg
# Image saved: GEM_CLARITY\VVS1 - VVs2\VVS1_-_VVs2_8.jpg
# Labels for VVS1_-_VVs2_8.jpg: jewellery, ring, gemstone, fashion, engagement ring, body jewelry, diamond, crystal, natural material, wedding ring
# Image saved: GEM_CLARITY\VVS1 - VVs2\VVS1_-_VVs2_9.jpg
# Labels for VVS1_-_VVs2_9.jpg: engagement ring, gemstone, crystal, ring, diamond, wedding ring, body jewelry, pre-engagement ring, silver, natural material
# Fetching images for VVS1...
# Image saved: GEM_CLARITY\VVS1\VVS1_1.jpg
# Labels for VVS1_1.jpg: engagement ring, ring, white, jewellery, gemstone, wedding ring, wedding ceremony supply, body jewelry, diamond, pink
# Image saved: GEM_CLARITY\VVS1\VVS1_2.jpg
# Labels for VVS1_2.jpg: gemstone, diamond, engagement ring, natural material, crystal, silver, pre-engagement ring, mineral, ring, wedding ring
# Image saved: GEM_CLARITY\VVS1\VVS1_3.jpg
# Labels for VVS1_3.jpg: gemstone, diamond, body jewelry, wedding ceremony supply, crystal, natural material, pre-engagement ring, silver, engagement ring, ring
# Image saved: GEM_CLARITY\VVS1\VVS1_4.jpg
# Labels for VVS1_4.jpg: diamond, gemstone, engagement ring
# Image saved: GEM_CLARITY\VVS1\VVS1_5.jpg
# Labels for VVS1_5.jpg: blue, gemstone, natural material, sapphire, diamond
# Image saved: GEM_CLARITY\VVS1\VVS1_6.jpg
# Labels for VVS1_6.jpg: engagement ring, diamond, natural material, pre-engagement ring, silver, gemstone, body jewelry, wedding ring, ring, wedding ceremony supply
# Image saved: GEM_CLARITY\VVS1\VVS1_7.jpg
# Labels for VVS1_7.jpg: engagement ring, white, ring, jewellery, wedding ceremony supply, gemstone, fashion, wedding ring, body jewelry, diamond
# Image saved: GEM_CLARITY\VVS1\VVS1_8.jpg
# Labels for VVS1_8.jpg: white, engagement ring, gemstone, crystal, diamond, pink, natural material, pre-engagement ring, platinum, body jewelry
# Image saved: GEM_CLARITY\VVS1\VVS1_9.jpg
# Labels for VVS1_9.jpg: pre-engagement ring, wedding ring, natural material, gemstone, engagement ring, body jewelry, diamond, ring, wedding ceremony supply, macro photography
# Image saved: GEM_CLARITY\VVS1\VVS1_10.jpg
# Labels for VVS1_10.jpg: white, engagement ring, gemstone, diamond, crystal, natural material, pre-engagement ring, silver, body jewelry, wedding ring
# Fetching images for VVS2...
# Image saved: GEM_CLARITY\VVS2\VVS2_1.jpg
# Labels for VVS2_1.jpg: watch, white, analog watch, diamond, gemstone, crystal, natural material, silver, mineral, metal
# Image saved: GEM_CLARITY\VVS2\VVS2_2.jpg
# Labels for VVS2_2.jpg: gemstone, engagement ring, body jewelry, diamond, jewellery, crystal, silver, pre-engagement ring, ring, natural material
# Image saved: GEM_CLARITY\VVS2\VVS2_3.jpg
# Labels for VVS2_3.jpg: gemstone, diamond, body jewelry, ring, jewellery, natural material, crystal, engagement ring, pre-engagement ring, silver
# Image saved: GEM_CLARITY\VVS2\VVS2_4.jpg
# Labels for VVS2_4.jpg: gemstone, engagement ring, body jewelry, diamond, jewellery, crystal, silver, ring, pre-engagement ring, metal
# Image saved: GEM_CLARITY\VVS2\VVS2_5.jpg
# Labels for VVS2_5.jpg: watch, gemstone, jewellery, natural material, diamond, silver, ring, crystal, body jewelry, engagement ring
# Image saved: GEM_CLARITY\VVS2\VVS2_6.jpg
# Labels for VVS2_6.jpg: silver, diamond, silver
# Image saved: GEM_CLARITY\VVS2\VVS2_7.jpg
# Labels for VVS2_7.jpg: white, engagement ring, gemstone, fashion, crystal, ring, jewellery, diamond, body jewelry, wedding ring
# Image saved: GEM_CLARITY\VVS2\VVS2_8.jpg
# Labels for VVS2_8.jpg: engagement ring, jewellery, gemstone, body jewelry, diamond, ring, pre-engagement ring, natural material, silver, wedding ring
# Image saved: GEM_CLARITY\VVS2\VVS2_9.jpg
# Labels for VVS2_9.jpg: jewellery, ring, gemstone, fashion, engagement ring, body jewelry, diamond, crystal, natural material, wedding ring
# Image saved: GEM_CLARITY\VVS2\VVS2_10.jpg
# Labels for VVS2_10.jpg: ring, engagement ring, gemstone, body jewelry, jewellery, crystal, diamond, pre-engagement ring, wedding ring, wedding ceremony supply
# Fetching images for VS...
# Image saved: GEM_CLARITY\VS\VS_1.jpg
# Labels for VS_1.jpg: engagement ring, ring, gemstone, diamond, natural material, wedding ceremony supply, wedding ring, body jewelry, pre-engagement ring, silver
# Image saved: GEM_CLARITY\VS\VS_2.jpg
# Labels for VS_2.jpg: fashion, engagement ring, gemstone, diamond, body jewelry, ring, natural material, pre-engagement ring, silver, wedding ring
# Image saved: GEM_CLARITY\VS\VS_3.jpg
# Labels for VS_3.jpg: ring, engagement ring, wedding ring, jewellery, diamond, wedding ceremony supply, body jewelry, natural material, pre-engagement ring, gemstone
# Image saved: GEM_CLARITY\VS\VS_4.jpg
# Labels for VS_4.jpg: ring, engagement ring, jewellery, fashion, gemstone, wedding ring, body jewelry, wedding ceremony supply, diamond, pre-engagement ring
# Image saved: GEM_CLARITY\VS\VS_5.jpg
# Labels for VS_5.jpg: engagement ring, white, ring, gemstone, wedding ring, body jewelry, diamond, jewellery, wedding ceremony supply, pre-engagement ring
# Image saved: GEM_CLARITY\VS\VS_6.jpg
# Labels for VS_6.jpg: jewellery, hand, ring, engagement ring, fashion, finger, body jewelry, gemstone, wrist, nail
# Image saved: GEM_CLARITY\VS\VS_7.jpg
# Labels for VS_7.jpg: ring, engagement ring, jewellery, body jewelry, gemstone, wedding ring, diamond, wedding ceremony supply, pre-engagement ring, natural material
# Image saved: GEM_CLARITY\VS\VS_8.jpg
# Labels for VS_8.jpg: engagement ring, ring, jewellery, wedding ring, fashion, gemstone, wedding ceremony supply, body jewelry, pre-engagement ring, diamond
# Image saved: GEM_CLARITY\VS\VS_9.jpg
# Labels for VS_9.jpg: ring, engagement ring, jewellery, wedding ring, body jewelry, wedding ceremony supply, pre-engagement ring, diamond, gemstone, natural material
# Image saved: GEM_CLARITY\VS\VS_10.jpg
# Labels for VS_10.jpg: engagement ring, jewellery, ring, white, gemstone, crystal, fashion, wedding ring, diamond, body jewelry
# Fetching images for VS1...
# Image saved: GEM_CLARITY\VS1\VS1_1.jpg
# Labels for VS1_1.jpg: natural material, ring, diamond, body jewelry, platinum, pre-engagement ring
# Image saved: GEM_CLARITY\VS1\VS1_2.jpg
# Labels for VS1_2.jpg: engagement ring, body jewelry, gemstone, diamond, pre-engagement ring, wedding ring, platinum, silver, natural material, ring
# Image saved: GEM_CLARITY\VS1\VS1_3.jpg
# Labels for VS1_3.jpg: engagement ring, gemstone, pre-engagement ring, ring, natural material, diamond, crystal, wedding ring, mineral, wedding ceremony supply
# Image saved: GEM_CLARITY\VS1\VS1_4.jpg
# Labels for VS1_4.jpg: diamond, engagement ring, pre-engagement ring
# Error downloading or verifying image: HTTPSConnectionPool(host='i.etsystatic.com', port=443): Read timed out. (read timeout=10) - URL: https://i.etsystatic.com/30688662/r/il/76fd71/5832245666/il_570xN.5832245666_myak.jpg
# Image saved: GEM_CLARITY\VS1\VS1_5.jpg
# Labels for VS1_5.jpg: engagement ring, white, jewellery, body jewelry, ring, gemstone, diamond, wedding ring, pre-engagement ring, natural material
# Image saved: GEM_CLARITY\VS1\VS1_6.jpg
# Labels for VS1_6.jpg: gemstone, diamond
# Image saved: GEM_CLARITY\VS1\VS1_7.jpg
# Labels for VS1_7.jpg: gemstone, engagement ring, jewellery, natural material, diamond, body jewelry, ring, mineral, crystal, pre-engagement ring
# Image saved: GEM_CLARITY\VS1\VS1_8.jpg
# Labels for VS1_8.jpg: white, engagement ring, diamond, gemstone, pre-engagement ring, natural material, silver, wedding ring, wedding ceremony supply, body jewelry
# Image saved: GEM_CLARITY\VS1\VS1_9.jpg
# Labels for VS1_9.jpg: jewellery, ring, engagement ring, body jewelry, wedding ring, diamond, gemstone, wedding ceremony supply, pre-engagement ring, natural material
# Fetching images for VS2...
# Image saved: GEM_CLARITY\VS2\VS2_1.jpg
# Labels for VS2_1.jpg: engagement ring, white, fashion, gemstone, wedding ring, ring, diamond, body jewelry, pre-engagement ring, jewellery
# Image saved: GEM_CLARITY\VS2\VS2_2.jpg
# Labels for VS2_2.jpg: engagement ring, ring, jewellery, natural material, diamond, metal, silver, mineral, pre-engagement ring, wedding ring
# Image saved: GEM_CLARITY\VS2\VS2_3.jpg
# Labels for VS2_3.jpg: ring, engagement ring, white, wedding ring, wedding ceremony supply, jewellery, diamond, pre-engagement ring, bangle, natural material
# Error downloading or verifying image: cannot identify image file <_io.BytesIO object at 0x00000297220E8310> - URL: https://lookaside.instagram.com/seo/google_widget/crawler/?media_id=2619167760345523506
# Image saved: GEM_CLARITY\VS2\VS2_4.jpg
# Labels for VS2_4.jpg: engagement ring, body jewelry, jewellery, gemstone, ring, wedding ceremony supply, diamond, wedding ring, natural material, pre-engagement ring
# Image saved: GEM_CLARITY\VS2\VS2_5.jpg
# Labels for VS2_5.jpg: engagement ring, ring, jewellery, gemstone, body jewelry, wedding ring, pre-engagement ring, wedding ceremony supply, diamond, natural material
# Image saved: GEM_CLARITY\VS2\VS2_6.jpg
# Labels for VS2_6.jpg: engagement ring, white, wedding ring, gemstone, diamond, body jewelry, ring, pre-engagement ring, jewellery, silver
# Image saved: GEM_CLARITY\VS2\VS2_7.jpg
# Labels for VS2_7.jpg: ring, body jewelry, pre-engagement ring, silver, natural material, wedding ring, wedding ceremony supply, engagement ring, silver
# Image saved: GEM_CLARITY\VS2\VS2_8.jpg
# Labels for VS2_8.jpg: engagement ring, diamond, body jewelry, jewellery, gemstone, pre-engagement ring, wedding ring, wedding ceremony supply, natural material, crystal
# Image saved: GEM_CLARITY\VS2\VS2_9.jpg
# Labels for VS2_9.jpg: engagement ring, pre-engagement ring, natural material, platinum, diamond, ring, wedding ring
# Fetching images for SI...
# Image saved: GEM_CLARITY\SI\SI_1.jpg
# Labels for SI_1.jpg: white, body jewelry, ring, engagement ring, bangle, jewellery, wedding ring, diamond, pre-engagement ring, natural material
# Error downloading or verifying image: HTTPSConnectionPool(host='i5.walmartimages.com', port=443): Read timed out. (read timeout=10) - URL: https://i5.walmartimages.com/seo/His-Hers-Diamond-SI-Wedding-Ring-Band-14K-Set_a43da5f3-9c36-44b7-8ed2-f710c47a6e7e_1.8cab688fc52b30093c6c529dd50f605e.jpeg?odnHeight=768&odnWidth=768&odnBg=FFFFFF
# Image saved: GEM_CLARITY\SI\SI_2.jpg
# Labels for SI_2.jpg: engagement ring, ring, jewellery, wedding ring, finger, body jewelry, wedding ceremony supply, pre-engagement ring, diamond, gemstone
# Image saved: GEM_CLARITY\SI\SI_3.jpg
# Labels for SI_3.jpg: engagement ring, gemstone, diamond, natural material, pre-engagement ring, silver, body jewelry, wedding ring, crystal, ring
# Image saved: GEM_CLARITY\SI\SI_4.jpg
# Labels for SI_4.jpg: jewellery, engagement ring, ring, wedding ring, body jewelry, wedding ceremony supply, gemstone, pre-engagement ring, diamond, metal
# Image saved: GEM_CLARITY\SI\SI_5.jpg
# Labels for SI_5.jpg: engagement ring, gemstone, ring, diamond, wedding ring, body jewelry, jewellery, wedding ceremony supply, pre-engagement ring, silver
# Image saved: GEM_CLARITY\SI\SI_6.jpg
# Labels for SI_6.jpg: jewellery, engagement ring, body jewelry, pre-engagement ring, silver, metal, natural material, diamond, platinum, wedding ring
# Image saved: GEM_CLARITY\SI\SI_7.jpg
# Labels for SI_7.jpg: ring, engagement ring, gemstone, body jewelry, diamond, wedding ring, pre-engagement ring, wedding ceremony supply, natural material, crystal
# Image saved: GEM_CLARITY\SI\SI_8.jpg
# Labels for SI_8.jpg: engagement ring, jewellery, white, ring, wedding ring, diamond, body jewelry, pre-engagement ring, metal, wedding ceremony supply
# Image saved: GEM_CLARITY\SI\SI_9.jpg
# Labels for SI_9.jpg: wedding ring, silver, natural material, ring, pre-engagement ring, engagement ring, titanium ring, nickel, silver, titanium
# Fetching images for SI1...
# Image saved: GEM_CLARITY\SI1\SI1_1.jpg
# Labels for SI1_1.jpg: jewellery, engagement ring, ring, body jewelry, wedding ceremony supply, wedding ring, gemstone, diamond, pre-engagement ring, metal
# Image saved: GEM_CLARITY\SI1\SI1_2.jpg
# Labels for SI1_2.jpg: engagement ring, ring, jewellery, body jewelry, diamond, gemstone, pre-engagement ring, wedding ceremony supply, wedding ring, natural material
# Image saved: GEM_CLARITY\SI1\SI1_3.jpg
# Labels for SI1_3.jpg: jewellery, ring, engagement ring, body jewelry, wedding ceremony supply, wedding ring, gemstone, diamond, pre-engagement ring, metal
# Image saved: GEM_CLARITY\SI1\SI1_4.jpg
# Labels for SI1_4.jpg: engagement ring, ring, gemstone, diamond, jewellery, body jewelry, pre-engagement ring, crystal, wedding ring, metal
# Image saved: GEM_CLARITY\SI1\SI1_5.jpg
# Labels for SI1_5.jpg: engagement ring, gemstone, crystal, jewellery, ring, body jewelry, diamond, wedding ring, pre-engagement ring, natural material
# Image saved: GEM_CLARITY\SI1\SI1_6.jpg
# Labels for SI1_6.jpg: engagement ring, jewellery, ring, body jewelry, gemstone, wedding ring, wedding ceremony supply, diamond, pre-engagement ring, natural material
# Image saved: GEM_CLARITY\SI1\SI1_7.jpg
# Labels for SI1_7.jpg: engagement ring, gemstone, ring, body jewelry, crystal, wedding ring, diamond, pre-engagement ring, jewellery, natural material
# Image saved: GEM_CLARITY\SI1\SI1_8.jpg
# Labels for SI1_8.jpg: engagement ring, ring, body jewelry, wedding ring, jewellery, gemstone, pre-engagement ring, wedding ceremony supply, diamond, natural material
# Image saved: GEM_CLARITY\SI1\SI1_9.jpg
# Labels for SI1_9.jpg: engagement ring, diamond, gemstone, ring, wedding ring, pre-engagement ring, wedding ceremony supply, silver, natural material, crystal
# Image saved: GEM_CLARITY\SI1\SI1_10.jpg
# Labels for SI1_10.jpg: jewellery, engagement ring, ring, wedding ceremony supply, fashion, gemstone, body jewelry, wedding ring, diamond, pre-engagement ring
# Fetching images for SI2...
# Image saved: GEM_CLARITY\SI2\SI2_1.jpg
# Labels for SI2_1.jpg: ring, engagement ring, wedding ceremony supply, jewellery, body jewelry, diamond, wedding ring, pre-engagement ring, silver, metal
# Image saved: GEM_CLARITY\SI2\SI2_2.jpg
# Labels for SI2_2.jpg: engagement ring, body jewelry, diamond, gemstone, jewellery, ring, wedding ring, pre-engagement ring, natural material, platinum
# Image saved: GEM_CLARITY\SI2\SI2_3.jpg
# Labels for SI2_3.jpg: ring, wedding ceremony supply, jewellery, engagement ring, body jewelry, diamond, pre-engagement ring, silver, wedding ring, metal
# Image saved: GEM_CLARITY\SI2\SI2_4.jpg
# Labels for SI2_4.jpg: engagement ring, ring, wedding ring, pre-engagement ring, wedding ceremony supply, diamond, body jewelry, natural material, metal, silver
# Image saved: GEM_CLARITY\SI2\SI2_5.jpg
# Labels for SI2_5.jpg: ring, engagement ring, jewellery, body jewelry, wedding ring, fashion, wedding ceremony supply, pre-engagement ring, diamond, gemstone
# Image saved: GEM_CLARITY\SI2\SI2_6.jpg
# Labels for SI2_6.jpg: white, engagement ring, body jewelry, gemstone, jewellery, diamond, crystal, natural material, pre-engagement ring, silver
# Image saved: GEM_CLARITY\SI2\SI2_7.jpg
# Labels for SI2_7.jpg: silver, metal, ring, diamond, natural material, engagement ring, wedding ceremony supply, pre-engagement ring, body jewelry, platinum
# Image saved: GEM_CLARITY\SI2\SI2_8.jpg
# Labels for SI2_8.jpg: engagement ring, ring, gemstone, pre-engagement ring, diamond, wedding ring, natural material, body jewelry, metal, wedding ceremony supply
# Image saved: GEM_CLARITY\SI2\SI2_9.jpg
# Labels for SI2_9.jpg: jewellery, ring, body jewelry, engagement ring, gemstone, wedding ceremony supply, diamond, wedding ring, pre-engagement ring, metal
# Image saved: GEM_CLARITY\SI2\SI2_10.jpg
# Labels for SI2_10.jpg: ring, jewellery, wedding ring, wedding ceremony supply, engagement ring, pre-engagement ring, diamond, body jewelry, natural material, metal
# Fetching images for SI3...
# Image saved: GEM_CLARITY\SI3\SI3_1.jpg
# Labels for SI3_1.jpg: natural material, engagement ring, silver, diamond, platinum, pre-engagement ring, ring, body jewelry, silver, gemstone
# Image saved: GEM_CLARITY\SI3\SI3_2.jpg
# Labels for SI3_2.jpg: engagement ring, pre-engagement ring, natural material, diamond, wedding ring, ring, platinum, body jewelry, gemstone, wedding ceremony supply
# Image saved: GEM_CLARITY\SI3\SI3_3.jpg
# Labels for SI3_3.jpg: engagement ring, ring, wedding ring, jewellery, gemstone, diamond, pre-engagement ring, body jewelry, wedding ceremony supply, platinum
# Image saved: GEM_CLARITY\SI3\SI3_4.jpg
# Labels for SI3_4.jpg: engagement ring, natural material, pre-engagement ring, diamond, wedding ring, platinum, ring, body jewelry, mineral, titanium ring
# Image saved: GEM_CLARITY\SI3\SI3_5.jpg
# Labels for SI3_5.jpg: engagement ring, ring, wedding ring, jewellery, pre-engagement ring, diamond, gemstone, body jewelry, wedding ceremony supply, platinum
# Image saved: GEM_CLARITY\SI3\SI3_6.jpg
# Labels for SI3_6.jpg: natural material, silver, engagement ring, diamond, platinum, pre-engagement ring, silver, ring
# Image saved: GEM_CLARITY\SI3\SI3_7.jpg
# Labels for SI3_7.jpg: engagement ring, ring, gemstone, pre-engagement ring, wedding ring, diamond, silver, body jewelry, natural material, platinum
# Image saved: GEM_CLARITY\SI3\SI3_8.jpg
# Labels for SI3_8.jpg: engagement ring, ring, wedding ring, pre-engagement ring, gemstone, diamond, body jewelry, silver, natural material, platinum
# Image saved: GEM_CLARITY\SI3\SI3_9.jpg
# Labels for SI3_9.jpg: engagement ring, gemstone, pre-engagement ring, wedding ring, ring, diamond, natural material, wedding ceremony supply, crystal, body jewelry
# Image saved: GEM_CLARITY\SI3\SI3_10.jpg
# Labels for SI3_10.jpg: engagement ring, body jewelry, ring, pre-engagement ring, wedding ring, gemstone, diamond, wedding ceremony supply, screenshot
# Fetching images for I1...
# Image saved: GEM_CLARITY\I1\I1_1.jpg
# Labels for I1_1.jpg: ring, body jewelry, natural material, diamond, silver, engagement ring, wedding ceremony supply, gemstone, wedding ring, pre-engagement ring
# Image saved: GEM_CLARITY\I1\I1_2.jpg
# Labels for I1_2.jpg: pink, gemstone, body jewelry, natural material, ruby, diamond, engagement ring, pre-engagement ring
# Image saved: GEM_CLARITY\I1\I1_3.jpg
# Labels for I1_3.jpg: engagement ring, fashion, diamond, body jewelry, gemstone, jewellery, pre-engagement ring, wedding ring, platinum, natural material
# Image saved: GEM_CLARITY\I1\I1_4.jpg
# Labels for I1_4.jpg: ring, pre-engagement ring, gemstone, diamond, engagement ring, wedding ring
# Image saved: GEM_CLARITY\I1\I1_5.jpg
# Labels for I1_5.jpg: engagement ring, jewellery, gemstone, body jewelry, wedding ceremony supply, wedding ring, ring, diamond, pre-engagement ring, mineral
# Image saved: GEM_CLARITY\I1\I1_6.jpg
# Labels for I1_6.jpg: technology, ring, silver, titanium ring, pre-engagement ring, platinum, titanium, wedding ring, nickel, silver
# Image saved: GEM_CLARITY\I1\I1_7.jpg
# Labels for I1_7.jpg: body jewelry, diamond, wedding ceremony supply, gemstone, ring, silver, natural material, engagement ring, pre-engagement ring, crystal
# Image saved: GEM_CLARITY\I1\I1_8.jpg
# Labels for I1_8.jpg: ring, pre-engagement ring, titanium ring, wedding ring, natural material, platinum, silver, engagement ring, diamond, silver
# Image saved: GEM_CLARITY\I1\I1_9.jpg
# Labels for I1_9.jpg: diamond, body jewelry, gemstone, silver, natural material, crystal, wedding ceremony supply, ring, mineral, platinum
# Image saved: GEM_CLARITY\I1\I1_10.jpg
# Labels for I1_10.jpg: wedding ceremony supply, gemstone, body jewelry, ring, pre-engagement ring, natural material, diamond, engagement ring, wedding ring, gold
# Fetching images for I2...
# Image saved: GEM_CLARITY\I2\I2_1.jpg
# Labels for I2_1.jpg: silver, metal, pre-engagement ring, natural material, wedding ring, design, wedding ceremony supply, titanium ring, ring, diamond
# Image saved: GEM_CLARITY\I2\I2_2.jpg
# Labels for I2_2.jpg: engagement ring, gemstone, diamond, pre-engagement ring, wedding ring, ring, wedding ceremony supply, gold, natural material, crystal
# Image saved: GEM_CLARITY\I2\I2_3.jpg
# Labels for I2_3.jpg: natural material, metal, silver, wedding ring, pre-engagement ring, copper, wedding ceremony supply, nickel, body jewelry
# Image saved: GEM_CLARITY\I2\I2_4.jpg
# Labels for I2_4.jpg: engagement ring, body jewelry, gemstone, jewellery, diamond, wedding ring, ring, crystal, pre-engagement ring, natural material
# Image saved: GEM_CLARITY\I2\I2_5.jpg
# Labels for I2_5.jpg: engagement ring, wedding ring, diamond, pre-engagement ring, silver, body jewelry, natural material, ring, gemstone, wedding ceremony supply
# Image saved: GEM_CLARITY\I2\I2_6.jpg
# Labels for I2_6.jpg: engagement ring, gemstone, diamond, pre-engagement ring, wedding ring, ring, metal, wedding ceremony supply, gold, natural material
# Image saved: GEM_CLARITY\I2\I2_7.jpg
# Labels for I2_7.jpg: yellow, wedding ring, wedding ceremony supply, pre-engagement ring, engagement ring, ring, gold, bangle, diamond, body jewelry
# Image saved: GEM_CLARITY\I2\I2_8.jpg
# Labels for I2_8.jpg: engagement ring, wedding ring, diamond, ring, pre-engagement ring, natural material, platinum, gold, gemstone, wedding ceremony supply
# Image saved: GEM_CLARITY\I2\I2_9.jpg
# Labels for I2_9.jpg: engagement ring, wedding ring, diamond, pre-engagement ring, body jewelry, ring, silver, natural material, gemstone, wedding ceremony supply
# Image saved: GEM_CLARITY\I2\I2_10.jpg
# Labels for I2_10.jpg: engagement ring, diamond, platinum, pre-engagement ring, natural material, wedding ring, ring, body jewelry, nickel
# Fetching images for I3...
# Image saved: GEM_CLARITY\I3\I3_1.jpg
# Labels for I3_1.jpg: jewellery, gemstone, body jewelry, natural material, diamond, silver, crystal, ring, mineral, pre-engagement ring
# Image saved: GEM_CLARITY\I3\I3_2.jpg
# Labels for I3_2.jpg: engagement ring, diamond, pre-engagement ring, body jewelry, gemstone, ring, wedding ring, natural material, wedding ceremony supply, platinum
# Image saved: GEM_CLARITY\I3\I3_3.jpg
# Labels for I3_3.jpg: gemstone, engagement ring, diamond, wedding ceremony supply, natural material, wedding ring, pre-engagement ring, crystal, ring, body jewelry
# Failed to download image: https://www.kayoutlet.com/productimages/processed/V-930882206_0_800.jpg?pristine=true (Status Code: 403)
# Image saved: GEM_CLARITY\I3\I3_4.jpg
# Labels for I3_4.jpg: engagement ring, brown, diamond, pre-engagement ring, gemstone, wedding ring, natural material, ring, wedding ceremony supply, crystal
# Image saved: GEM_CLARITY\I3\I3_5.jpg
# Labels for I3_5.jpg: engagement ring, diamond, body jewelry, pre-engagement ring, gemstone, ring, wedding ring, natural material, wedding ceremony supply, platinum
# Image saved: GEM_CLARITY\I3\I3_6.jpg
# Labels for I3_6.jpg: engagement ring, gemstone, diamond, wedding ceremony supply, natural material, wedding ring, pre-engagement ring, ring, crystal, body jewelry
# Image saved: GEM_CLARITY\I3\I3_7.jpg
# Labels for I3_7.jpg: body jewelry, diamond, gemstone, natural material, pre-engagement ring
# Image saved: GEM_CLARITY\I3\I3_8.jpg
# Labels for I3_8.jpg: gemstone, engagement ring, body jewelry, diamond, pre-engagement ring, jewellery, wedding ring, ring, natural material, crystal
# Image saved: GEM_CLARITY\I3\I3_9.jpg
# Labels for I3_9.jpg: jewellery, engagement ring, gemstone, body jewelry, diamond, ring, pre-engagement ring, wedding ring, wedding ceremony supply, natural material
