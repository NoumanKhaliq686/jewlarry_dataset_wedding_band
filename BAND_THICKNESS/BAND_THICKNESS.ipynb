# %%
import os
import requests
from google.cloud import vision
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError
from PIL import Image
from io import BytesIO

# Ensure the image storage directory exists
IMAGE_DIR = "Band_thickness"
os.makedirs(IMAGE_DIR, exist_ok=True)

# List of shink design for which we will fetch images
Thickness=[
   "1.9mm",
"2.3mm" ,
"5.5mm",
"6mm",
"7mm",
"8mm",
  
 
 ]


def search_image(query, api_key, cse_id):
    """Search for images using Google Custom Search JSON API."""
    try:
        # Format query to avoid invalid characters
        formatted_query = query.replace(" ", "+").replace("-", "_").replace(".", "")  # Remove dots
        
        service = build("customsearch", "v1", developerKey=api_key)
        res = service.cse().list(
            q=formatted_query + "wedding+band+diamond",
            cx=cse_id,
            searchType="image",
            num=10 # Reduced to 10 as per Google API limits
        ).execute()

        if "items" in res:
            return [item["link"] for item in res["items"]]
        else:
            print(f"No images found for query: {query}")
    except HttpError as e:
        print(f"Google Search API Error: {e}")
    return []

def analyze_image(image_url):
    """Analyze image using Google Cloud Vision API."""
    try:
        client = vision.ImageAnnotatorClient()
        image = vision.Image()
        image.source.image_uri = image_url
        response = client.label_detection(image=image)
        labels = [label.description.lower() for label in response.label_annotations]
        return labels
    except Exception as e:
        print(f"Vision API Error: {e}")
        return []

def download_image(image_url, save_path):
    """Download and save an image if it's valid."""
    try:
        response = requests.get(image_url, timeout=10)
        if response.status_code == 200:
            img = Image.open(BytesIO(response.content))
            img.verify()  # Ensure it's a valid image
            img = Image.open(BytesIO(response.content))  # Reopen after verification
            img = img.convert("RGB")  # Convert to standard format
            img.save(save_path, format="JPEG")  # Save as JPEG
            return save_path
        else:
            print(f"Failed to download image: {image_url} (Status Code: {response.status_code})")
    except Exception as e:
        print(f"Error downloading or verifying image: {e} - URL: {image_url}")
    return None

def create_folder_structure():
    """Create subfolders for each gem color."""
    for cat in Thickness:
        folder_path = os.path.join(IMAGE_DIR, cat)
        os.makedirs(folder_path, exist_ok=True)

def fetch_and_save_images(api_key, cse_id):
    """Fetch and save images for each gem color, using Google Custom Search and Vision API."""
    for cat in Thickness:
        print(f"Fetching images for {cat}...")

        # Create subfolder for the current gem color
        color_folder = os.path.join(IMAGE_DIR, cat)
        
        # Search for images related to the gem color
        image_urls = search_image(cat, api_key, cse_id)

        if image_urls:
            downloaded_images = 0  # Track successfully downloaded images

            for image_url in image_urls:
                if downloaded_images >= 20:  # Stop if we have downloaded 20 images
                    break
                
                # Generate unique file name for each image
                image_filename = f"{cat.replace(' ', '_')}_{downloaded_images + 1}.jpg"
                image_path = os.path.join(color_folder, image_filename)

                # Attempt to download and save the image
                saved_image = download_image(image_url, image_path)

                if saved_image:
                    print(f"Image saved: {saved_image}")

                    # Analyze image with Vision API and get labels
                    labels = analyze_image(image_url)
                    print(f"Labels for {image_filename}: {', '.join(labels)}")
                    
                    downloaded_images += 1
        else:
            print(f"No images found for {cat}")

# Google API credentials (Replace these with your actual credentials)
API_KEY = "AIzaSyAo5M5HXAXSkVxBzHRG0bUMRJf3RltEhJw"  # Replace with your actual API key
CSE_ID = "d63ff1141028241de"  # Replace with your actual CSE ID

# Set Google Cloud credentials
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = r"C:/Users/TechAir\Desktop/BAND_THICKNESS/jewelry-449211-b1561756ae8d.json"  

# Create the folder structure for Gem Color categories
create_folder_structure()

# Fetch and save images for each gem color
fetch_and_save_images(API_KEY, CSE_ID)
# Out:
# Fetching images for 1.9mm...
# Image saved: Band_thickness\1.9mm\1.9mm_1.jpg
# Labels for 1.9mm_1.jpg: gemstone, crystal, ring, silver, jewellery, diamond, natural material, mineral, wedding ceremony supply, metal
# Image saved: Band_thickness\1.9mm\1.9mm_2.jpg
# Labels for 1.9mm_2.jpg: earring, body jewelry, jewellery, metal, natural material, bangle, silver, gold, jewelry making, brass
# Image saved: Band_thickness\1.9mm\1.9mm_3.jpg
# Labels for 1.9mm_3.jpg: earring, jewellery, body jewelry, jewelry making, metal, brass, natural material, gold, gemstone, ring
# Image saved: Band_thickness\1.9mm\1.9mm_4.jpg
# Labels for 1.9mm_4.jpg: earring, body jewelry, silver, natural material, metal, platinum, ring, nickel, silver, titanium
# Image saved: Band_thickness\1.9mm\1.9mm_5.jpg
# Labels for 1.9mm_5.jpg: silver, metal, natural material, wedding ceremony supply, ring, titanium ring, nickel, titanium, pre-engagement ring, platinum
# Image saved: Band_thickness\1.9mm\1.9mm_6.jpg
# Labels for 1.9mm_6.jpg: body jewelry, jewellery, earring, silver, natural material, metal, ring, gemstone, platinum, diamond
# Image saved: Band_thickness\1.9mm\1.9mm_7.jpg
# Labels for 1.9mm_7.jpg: gemstone, crystal, ring, jewellery, silver, body jewelry, natural material, mineral, wedding ceremony supply, diamond
# Image saved: Band_thickness\1.9mm\1.9mm_8.jpg
# Labels for 1.9mm_8.jpg: earring, body jewelry, jewellery, gemstone, metal, natural material, ring, silver, diamond, jewelry making
# Image saved: Band_thickness\1.9mm\1.9mm_9.jpg
# Labels for 1.9mm_9.jpg: yellow, natural material, gemstone, jade
# Image saved: Band_thickness\1.9mm\1.9mm_10.jpg
# Labels for 1.9mm_10.jpg: earring, body jewelry, jewellery, gemstone, metal, natural material, ring, silver, diamond, jewelry making
# Fetching images for 2.3mm...
# Image saved: Band_thickness\2.3mm\2.3mm_1.jpg
# Labels for 2.3mm_1.jpg: button, dishware, oval, badge
# Failed to download image: https://media.beaverbrooks.co.uk/i/beaverbrooks/WBB3252_0/Maple-Leaf-Diamonds-18ct-White-Gold-Diamond-23mm-Wedding-Ring-0009520?$PDP_M$ (Status Code: 403)
# Image saved: Band_thickness\2.3mm\2.3mm_2.jpg
# Labels for 2.3mm_2.jpg: button, dishware, oval, badge
# Image saved: Band_thickness\2.3mm\2.3mm_3.jpg
# Labels for 2.3mm_3.jpg: ring, engagement ring, body jewelry, jewellery, wedding ring, pre-engagement ring, natural material, wedding ceremony supply, diamond, metal
# Image saved: Band_thickness\2.3mm\2.3mm_4.jpg
# Labels for 2.3mm_4.jpg: engagement ring, white, jewellery, ring, body jewelry, diamond, gemstone, wedding ring, crystal, pre-engagement ring
# Image saved: Band_thickness\2.3mm\2.3mm_5.jpg
# Labels for 2.3mm_5.jpg: blue, gemstone, crystal, natural material, silver, body jewelry, creative arts, sapphire, jewelry making, bead
# Image saved: Band_thickness\2.3mm\2.3mm_6.jpg
# Labels for 2.3mm_6.jpg: white, engagement ring, body jewelry, pre-engagement ring, diamond, natural material, ring, silver, gemstone, platinum
# Image saved: Band_thickness\2.3mm\2.3mm_7.jpg
# Labels for 2.3mm_7.jpg: blue, gemstone, natural material, crystal, silver, sapphire, body jewelry, bead
# Image saved: Band_thickness\2.3mm\2.3mm_8.jpg
# Labels for 2.3mm_8.jpg: crochet, creative arts, craft, knitting, yarn, wool, woolen, embellishment, pattern, lace
# Image saved: Band_thickness\2.3mm\2.3mm_9.jpg
# Labels for 2.3mm_9.jpg: paper, paper product, box, design, office supplies, packaging and labeling, graphic design, publication
# Fetching images for 5.5mm...
# Image saved: Band_thickness\5.5mm\5.5mm_1.jpg
# Labels for 5.5mm_1.jpg: ring, engagement ring, wedding ceremony supply, wedding ring, jewellery, diamond, pre-engagement ring, body jewelry, natural material, silver
# Image saved: Band_thickness\5.5mm\5.5mm_2.jpg
# Labels for 5.5mm_2.jpg: ring, white, engagement ring, jewellery, wedding ring, wedding ceremony supply, body jewelry, diamond, pre-engagement ring, titanium ring
# Image saved: Band_thickness\5.5mm\5.5mm_3.jpg
# Labels for 5.5mm_3.jpg: ring, engagement ring, wedding ceremony supply, pre-engagement ring, wedding ring, jewellery, diamond, titanium ring, natural material, silver
# Image saved: Band_thickness\5.5mm\5.5mm_4.jpg
# Labels for 5.5mm_4.jpg: ring, engagement ring, white, jewellery, wedding ring, wedding ceremony supply, diamond, body jewelry, pre-engagement ring, titanium ring
# Image saved: Band_thickness\5.5mm\5.5mm_5.jpg
# Labels for 5.5mm_5.jpg: ring, engagement ring, wedding ceremony supply, wedding ring, pre-engagement ring, diamond, jewellery, natural material, silver, body jewelry
# Image saved: Band_thickness\5.5mm\5.5mm_6.jpg
# Labels for 5.5mm_6.jpg: gemstone, crystal, diamond, natural material, silver, ring, engagement ring, pre-engagement ring, mineral, silver
# Image saved: Band_thickness\5.5mm\5.5mm_7.jpg
# Labels for 5.5mm_7.jpg: ring, wedding ceremony supply, jewellery, engagement ring, pre-engagement ring, wedding ring, natural material, body jewelry, titanium ring, silver
# Image saved: Band_thickness\5.5mm\5.5mm_8.jpg
# Labels for 5.5mm_8.jpg: natural material, pre-engagement ring, ring, strap, titanium, titanium ring, watch, wedding ring
# Image saved: Band_thickness\5.5mm\5.5mm_9.jpg
# Labels for 5.5mm_9.jpg: ring, jewellery, wedding ring, pre-engagement ring, engagement ring, metal, wedding ceremony supply, titanium ring, natural material, silver
# Image saved: Band_thickness\5.5mm\5.5mm_10.jpg
# Labels for 5.5mm_10.jpg: ring, white, engagement ring, jewellery, wedding ring, wedding ceremony supply, body jewelry, diamond, pre-engagement ring, titanium ring
# Fetching images for 6mm...
# Image saved: Band_thickness\6mm\6mm_1.jpg
# Labels for 6mm_1.jpg: jewellery, ring, engagement ring, body jewelry, wedding ring, pre-engagement ring, silver, metal, natural material, diamond
# Image saved: Band_thickness\6mm\6mm_2.jpg
# Labels for 6mm_2.jpg: ring, bangle, wedding ring, metal, gold, pre-engagement ring, wedding ceremony supply, natural material, engagement ring, body jewelry
# Image saved: Band_thickness\6mm\6mm_3.jpg
# Labels for 6mm_3.jpg:
# Image saved: Band_thickness\6mm\6mm_4.jpg
# Labels for 6mm_4.jpg: engagement ring, jewellery, pre-engagement ring, wedding ring, diamond, gold, body jewelry, gemstone, ring, wedding ceremony supply
# Image saved: Band_thickness\6mm\6mm_5.jpg
# Labels for 6mm_5.jpg: engagement ring, ring, gemstone, diamond, jewellery, natural material, wedding ring, pre-engagement ring, metal, body jewelry
# Image saved: Band_thickness\6mm\6mm_6.jpg
# Labels for 6mm_6.jpg:
# Image saved: Band_thickness\6mm\6mm_7.jpg
# Labels for 6mm_7.jpg: ring, engagement ring, jewellery, wedding ceremony supply, wedding ring, natural material, diamond, pre-engagement ring, metal, gemstone
# Image saved: Band_thickness\6mm\6mm_8.jpg
# Labels for 6mm_8.jpg: silver, metal, pre-engagement ring, diamond, natural material, wedding ring, platinum, silver, engagement ring, nickel
# Image saved: Band_thickness\6mm\6mm_9.jpg
# Labels for 6mm_9.jpg:
# Image saved: Band_thickness\6mm\6mm_10.jpg
# Labels for 6mm_10.jpg: ring, wedding ring, engagement ring, diamond, wedding ceremony supply, natural material, bangle, pre-engagement ring, silver, platinum
# Fetching images for 7mm...
# Failed to download image: https://www.kay.com/productimages/processed/V-031600202_0_800.jpg?pristine=true (Status Code: 403)
# Failed to download image: https://www.reeds.com/media/catalog/product/cache/38c3c1b8e53ef11aa9803a5390245afc/1/_/1_10ct_bezel-set_diamond_and_pearl_white_ceramic_inlay_yellow_gold_wedding_band__7mm__men_s-1-22-6240ycew7-g-hxbf913fa2_1.jpg (Status Code: 403)
# Image saved: Band_thickness\7mm\7mm_1.jpg
# Labels for 7mm_1.jpg: metal, wedding ring, pre-engagement ring, ring, silver, copper, natural material, engagement ring, platinum, titanium
# Failed to download image: https://www.kay.com/productimages/processed/V-031747304_0_800.jpg?pristine=true (Status Code: 403)
# Image saved: Band_thickness\7mm\7mm_2.jpg
# Labels for 7mm_2.jpg: carbon fibers, silver, natural material, ring, triangle, titanium, titanium ring
# Image saved: Band_thickness\7mm\7mm_3.jpg
# Labels for 7mm_3.jpg: natural material, wedding ring, pre-engagement ring, diamond, silver, ring, wedding ceremony supply, gold, engagement ring, bangle
# Failed to download image: https://beardsdiamonds.com/wp-content/uploads/2020/10/Gabriel-MBM0134-70W4JJJ-5.jpg (Status Code: 403)
# Image saved: Band_thickness\7mm\7mm_4.jpg
# Labels for 7mm_4.jpg: silver, pre-engagement ring, platinum, titanium, ring, wedding ring, silver, titanium ring
# Image saved: Band_thickness\7mm\7mm_5.jpg
# Labels for 7mm_5.jpg:
# Image saved: Band_thickness\7mm\7mm_6.jpg
# Labels for 7mm_6.jpg: silver, natural material, metal, pre-engagement ring, wedding ring, ring, diamond, platinum, titanium, engagement ring
# Fetching images for 8mm...
# Image saved: Band_thickness\8mm\8mm_1.jpg
# Labels for 8mm_1.jpg:
# Image saved: Band_thickness\8mm\8mm_2.jpg
# Labels for 8mm_2.jpg: ring, titanium ring, pre-engagement ring, wedding ring, metal, wedding ceremony supply, silver, natural material, titanium, platinum
# Image saved: Band_thickness\8mm\8mm_3.jpg
# Labels for 8mm_3.jpg: ring, diamond, pre-engagement ring, engagement ring, wedding ring, bangle, gold, natural material, gemstone, wedding ceremony supply
# Image saved: Band_thickness\8mm\8mm_4.jpg
# Labels for 8mm_4.jpg: metal, natural material, silver, platinum, titanium, wedding ring, ring, pre-engagement ring, titanium ring, silver
# Image saved: Band_thickness\8mm\8mm_5.jpg
# Labels for 8mm_5.jpg: ring, pre-engagement ring, wedding ring, diamond, platinum, titanium ring
# Image saved: Band_thickness\8mm\8mm_6.jpg
# Labels for 8mm_6.jpg: white, silver, metal, natural material, design, platinum, electronics, silver, gadget, titanium
# Image saved: Band_thickness\8mm\8mm_7.jpg
# Labels for 8mm_7.jpg: ring, fashion, wedding ring, pre-engagement ring, jewellery, titanium ring, wedding ceremony supply, engagement ring, silver, metal
# Image saved: Band_thickness\8mm\8mm_8.jpg
# Labels for 8mm_8.jpg: fashion, jewellery, silver, ring, wedding ring, engagement ring, metal, pre-engagement ring, diamond, platinum
# Image saved: Band_thickness\8mm\8mm_9.jpg
# Labels for 8mm_9.jpg: engagement ring, ring, wedding ring, gemstone, diamond, pre-engagement ring, wedding ceremony supply, natural material, gold, crystal
# Image saved: Band_thickness\8mm\8mm_10.jpg
# Labels for 8mm_10.jpg:
