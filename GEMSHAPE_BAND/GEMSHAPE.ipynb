# %%
import os
import requests
from google.cloud import vision
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError
from PIL import Image
from io import BytesIO

# Ensure the image storage directory exists
IMAGE_DIR = "GEMSHAPE"
os.makedirs(IMAGE_DIR, exist_ok=True)

# List of shink design for which we will fetch images
shape=[
  "Round",
"Oval",
"Princess",
"Emerald",
"Baguette",
"Pear",
"Marquise",
"Heart",
"Asscher",
"Radiant",
"Cushion",
"Trilliant"
   
 ]


def search_image(query, api_key, cse_id):
    """Search for images using Google Custom Search JSON API."""
    try:
        # Format query to avoid invalid characters
        formatted_query = query.replace(" ", "+").replace("-", "_").replace(".", "")  # Remove dots
        
        service = build("customsearch", "v1", developerKey=api_key)
        res = service.cse().list(
            q=formatted_query + "wedding+band+diamond",
            cx=cse_id,
            searchType="image",
            num=10 # Reduced to 10 as per Google API limits
        ).execute()

        if "items" in res:
            return [item["link"] for item in res["items"]]
        else:
            print(f"No images found for query: {query}")
    except HttpError as e:
        print(f"Google Search API Error: {e}")
    return []

def analyze_image(image_url):
    """Analyze image using Google Cloud Vision API."""
    try:
        client = vision.ImageAnnotatorClient()
        image = vision.Image()
        image.source.image_uri = image_url
        response = client.label_detection(image=image)
        labels = [label.description.lower() for label in response.label_annotations]
        return labels
    except Exception as e:
        print(f"Vision API Error: {e}")
        return []

def download_image(image_url, save_path):
    """Download and save an image if it's valid."""
    try:
        response = requests.get(image_url, timeout=10)
        if response.status_code == 200:
            img = Image.open(BytesIO(response.content))
            img.verify()  # Ensure it's a valid image
            img = Image.open(BytesIO(response.content))  # Reopen after verification
            img = img.convert("RGB")  # Convert to standard format
            img.save(save_path, format="JPEG")  # Save as JPEG
            return save_path
        else:
            print(f"Failed to download image: {image_url} (Status Code: {response.status_code})")
    except Exception as e:
        print(f"Error downloading or verifying image: {e} - URL: {image_url}")
    return None

def create_folder_structure():
    """Create subfolders for each gem color."""
    for cat in shape:
        folder_path = os.path.join(IMAGE_DIR, cat)
        os.makedirs(folder_path, exist_ok=True)

def fetch_and_save_images(api_key, cse_id):
    """Fetch and save images for each gem color, using Google Custom Search and Vision API."""
    for cat in shape:
        print(f"Fetching images for {cat}...")

        # Create subfolder for the current gem color
        color_folder = os.path.join(IMAGE_DIR, cat)
        
        # Search for images related to the gem color
        image_urls = search_image(cat, api_key, cse_id)

        if image_urls:
            downloaded_images = 0  # Track successfully downloaded images

            for image_url in image_urls:
                if downloaded_images >= 20:  # Stop if we have downloaded 20 images
                    break
                
                # Generate unique file name for each image
                image_filename = f"{cat.replace(' ', '_')}_{downloaded_images + 1}.jpg"
                image_path = os.path.join(color_folder, image_filename)

                # Attempt to download and save the image
                saved_image = download_image(image_url, image_path)

                if saved_image:
                    print(f"Image saved: {saved_image}")

                    # Analyze image with Vision API and get labels
                    labels = analyze_image(image_url)
                    print(f"Labels for {image_filename}: {', '.join(labels)}")
                    
                    downloaded_images += 1
        else:
            print(f"No images found for {cat}")

# Google API credentials (Replace these with your actual credentials)
API_KEY = "AIzaSyAo5M5HXAXSkVxBzHRG0bUMRJf3RltEhJw"  # Replace with your actual API key
CSE_ID = "d63ff1141028241de"  # Replace with your actual CSE ID

# Set Google Cloud credentials
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = r"C:/Users/TechAir\Desktop/GEMSHAPE_BAND/jewelry-449211-b1561756ae8d.json"  

# Create the folder structure for Gem Color categories
create_folder_structure()

# Fetch and save images for each gem color
fetch_and_save_images(API_KEY, CSE_ID)
# Out:
# Fetching images for Round...
# Image saved: GEMSHAPE\Round\Round_1.jpg
# Labels for Round_1.jpg: engagement ring, ring, fashion, gemstone, jewellery, body jewelry, diamond, wedding ring, pre-engagement ring, wedding ceremony supply
# Image saved: GEMSHAPE\Round\Round_2.jpg
# Labels for Round_2.jpg: ring, silver, metal, natural material, wedding ceremony supply, pre-engagement ring, titanium, wedding ring, platinum, titanium ring
# Image saved: GEMSHAPE\Round\Round_3.jpg
# Labels for Round_3.jpg:
# Image saved: GEMSHAPE\Round\Round_4.jpg
# Labels for Round_4.jpg: ring, jewellery, pre-engagement ring, wedding ceremony supply, wedding ring, silver, engagement ring, body jewelry, natural material, metal
# Image saved: GEMSHAPE\Round\Round_5.jpg
# Labels for Round_5.jpg: engagement ring
# Image saved: GEMSHAPE\Round\Round_6.jpg
# Labels for Round_6.jpg: ring, engagement ring, wedding ring, pre-engagement ring, natural material, titanium ring, silver, body jewelry, wedding ceremony supply, platinum
# Image saved: GEMSHAPE\Round\Round_7.jpg
# Labels for Round_7.jpg: engagement ring, ring, jewellery, body jewelry, diamond, gemstone, wedding ring, pre-engagement ring, natural material, wedding ceremony supply
# Image saved: GEMSHAPE\Round\Round_8.jpg
# Labels for Round_8.jpg: engagement ring, diamond, pre-engagement ring, wedding ring, gemstone, natural material, wedding ceremony supply, titanium ring, ring, mineral
# Image saved: GEMSHAPE\Round\Round_9.jpg
# Labels for Round_9.jpg: jewellery, fashion, body jewelry, ring, engagement ring, wedding ceremony supply, metal, diamond, gemstone, natural material
# Image saved: GEMSHAPE\Round\Round_10.jpg
# Labels for Round_10.jpg: engagement ring, ring, gemstone, jewellery, diamond, metal, natural material, wedding ring, body jewelry, silver
# Fetching images for Oval...
# Image saved: GEMSHAPE\Oval\Oval_1.jpg
# Labels for Oval_1.jpg: engagement ring, fashion, finger, ring, jewellery, gemstone, wedding ceremony supply, body jewelry, diamond, nail
# Image saved: GEMSHAPE\Oval\Oval_2.jpg
# Labels for Oval_2.jpg: jewellery, gemstone, engagement ring, ring, body jewelry, crystal, diamond, wedding ring, wedding ceremony supply, silver
# Image saved: GEMSHAPE\Oval\Oval_3.jpg
# Labels for Oval_3.jpg: engagement ring, jewellery, ring, gemstone, body jewelry, wedding ring, diamond, pre-engagement ring, wedding ceremony supply, natural material
# Image saved: GEMSHAPE\Oval\Oval_4.jpg
# Labels for Oval_4.jpg: engagement ring, diamond, silver, wedding ring, body jewelry, gemstone, natural material, ring, wedding ceremony supply, pre-engagement ring
# Image saved: GEMSHAPE\Oval\Oval_5.jpg
# Labels for Oval_5.jpg: wedding ceremony supply, ring, engagement ring, gemstone, body jewelry, diamond, jewellery, wedding ring, pre-engagement ring, mineral
# Image saved: GEMSHAPE\Oval\Oval_6.jpg
# Labels for Oval_6.jpg: engagement ring, diamond, ring, wedding ring, pre-engagement ring, silver, body jewelry, natural material, platinum, gemstone
# Image saved: GEMSHAPE\Oval\Oval_7.jpg
# Labels for Oval_7.jpg: engagement ring, ring, jewellery, gemstone, body jewelry, fashion, wedding ring, wedding ceremony supply, diamond, crystal
# Image saved: GEMSHAPE\Oval\Oval_8.jpg
# Labels for Oval_8.jpg: engagement ring, fashion, gemstone, diamond, body jewelry, ring, crystal, natural material, wedding ceremony supply, wedding ring
# Image saved: GEMSHAPE\Oval\Oval_9.jpg
# Labels for Oval_9.jpg: diamond, gemstone, pre-engagement ring, engagement ring, ring
# Image saved: GEMSHAPE\Oval\Oval_10.jpg
# Labels for Oval_10.jpg: engagement ring, jewellery, ring, body jewelry, wedding ring, gemstone, diamond, wedding ceremony supply, pre-engagement ring, crystal
# Fetching images for Princess...
# Failed to download image: https://solidgoldjewelers.net/wp-content/uploads/Dia-C00902.jpeg (Status Code: 403)
# Image saved: GEMSHAPE\Princess\Princess_1.jpg
# Labels for Princess_1.jpg: yellow, ring, jewellery, body jewelry, gemstone, metal, natural material, wedding ring, diamond, wedding ceremony supply
# Image saved: GEMSHAPE\Princess\Princess_2.jpg
# Labels for Princess_2.jpg: diamond, gemstone, bangle, wedding ceremony supply, ring, pre-engagement ring, natural material, wedding ring, silver, engagement ring
# Image saved: GEMSHAPE\Princess\Princess_3.jpg
# Labels for Princess_3.jpg: engagement ring, gemstone, body jewelry, diamond, natural material, pre-engagement ring, silver, platinum, mineral, ring
# Image saved: GEMSHAPE\Princess\Princess_4.jpg
# Labels for Princess_4.jpg:
# Image saved: GEMSHAPE\Princess\Princess_5.jpg
# Labels for Princess_5.jpg: fashion, engagement ring, diamond, wedding ring, silver, ring, pre-engagement ring, gemstone, natural material, platinum
# Image saved: GEMSHAPE\Princess\Princess_6.jpg
# Labels for Princess_6.jpg: diamond, gemstone, natural material, ring, engagement ring, body jewelry, pre-engagement ring, crystal, wedding ring, platinum
# Image saved: GEMSHAPE\Princess\Princess_7.jpg
# Labels for Princess_7.jpg: natural material, gemstone, diamond
# Image saved: GEMSHAPE\Princess\Princess_8.jpg
# Labels for Princess_8.jpg: silver, natural material, engagement ring, diamond, pre-engagement ring, platinum, wedding ring, silver, titanium, ring
# Image saved: GEMSHAPE\Princess\Princess_9.jpg
# Labels for Princess_9.jpg: jewellery, engagement ring, gemstone, ring, body jewelry, crystal, diamond, jewelry making, pre-engagement ring, wedding ring
# Fetching images for Emerald...
# Failed to download image: https://www.valina.com/media/catalog/product/cache/3d2d4bde6fa8749cfa1564e04fd559c4/c/c/cce2536-w.jpg (Status Code: 403)
# Image saved: GEMSHAPE\Emerald\Emerald_1.jpg
# Labels for Emerald_1.jpg: gemstone, natural material, diamond, engagement ring, ring, body jewelry, wedding ceremony supply, pre-engagement ring, wedding ring, mineral
# Image saved: GEMSHAPE\Emerald\Emerald_2.jpg
# Labels for Emerald_2.jpg: gemstone, natural material, diamond, engagement ring, ring, wedding ceremony supply, body jewelry, pre-engagement ring, wedding ring, mineral
# Image saved: GEMSHAPE\Emerald\Emerald_3.jpg
# Labels for Emerald_3.jpg: jewellery, ring, engagement ring, gemstone, crystal, wedding ring, diamond, wedding ceremony supply, pre-engagement ring, natural material
# Image saved: GEMSHAPE\Emerald\Emerald_4.jpg
# Labels for Emerald_4.jpg: gemstone, emerald, body jewelry, natural material, diamond, pre-engagement ring, crystal, ring, wedding ring, engagement ring
# Image saved: GEMSHAPE\Emerald\Emerald_5.jpg
# Labels for Emerald_5.jpg: diamond, silver, natural material, platinum, mineral, crystal
# Image saved: GEMSHAPE\Emerald\Emerald_6.jpg
# Labels for Emerald_6.jpg: gemstone, crystal, emerald, engagement ring, ring, body jewelry, diamond, natural material, pre-engagement ring, wedding ring
# Image saved: GEMSHAPE\Emerald\Emerald_7.jpg
# Labels for Emerald_7.jpg: gemstone, natural material, diamond, engagement ring, ring, wedding ceremony supply, body jewelry, pre-engagement ring, wedding ring, mineral
# Image saved: GEMSHAPE\Emerald\Emerald_8.jpg
# Labels for Emerald_8.jpg: natural material, silver, diamond, mineral, gemstone, pre-engagement ring, platinum, copper, nickel
# Image saved: GEMSHAPE\Emerald\Emerald_9.jpg
# Labels for Emerald_9.jpg: blue, natural material, bangle, ring, pre-engagement ring, silver, wedding ring, wedding ceremony supply, turquoise, body jewelry
# Fetching images for Baguette...
# Image saved: GEMSHAPE\Baguette\Baguette_1.jpg
# Labels for Baguette_1.jpg: white, engagement ring, wedding ceremony supply, body jewelry, diamond, silver, wedding ring, ring, natural material, platinum
# Image saved: GEMSHAPE\Baguette\Baguette_2.jpg
# Labels for Baguette_2.jpg: engagement ring, body jewelry, diamond, silver, natural material, platinum, gemstone, metal, mineral, ring
# Image saved: GEMSHAPE\Baguette\Baguette_3.jpg
# Labels for Baguette_3.jpg: engagement ring, jewellery, ring, gemstone, body jewelry, wedding ceremony supply, natural material, pre-engagement ring, wedding ring, silver
# c:\Users\TechAir\anaconda3\envs\webscrapping\lib\site-packages\PIL\Image.py:1045: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Image saved: GEMSHAPE\Baguette\Baguette_4.jpg
# Labels for Baguette_4.jpg: silver, ring, platinum, natural material, diamond, wedding ring, design, pre-engagement ring, silver, titanium
# Image saved: GEMSHAPE\Baguette\Baguette_5.jpg
# Labels for Baguette_5.jpg: engagement ring, jewellery, gemstone, body jewelry, ring, pre-engagement ring, diamond, silver, metal, wedding ring
# Image saved: GEMSHAPE\Baguette\Baguette_6.jpg
# Labels for Baguette_6.jpg: engagement ring, ring, fashion, wedding ring, gemstone, diamond, pre-engagement ring, silver, natural material, body jewelry
# Image saved: GEMSHAPE\Baguette\Baguette_7.jpg
# Labels for Baguette_7.jpg: engagement ring, jewellery, body jewelry, gemstone, diamond, ring, wedding ring, pre-engagement ring, crystal, natural material
# Image saved: GEMSHAPE\Baguette\Baguette_8.jpg
# Labels for Baguette_8.jpg: engagement ring, diamond, gemstone, natural material, platinum, silver, pre-engagement ring, ring, mineral, wedding ring
# Image saved: GEMSHAPE\Baguette\Baguette_9.jpg
# Labels for Baguette_9.jpg: engagement ring, gemstone, jewellery, diamond, body jewelry, pre-engagement ring, natural material, metal, silver, crystal
# Image saved: GEMSHAPE\Baguette\Baguette_10.jpg
# Labels for Baguette_10.jpg: engagement ring, ring, gemstone, fashion, wedding ring, diamond, pre-engagement ring, natural material, silver, wedding ceremony supply
# Fetching images for Pear...
# Image saved: GEMSHAPE\Pear\Pear_1.jpg
# Labels for Pear_1.jpg: engagement ring, ring, jewellery, gemstone, fashion, wedding ceremony supply, wedding ring, body jewelry, diamond, pre-engagement ring
# Image saved: GEMSHAPE\Pear\Pear_2.jpg
# Labels for Pear_2.jpg: gemstone, fashion, ring, jewellery, engagement ring, body jewelry, nail care, silver, nail polish, diamond
# Image saved: GEMSHAPE\Pear\Pear_3.jpg
# Labels for Pear_3.jpg: gemstone, natural material, diamond, crystal, mineral, body jewelry, wedding ceremony supply
# Image saved: GEMSHAPE\Pear\Pear_4.jpg
# Labels for Pear_4.jpg: body jewelry, natural material, heart, ring, love, pre-engagement ring, gemstone, engagement ring, wedding ring, diamond
# Image saved: GEMSHAPE\Pear\Pear_5.jpg
# Labels for Pear_5.jpg: engagement ring, gemstone, fashion, jewellery, body jewelry, ring, diamond, nail care, wedding ring, pre-engagement ring
# Image saved: GEMSHAPE\Pear\Pear_6.jpg
# Labels for Pear_6.jpg: engagement ring, gemstone, wedding ceremony supply, body jewelry, jewellery, wedding ring, diamond, pre-engagement ring, natural material, ring
# Image saved: GEMSHAPE\Pear\Pear_7.jpg
# Labels for Pear_7.jpg: gemstone, diamond, crystal, natural material, body jewelry, mineral, wedding ceremony supply, engagement ring, pre-engagement ring
# Image saved: GEMSHAPE\Pear\Pear_8.jpg
# Labels for Pear_8.jpg: gemstone, engagement ring, diamond, crystal, pre-engagement ring, body jewelry, wedding ring, natural material, ring, wedding ceremony supply
# Image saved: GEMSHAPE\Pear\Pear_9.jpg
# Labels for Pear_9.jpg: diamond, natural material, silver, pre-engagement ring, engagement ring, body jewelry, platinum, gemstone, design, ring
# Image saved: GEMSHAPE\Pear\Pear_10.jpg
# Labels for Pear_10.jpg: natural material, gemstone, wedding ceremony supply, diamond
# Fetching images for Marquise...
# Image saved: GEMSHAPE\Marquise\Marquise_1.jpg
# Labels for Marquise_1.jpg: gemstone, engagement ring, body jewelry, diamond, pre-engagement ring, wedding ceremony supply, ring, natural material, wedding ring, silver
# Image saved: GEMSHAPE\Marquise\Marquise_2.jpg
# Labels for Marquise_2.jpg: gemstone, engagement ring, body jewelry, ring, crystal, sapphire, diamond, jewellery, pre-engagement ring, natural material
# Image saved: GEMSHAPE\Marquise\Marquise_3.jpg
# Labels for Marquise_3.jpg: gemstone, engagement ring, wedding ceremony supply, pre-engagement ring, diamond, body jewelry, ring, wedding ring, natural material, silver
# Image saved: GEMSHAPE\Marquise\Marquise_4.jpg
# Labels for Marquise_4.jpg: engagement ring, gemstone, jewellery, body jewelry, ring, diamond, wedding ceremony supply, wedding ring, pre-engagement ring, crystal
# Image saved: GEMSHAPE\Marquise\Marquise_5.jpg
# Labels for Marquise_5.jpg: natural material, gemstone, body jewelry, crystal, diamond, ring, wedding ceremony supply, pre-engagement ring, engagement ring, sapphire
# Image saved: GEMSHAPE\Marquise\Marquise_6.jpg
# Labels for Marquise_6.jpg: engagement ring, jewellery, body jewelry, gemstone, ring, pre-engagement ring, wedding ceremony supply, wedding ring, diamond, natural material
# Image saved: GEMSHAPE\Marquise\Marquise_7.jpg
# Labels for Marquise_7.jpg: jewellery, engagement ring, ring, fashion, body jewelry, gemstone, wedding ceremony supply, wedding ring, pre-engagement ring, diamond
# Image saved: GEMSHAPE\Marquise\Marquise_8.jpg
# Labels for Marquise_8.jpg: gemstone, wedding ceremony supply, natural material, diamond, crystal
# Image saved: GEMSHAPE\Marquise\Marquise_9.jpg
# Labels for Marquise_9.jpg: engagement ring, gemstone, body jewelry, ring, pre-engagement ring, diamond, wedding ring, natural material, wedding ceremony supply, crystal
# Image saved: GEMSHAPE\Marquise\Marquise_10.jpg
# Labels for Marquise_10.jpg: engagement ring, gemstone, ring, body jewelry, sapphire, crystal, pre-engagement ring, jewellery, diamond, wedding ring
# Fetching images for Heart...
# Image saved: GEMSHAPE\Heart\Heart_1.jpg
# Labels for Heart_1.jpg: heart, natural material, body jewelry, silver, pre-engagement ring, platinum, gemstone, wedding ceremony supply
# Failed to download image: https://www.zales.com/productimages/processed/V-20102682_0_800.jpg (Status Code: 403)
# Image saved: GEMSHAPE\Heart\Heart_2.jpg
# Labels for Heart_2.jpg: ring, wedding ring, pre-engagement ring, silver, metal, natural material, engagement ring, titanium ring, diamond, wedding ceremony supply
# Image saved: GEMSHAPE\Heart\Heart_3.jpg
# Labels for Heart_3.jpg: natural material, heart, platinum, design, diamond, pre-engagement ring, engagement ring, silver, mineral
# Image saved: GEMSHAPE\Heart\Heart_4.jpg
# Labels for Heart_4.jpg: heart, engagement ring, body jewelry, pre-engagement ring, jewellery, ring, diamond, wedding ring, wedding ceremony supply, gemstone
# Image saved: GEMSHAPE\Heart\Heart_5.jpg
# Labels for Heart_5.jpg: diamond, natural material, silver, body jewelry, pre-engagement ring, engagement ring, metal, platinum, ring, wedding ceremony supply
# Image saved: GEMSHAPE\Heart\Heart_6.jpg
# Labels for Heart_6.jpg: ring, engagement ring, jewellery, wedding ring, body jewelry, wedding ceremony supply, pre-engagement ring, heart, natural material, diamond
# Image saved: GEMSHAPE\Heart\Heart_7.jpg
# Labels for Heart_7.jpg: heart, white, engagement ring, ring, body jewelry, gemstone, jewellery, pre-engagement ring, diamond, natural material
# Image saved: GEMSHAPE\Heart\Heart_8.jpg
# Labels for Heart_8.jpg: heart, ring, engagement ring, jewellery, wedding ceremony supply, body jewelry, pre-engagement ring, love, wedding ring, silver
# Image saved: GEMSHAPE\Heart\Heart_9.jpg
# Labels for Heart_9.jpg: silver, gemstone, natural material, wedding ceremony supply, diamond, crystal, body jewelry, ring, pre-engagement ring, jewelry making
# Fetching images for Asscher...
# Image saved: GEMSHAPE\Asscher\Asscher_1.jpg
# Labels for Asscher_1.jpg: gemstone, diamond, engagement ring, wedding ceremony supply, crystal, wedding ring, natural material, pre-engagement ring, ring, mineral
# Image saved: GEMSHAPE\Asscher\Asscher_2.jpg
# Labels for Asscher_2.jpg: body jewelry, gemstone, jewellery, engagement ring, wedding ceremony supply, diamond, ring, silver, natural material, wedding ring
# Image saved: GEMSHAPE\Asscher\Asscher_3.jpg
# Labels for Asscher_3.jpg: gemstone, diamond, engagement ring, wedding ceremony supply, crystal, wedding ring, natural material, pre-engagement ring, ring, mineral
# Image saved: GEMSHAPE\Asscher\Asscher_4.jpg
# Labels for Asscher_4.jpg: ring, jewellery, engagement ring, body jewelry, gemstone, wedding ceremony supply, wedding ring, diamond, pre-engagement ring, natural material
# Image saved: GEMSHAPE\Asscher\Asscher_5.jpg
# Labels for Asscher_5.jpg: bangle, ring, natural material, gemstone, body jewelry, diamond, crystal, wedding ceremony supply, wedding ring, pre-engagement ring
# Image saved: GEMSHAPE\Asscher\Asscher_6.jpg
# Labels for Asscher_6.jpg: ring, body jewelry, jewellery, wedding ceremony supply, engagement ring, gemstone, diamond, wedding ring, pre-engagement ring, silver
# Image saved: GEMSHAPE\Asscher\Asscher_7.jpg
# Labels for Asscher_7.jpg: jewellery, bangle, diamond, wedding ceremony supply, ring, crystal, natural material, body jewelry, gemstone, platinum
# Image saved: GEMSHAPE\Asscher\Asscher_8.jpg
# Labels for Asscher_8.jpg: engagement ring, jewellery, ring, gemstone, fashion, wedding ring, body jewelry, diamond, pre-engagement ring, wrist
# Image saved: GEMSHAPE\Asscher\Asscher_9.jpg
# Labels for Asscher_9.jpg: engagement ring, fashion, finger, gemstone, diamond, wedding ring, pre-engagement ring, ring, natural material, watch
# Image saved: GEMSHAPE\Asscher\Asscher_10.jpg
# Labels for Asscher_10.jpg: ring, natural material, wedding ring, gold, crystal, diamond, engagement ring, titanium, pre-engagement ring, gemstone
# Fetching images for Radiant...
# Image saved: GEMSHAPE\Radiant\Radiant_1.jpg
# Labels for Radiant_1.jpg: engagement ring, ring, diamond, gemstone, body jewelry, wedding ring, wedding ceremony supply, pre-engagement ring, mineral, silver
# Image saved: GEMSHAPE\Radiant\Radiant_2.jpg
# Labels for Radiant_2.jpg: engagement ring, ring, wedding ring, gemstone, diamond, wedding ceremony supply, pre-engagement ring, silver, body jewelry, natural material
# Image saved: GEMSHAPE\Radiant\Radiant_3.jpg
# Labels for Radiant_3.jpg: white, silver, metal, natural material, diamond, mineral, platinum, nickel, titanium, gemstone
# Image saved: GEMSHAPE\Radiant\Radiant_4.jpg
# Labels for Radiant_4.jpg: diamond, gemstone, crystal, silver, natural material, platinum, body jewelry, engagement ring, ring, wedding ceremony supply
# Image saved: GEMSHAPE\Radiant\Radiant_5.jpg
# Labels for Radiant_5.jpg: engagement ring, ring, wedding ring, pre-engagement ring, diamond, jewellery, body jewelry, wedding ceremony supply, silver, natural material
# Image saved: GEMSHAPE\Radiant\Radiant_6.jpg
# Labels for Radiant_6.jpg: engagement ring, ring, gemstone, body jewelry, crystal, wedding ring, jewellery, diamond, wedding ceremony supply, pre-engagement ring
# Image saved: GEMSHAPE\Radiant\Radiant_7.jpg
# Labels for Radiant_7.jpg: gemstone, crystal, diamond, natural material, silver, engagement ring, mineral, body jewelry, pre-engagement ring, wedding ceremony supply
# Image saved: GEMSHAPE\Radiant\Radiant_8.jpg
# Labels for Radiant_8.jpg: engagement ring, silver, gemstone, diamond, natural material, ring, pre-engagement ring, wedding ceremony supply, wedding ring, crystal
# Image saved: GEMSHAPE\Radiant\Radiant_9.jpg
# Labels for Radiant_9.jpg: engagement ring, ring, jewellery, wedding ceremony supply, wedding ring, pre-engagement ring, diamond, gemstone, metal, silver
# Image saved: GEMSHAPE\Radiant\Radiant_10.jpg
# Labels for Radiant_10.jpg: engagement ring, jewellery, ring, body jewelry, wedding ring, gemstone, silver, diamond, wedding ceremony supply, pre-engagement ring
# Fetching images for Cushion...
# Image saved: GEMSHAPE\Cushion\Cushion_1.jpg
# Labels for Cushion_1.jpg: gemstone, engagement ring, wedding ceremony supply, ring, diamond, wedding ring, body jewelry, jewellery, pre-engagement ring, crystal
# Image saved: GEMSHAPE\Cushion\Cushion_2.jpg
# Labels for Cushion_2.jpg: engagement ring, finger, gemstone, jewellery, ring, fashion, body jewelry, diamond, wedding ceremony supply, wedding ring
# Image saved: GEMSHAPE\Cushion\Cushion_3.jpg
# Labels for Cushion_3.jpg: white, engagement ring, ring, wedding ceremony supply, wedding ring, diamond, body jewelry, silver, pre-engagement ring, gemstone
# Image saved: GEMSHAPE\Cushion\Cushion_4.jpg
# Labels for Cushion_4.jpg: engagement ring, finger, jewellery, gemstone, ring, body jewelry, fashion, diamond, wedding ceremony supply, wedding ring
# Image saved: GEMSHAPE\Cushion\Cushion_5.jpg
# Labels for Cushion_5.jpg: natural material, gemstone, diamond, pre-engagement ring, ring, wedding ceremony supply, wedding ring, engagement ring, platinum, mineral
# Image saved: GEMSHAPE\Cushion\Cushion_6.jpg
# Labels for Cushion_6.jpg: diamond, engagement ring, gemstone, silver, wedding ceremony supply, platinum, pre-engagement ring, mineral, natural material, body jewelry
# Image saved: GEMSHAPE\Cushion\Cushion_7.jpg
# Labels for Cushion_7.jpg: white, diamond, gemstone, silver, wedding ceremony supply, ring, engagement ring, body jewelry, mineral, crystal
# Image saved: GEMSHAPE\Cushion\Cushion_8.jpg
# Labels for Cushion_8.jpg: engagement ring, finger, jewellery, gemstone, ring, fashion, body jewelry, diamond, wedding ceremony supply, wedding ring
# Image saved: GEMSHAPE\Cushion\Cushion_9.jpg
# Labels for Cushion_9.jpg: engagement ring, ring, wedding ring, wedding ceremony supply, gemstone, diamond, body jewelry, jewellery, pre-engagement ring, silver
# Image saved: GEMSHAPE\Cushion\Cushion_10.jpg
# Labels for Cushion_10.jpg: yellow, engagement ring, diamond, gemstone, ring, wedding ring, pre-engagement ring, natural material, body jewelry, silver
# Fetching images for Trilliant...
# Image saved: GEMSHAPE\Trilliant\Trilliant_1.jpg
# Labels for Trilliant_1.jpg: ring, engagement ring, wedding ceremony supply, wedding ring, natural material, silver, metal, pre-engagement ring, diamond, platinum
# Image saved: GEMSHAPE\Trilliant\Trilliant_2.jpg
# Labels for Trilliant_2.jpg: engagement ring, ring, gemstone, wedding ring, diamond, pre-engagement ring, wedding ceremony supply, body jewelry, jewellery, silver
# Image saved: GEMSHAPE\Trilliant\Trilliant_3.jpg
# Labels for Trilliant_3.jpg: gemstone, natural material, ring, pre-engagement ring, wedding ceremony supply, engagement ring, emerald
# Image saved: GEMSHAPE\Trilliant\Trilliant_4.jpg
# Labels for Trilliant_4.jpg: natural material, gemstone, diamond, engagement ring, pre-engagement ring, body jewelry, triangle, mineral, crystal
# Image saved: GEMSHAPE\Trilliant\Trilliant_5.jpg
# Labels for Trilliant_5.jpg: engagement ring, ring, gemstone, wedding ring, jewellery, body jewelry, wedding ceremony supply, diamond, pre-engagement ring, crystal
# Image saved: GEMSHAPE\Trilliant\Trilliant_6.jpg
# Labels for Trilliant_6.jpg: gemstone, diamond, engagement ring, silver, crystal, pre-engagement ring, ring, wedding ring, natural material, metal
# Image saved: GEMSHAPE\Trilliant\Trilliant_7.jpg
# Labels for Trilliant_7.jpg: wedding ceremony supply, pre-engagement ring, engagement ring, gemstone, wedding ring, ring, natural material, diamond, body jewelry, mineral
# Image saved: GEMSHAPE\Trilliant\Trilliant_8.jpg
# Labels for Trilliant_8.jpg: ring, engagement ring, jewellery, body jewelry, wedding ring, wedding ceremony supply, pre-engagement ring, diamond, gemstone, natural material
# Image saved: GEMSHAPE\Trilliant\Trilliant_9.jpg
# Labels for Trilliant_9.jpg: engagement ring, gemstone, pre-engagement ring, jewellery, body jewelry, ring, natural material, diamond, wedding ceremony supply, wedding ring
# Image saved: GEMSHAPE\Trilliant\Trilliant_10.jpg
# Labels for Trilliant_10.jpg: gemstone, engagement ring, diamond, natural material, triangle, pre-engagement ring, silver, crystal, mineral, wedding ceremony supply
