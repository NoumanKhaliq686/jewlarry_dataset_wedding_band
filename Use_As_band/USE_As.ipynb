# %%
import os
import requests
from google.cloud import vision
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError
from PIL import Image
from io import BytesIO

# Ensure the image storage directory exists
IMAGE_DIR = "USE_As"
os.makedirs(IMAGE_DIR, exist_ok=True)

# List of shink design for which we will fetch images
use_as=[
    "Wedding Band, Anniversary Band",
"Eternity Band",
"Promise Ring",
"Ring Enhancer",
 ]


def search_image(query, api_key, cse_id):
    """Search for images using Google Custom Search JSON API."""
    try:
        # Format query to avoid invalid characters
        formatted_query = query.replace(" ", "+").replace("-", "_").replace(".", "")  # Remove dots
        
        service = build("customsearch", "v1", developerKey=api_key)
        res = service.cse().list(
            q=formatted_query + "wedding+band+diamond",
            cx=cse_id,
            searchType="image",
            num=10 # Reduced to 10 as per Google API limits
        ).execute()

        if "items" in res:
            return [item["link"] for item in res["items"]]
        else:
            print(f"No images found for query: {query}")
    except HttpError as e:
        print(f"Google Search API Error: {e}")
    return []

def analyze_image(image_url):
    """Analyze image using Google Cloud Vision API."""
    try:
        client = vision.ImageAnnotatorClient()
        image = vision.Image()
        image.source.image_uri = image_url
        response = client.label_detection(image=image)
        labels = [label.description.lower() for label in response.label_annotations]
        return labels
    except Exception as e:
        print(f"Vision API Error: {e}")
        return []

def download_image(image_url, save_path):
    """Download and save an image if it's valid."""
    try:
        response = requests.get(image_url, timeout=10)
        if response.status_code == 200:
            img = Image.open(BytesIO(response.content))
            img.verify()  # Ensure it's a valid image
            img = Image.open(BytesIO(response.content))  # Reopen after verification
            img = img.convert("RGB")  # Convert to standard format
            img.save(save_path, format="JPEG")  # Save as JPEG
            return save_path
        else:
            print(f"Failed to download image: {image_url} (Status Code: {response.status_code})")
    except Exception as e:
        print(f"Error downloading or verifying image: {e} - URL: {image_url}")
    return None

def create_folder_structure():
    """Create subfolders for each gem color."""
    for cat in use_as:
        folder_path = os.path.join(IMAGE_DIR, cat)
        os.makedirs(folder_path, exist_ok=True)

def fetch_and_save_images(api_key, cse_id):
    """Fetch and save images for each gem color, using Google Custom Search and Vision API."""
    for cat in use_as:
        print(f"Fetching images for {cat}...")

        # Create subfolder for the current gem color
        color_folder = os.path.join(IMAGE_DIR, cat)
        
        # Search for images related to the gem color
        image_urls = search_image(cat, api_key, cse_id)

        if image_urls:
            downloaded_images = 0  # Track successfully downloaded images

            for image_url in image_urls:
                if downloaded_images >= 20:  # Stop if we have downloaded 20 images
                    break
                
                # Generate unique file name for each image
                image_filename = f"{cat.replace(' ', '_')}_{downloaded_images + 1}.jpg"
                image_path = os.path.join(color_folder, image_filename)

                # Attempt to download and save the image
                saved_image = download_image(image_url, image_path)

                if saved_image:
                    print(f"Image saved: {saved_image}")

                    # Analyze image with Vision API and get labels
                    labels = analyze_image(image_url)
                    print(f"Labels for {image_filename}: {', '.join(labels)}")
                    
                    downloaded_images += 1
        else:
            print(f"No images found for {cat}")

# Google API credentials (Replace these with your actual credentials)
API_KEY = "AIzaSyAo5M5HXAXSkVxBzHRG0bUMRJf3RltEhJw"  # Replace with your actual API key
CSE_ID = "d63ff1141028241de"  # Replace with your actual CSE ID

# Set Google Cloud credentials
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = r"C:/Users/TechAir\Desktop/USE_AS/jewelry-449211-b1561756ae8d.json"  

# Create the folder structure for Gem Color categories
create_folder_structure()

# Fetch and save images for each gem color
fetch_and_save_images(API_KEY, CSE_ID)
# Out:
# Fetching images for Wedding Band, Anniversary Band...
# Image saved: USE_As\Wedding Band, Anniversary Band\Wedding_Band,_Anniversary_Band_1.jpg
# Labels for Wedding_Band,_Anniversary_Band_1.jpg: body jewelry, gemstone, diamond, crystal, jewellery, engagement ring, natural material, wedding ceremony supply, ring, silver
# Image saved: USE_As\Wedding Band, Anniversary Band\Wedding_Band,_Anniversary_Band_2.jpg
# Labels for Wedding_Band,_Anniversary_Band_2.jpg: jewellery, ring, body jewelry, engagement ring, natural material, wedding ring, pre-engagement ring, gemstone, wedding ceremony supply, diamond
# Image saved: USE_As\Wedding Band, Anniversary Band\Wedding_Band,_Anniversary_Band_3.jpg
# Labels for Wedding_Band,_Anniversary_Band_3.jpg: jewellery, ring, body jewelry, engagement ring, nail, natural material, pre-engagement ring, wedding ceremony supply, wedding ring, gemstone
# Image saved: USE_As\Wedding Band, Anniversary Band\Wedding_Band,_Anniversary_Band_4.jpg
# Labels for Wedding_Band,_Anniversary_Band_4.jpg: natural material, pre-engagement ring, ring, wedding ceremony supply, body jewelry, wedding ring, engagement ring, diamond
# Image saved: USE_As\Wedding Band, Anniversary Band\Wedding_Band,_Anniversary_Band_5.jpg
# Labels for Wedding_Band,_Anniversary_Band_5.jpg: jewellery, ring, engagement ring, gemstone, body jewelry, fashion, crystal, wedding ring, diamond, wedding ceremony supply
# Image saved: USE_As\Wedding Band, Anniversary Band\Wedding_Band,_Anniversary_Band_6.jpg
# Labels for Wedding_Band,_Anniversary_Band_6.jpg: engagement ring, ring, wedding ring, gemstone, wedding ceremony supply, diamond, pre-engagement ring, silver, natural material, crystal
# Image saved: USE_As\Wedding Band, Anniversary Band\Wedding_Band,_Anniversary_Band_7.jpg
# Labels for Wedding_Band,_Anniversary_Band_7.jpg: jewellery, ring, fashion, finger, body jewelry, engagement ring, wedding ring, nail, pre-engagement ring, natural material
# Image saved: USE_As\Wedding Band, Anniversary Band\Wedding_Band,_Anniversary_Band_8.jpg
# Labels for Wedding_Band,_Anniversary_Band_8.jpg: engagement ring, diamond, ring, wedding ring, gemstone, jewellery, body jewelry, pre-engagement ring, natural material, metal
# Image saved: USE_As\Wedding Band, Anniversary Band\Wedding_Band,_Anniversary_Band_9.jpg
# Labels for Wedding_Band,_Anniversary_Band_9.jpg: diamond, gemstone, silver, engagement ring, platinum, pre-engagement ring, crystal, ring, body jewelry, wedding ring
# Image saved: USE_As\Wedding Band, Anniversary Band\Wedding_Band,_Anniversary_Band_10.jpg
# Labels for Wedding_Band,_Anniversary_Band_10.jpg: gemstone, platinum
# Fetching images for Eternity Band...
# Image saved: USE_As\Eternity Band\Eternity_Band_1.jpg
# Labels for Eternity_Band_1.jpg: engagement ring, natural material, diamond, silver, pre-engagement ring, wedding ring, platinum
# Image saved: USE_As\Eternity Band\Eternity_Band_2.jpg
# Labels for Eternity_Band_2.jpg: jewellery, ring, fashion, finger, body jewelry, engagement ring, wedding ring, nail, pre-engagement ring, natural material
# Image saved: USE_As\Eternity Band\Eternity_Band_3.jpg
# Labels for Eternity_Band_3.jpg: jewellery, ring, body jewelry, engagement ring, natural material, wedding ring, pre-engagement ring, gemstone, wedding ceremony supply, diamond
# Image saved: USE_As\Eternity Band\Eternity_Band_4.jpg
# Labels for Eternity_Band_4.jpg: jewellery, ring, engagement ring, gemstone, body jewelry, fashion, crystal, wedding ring, diamond, wedding ceremony supply
# Image saved: USE_As\Eternity Band\Eternity_Band_5.jpg
# Labels for Eternity_Band_5.jpg: jewellery, ring, engagement ring, gemstone, fashion, wedding ring, body jewelry, wedding ceremony supply, diamond, crystal
# Image saved: USE_As\Eternity Band\Eternity_Band_6.jpg
# Labels for Eternity_Band_6.jpg: jewellery, ring, body jewelry, engagement ring, nail, natural material, pre-engagement ring, gemstone, wedding ring, wedding ceremony supply
# Image saved: USE_As\Eternity Band\Eternity_Band_7.jpg
# Labels for Eternity_Band_7.jpg: jewellery, ring, body jewelry, engagement ring, gemstone, diamond, crystal, wedding ring, natural material, pre-engagement ring
# Image saved: USE_As\Eternity Band\Eternity_Band_8.jpg
# Labels for Eternity_Band_8.jpg: gemstone, ring, natural material, diamond, pre-engagement ring, wedding ceremony supply, engagement ring, body jewelry, wedding ring
# Image saved: USE_As\Eternity Band\Eternity_Band_9.jpg
# Labels for Eternity_Band_9.jpg: gemstone, diamond, natural material, emerald, crystal, ring, pre-engagement ring
# Image saved: USE_As\Eternity Band\Eternity_Band_10.jpg
# Labels for Eternity_Band_10.jpg: wedding ceremony supply, gemstone, diamond, engagement ring, natural material, ring, wedding ring, crystal, pre-engagement ring, body jewelry
# Fetching images for Promise Ring...
# Image saved: USE_As\Promise Ring\Promise_Ring_1.jpg
# Labels for Promise_Ring_1.jpg: body jewelry, gemstone, diamond, engagement ring, natural material, wedding ceremony supply, pre-engagement ring, crystal, ring, jewelry making
# Image saved: USE_As\Promise Ring\Promise_Ring_2.jpg
# Labels for Promise_Ring_2.jpg: engagement ring, diamond, ring, silver, pre-engagement ring, natural material, gemstone, wedding ring, body jewelry, platinum
# Image saved: USE_As\Promise Ring\Promise_Ring_3.jpg
# Labels for Promise_Ring_3.jpg: ring, engagement ring, fashion, jewellery, wedding ring, body jewelry, wedding ceremony supply, diamond, gemstone, pre-engagement ring
# Image saved: USE_As\Promise Ring\Promise_Ring_4.jpg
# Labels for Promise_Ring_4.jpg: body jewelry, diamond, gemstone, natural material, engagement ring, wedding ceremony supply, pre-engagement ring
# Image saved: USE_As\Promise Ring\Promise_Ring_5.jpg
# Labels for Promise_Ring_5.jpg: silver, engagement ring, ring, wedding ceremony supply, metal, natural material, platinum, diamond, pre-engagement ring, wedding ring
# Image saved: USE_As\Promise Ring\Promise_Ring_6.jpg
# Labels for Promise_Ring_6.jpg: diamond, metal, natural material, silver, pre-engagement ring, engagement ring, platinum, body jewelry, gemstone, wedding ring
# Image saved: USE_As\Promise Ring\Promise_Ring_7.jpg
# Labels for Promise_Ring_7.jpg: body jewelry, diamond, pre-engagement ring, silver, natural material, gemstone, engagement ring, wedding ceremony supply, ring, platinum
# Image saved: USE_As\Promise Ring\Promise_Ring_8.jpg
# Labels for Promise_Ring_8.jpg: engagement ring, ring, jewellery, petal, pink, diamond, wedding ceremony supply, pre-engagement ring, gemstone, body jewelry
# Image saved: USE_As\Promise Ring\Promise_Ring_9.jpg
# Labels for Promise_Ring_9.jpg: white, body jewelry, jewellery, gemstone, diamond, silver, ring, natural material, engagement ring, pre-engagement ring
# Image saved: USE_As\Promise Ring\Promise_Ring_10.jpg
# Labels for Promise_Ring_10.jpg: engagement ring, gemstone, jewellery, body jewelry, diamond, ring, wedding ceremony supply, wedding ring, pre-engagement ring, natural material
# Fetching images for Ring Enhancer...
# Image saved: USE_As\Ring Enhancer\Ring_Enhancer_1.jpg
# Labels for Ring_Enhancer_1.jpg: ring, body jewelry, gemstone, pre-engagement ring, natural material, silver, wedding ceremony supply, engagement ring, wedding ring, diamond
# Image saved: USE_As\Ring Enhancer\Ring_Enhancer_2.jpg
# Labels for Ring_Enhancer_2.jpg: platinum, pre-engagement ring, ring, silver
# Image saved: USE_As\Ring Enhancer\Ring_Enhancer_3.jpg
# Labels for Ring_Enhancer_3.jpg: gemstone, ring, body jewelry, pre-engagement ring, wedding ceremony supply, natural material, engagement ring, wedding ring, diamond, platinum
# Image saved: USE_As\Ring Enhancer\Ring_Enhancer_4.jpg
# Labels for Ring_Enhancer_4.jpg: jewellery, ring, engagement ring, body jewelry, gemstone, wedding ceremony supply, wedding ring, pre-engagement ring, diamond, natural material
# Image saved: USE_As\Ring Enhancer\Ring_Enhancer_5.jpg
# Labels for Ring_Enhancer_5.jpg: wedding ceremony supply, body jewelry, natural material, ring, pre-engagement ring, diamond, wedding ring, gemstone, engagement ring
# Failed to download image: https://www-image.charlesandcolvard.com/fit-in/600x600/filters:quality(80)/filters:format(webp)/media/catalog/product/R/0/R00233CRM0000WX---metal_type--14K_White_Gold---view--2l.jpg (Status Code: 403)
# Image saved: USE_As\Ring Enhancer\Ring_Enhancer_6.jpg
# Labels for Ring_Enhancer_6.jpg: engagement ring, jewellery, ring, fashion, wedding ring, gemstone, body jewelry, diamond, wedding ceremony supply, pre-engagement ring
# Image saved: USE_As\Ring Enhancer\Ring_Enhancer_7.jpg
# Labels for Ring_Enhancer_7.jpg: engagement ring, diamond, pre-engagement ring, natural material, wedding ceremony supply, platinum, silver, gemstone, wedding ring, ring
# Image saved: USE_As\Ring Enhancer\Ring_Enhancer_8.jpg
# Labels for Ring_Enhancer_8.jpg: natural material, engagement ring, gemstone, pre-engagement ring, diamond, ring
# Image saved: USE_As\Ring Enhancer\Ring_Enhancer_9.jpg
# Labels for Ring_Enhancer_9.jpg: engagement ring, gemstone, ring, body jewelry, diamond, wedding ring, pre-engagement ring, wedding ceremony supply, natural material, gold
