# %%
import os
import requests
from google.cloud import vision
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError
from PIL import Image
from io import BytesIO

# Ensure the image storage directory exists
IMAGE_DIR = "BODY_METEL"
os.makedirs(IMAGE_DIR, exist_ok=True)

# List of shink design for which we will fetch images
body_metal=[

 "14K White Gold",
"14K Rose Gold",
"14K Yellow Gold",
"18K White Gold",
"18K Rose Gold",
"18K Yellow Gold",
"Platinum",
"925 Sterling Silver",
"18K Gold Plated",
"Two Tone 14K White & Yellow Gold",
"Two Tone 14K White & Rose Gold"
 
   
 ]


def search_image(query, api_key, cse_id):
    """Search for images using Google Custom Search JSON API."""
    try:
        # Format query to avoid invalid characters
        formatted_query = query.replace(" ", "+").replace("-", "_").replace(".", "")  # Remove dots
        
        service = build("customsearch", "v1", developerKey=api_key)
        res = service.cse().list(
            q=formatted_query + "wedding+band+diamond",
            cx=cse_id,
            searchType="image",
            num=10 # Reduced to 10 as per Google API limits
        ).execute()

        if "items" in res:
            return [item["link"] for item in res["items"]]
        else:
            print(f"No images found for query: {query}")
    except HttpError as e:
        print(f"Google Search API Error: {e}")
    return []

def analyze_image(image_url):
    """Analyze image using Google Cloud Vision API."""
    try:
        client = vision.ImageAnnotatorClient()
        image = vision.Image()
        image.source.image_uri = image_url
        response = client.label_detection(image=image)
        labels = [label.description.lower() for label in response.label_annotations]
        return labels
    except Exception as e:
        print(f"Vision API Error: {e}")
        return []

def download_image(image_url, save_path):
    """Download and save an image if it's valid."""
    try:
        response = requests.get(image_url, timeout=10)
        if response.status_code == 200:
            img = Image.open(BytesIO(response.content))
            img.verify()  # Ensure it's a valid image
            img = Image.open(BytesIO(response.content))  # Reopen after verification
            img = img.convert("RGB")  # Convert to standard format
            img.save(save_path, format="JPEG")  # Save as JPEG
            return save_path
        else:
            print(f"Failed to download image: {image_url} (Status Code: {response.status_code})")
    except Exception as e:
        print(f"Error downloading or verifying image: {e} - URL: {image_url}")
    return None

def create_folder_structure():
    """Create subfolders for each gem color."""
    for cat in body_metal:
        folder_path = os.path.join(IMAGE_DIR, cat)
        os.makedirs(folder_path, exist_ok=True)

def fetch_and_save_images(api_key, cse_id):
    """Fetch and save images for each gem color, using Google Custom Search and Vision API."""
    for cat in body_metal:
        print(f"Fetching images for {cat}...")

        # Create subfolder for the current gem color
        color_folder = os.path.join(IMAGE_DIR, cat)
        
        # Search for images related to the gem color
        image_urls = search_image(cat, api_key, cse_id)

        if image_urls:
            downloaded_images = 0  # Track successfully downloaded images

            for image_url in image_urls:
                if downloaded_images >= 20:  # Stop if we have downloaded 20 images
                    break
                
                # Generate unique file name for each image
                image_filename = f"{cat.replace(' ', '_')}_{downloaded_images + 1}.jpg"
                image_path = os.path.join(color_folder, image_filename)

                # Attempt to download and save the image
                saved_image = download_image(image_url, image_path)

                if saved_image:
                    print(f"Image saved: {saved_image}")

                    # Analyze image with Vision API and get labels
                    labels = analyze_image(image_url)
                    print(f"Labels for {image_filename}: {', '.join(labels)}")
                    
                    downloaded_images += 1
        else:
            print(f"No images found for {cat}")

# Google API credentials (Replace these with your actual credentials)
API_KEY = "AIzaSyAo5M5HXAXSkVxBzHRG0bUMRJf3RltEhJw"  # Replace with your actual API key
CSE_ID = "d63ff1141028241de"  # Replace with your actual CSE ID

# Set Google Cloud credentials
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = r"C:/Users/TechAir\Desktop/BODY_METAL_BAND/jewelry-449211-b1561756ae8d.json"  

# Create the folder structure for Gem Color categories
create_folder_structure()

# Fetch and save images for each gem color
fetch_and_save_images(API_KEY, CSE_ID)
# Out:
# Fetching images for 14K White Gold...
# Image saved: BODY_METEL\14K White Gold\14K_White_Gold_1.jpg
# Labels for 14K_White_Gold_1.jpg: diamond, pre-engagement ring, natural material, silver, engagement ring, wedding ring, platinum, wedding ceremony supply, silver, gemstone
# Image saved: BODY_METEL\14K White Gold\14K_White_Gold_2.jpg
# Labels for 14K_White_Gold_2.jpg: jewellery, engagement ring, ring, body jewelry, wedding ring, diamond, gemstone, natural material, pre-engagement ring, silver
# Image saved: BODY_METEL\14K White Gold\14K_White_Gold_3.jpg
# Labels for 14K_White_Gold_3.jpg: blue, gemstone, natural material, crystal, pre-engagement ring, diamond, body jewelry, ring, platinum, engagement ring
# Image saved: BODY_METEL\14K White Gold\14K_White_Gold_4.jpg
# Labels for 14K_White_Gold_4.jpg: jewellery, engagement ring, ring, body jewelry, gemstone, wedding ring, finger, wedding ceremony supply, pre-engagement ring, diamond
# Image saved: BODY_METEL\14K White Gold\14K_White_Gold_5.jpg
# Labels for 14K_White_Gold_5.jpg: gemstone, natural material, silver, ring, platinum, diamond, pre-engagement ring, wedding ceremony supply, body jewelry, mineral
# Failed to download image: https://www.reeds.com/media/catalog/product/cache/38c3c1b8e53ef11aa9803a5390245afc/1/c/1ctw_round_lab_grown_diamond_white_gold_wedding_band__men_s-1-20291449-hx2f012c57_1.jpg (Status Code: 403)
# Image saved: BODY_METEL\14K White Gold\14K_White_Gold_6.jpg
# Labels for 14K_White_Gold_6.jpg: blue, ring, gemstone, engagement ring, jewellery, body jewelry, wedding ring, pre-engagement ring, natural material, wedding ceremony supply
# Image saved: BODY_METEL\14K White Gold\14K_White_Gold_7.jpg
# Labels for 14K_White_Gold_7.jpg: white, engagement ring, gemstone, body jewelry, diamond, crystal, ring, jewellery, wedding ring, natural material
# Image saved: BODY_METEL\14K White Gold\14K_White_Gold_8.jpg
# Labels for 14K_White_Gold_8.jpg: jewellery, body jewelry, ring, engagement ring, pre-engagement ring, diamond, wedding ring, wedding ceremony supply, natural material, metal
# Image saved: BODY_METEL\14K White Gold\14K_White_Gold_9.jpg
# Labels for 14K_White_Gold_9.jpg: gemstone, body jewelry, diamond, engagement ring, crystal, silver, ring, natural material, pre-engagement ring, wedding ring
# Fetching images for 14K Rose Gold...
# Image saved: BODY_METEL\14K Rose Gold\14K_Rose_Gold_1.jpg
# Labels for 14K_Rose_Gold_1.jpg: ring, natural material, copper, wedding ceremony supply, body jewelry, wedding ring, pre-engagement ring
# Image saved: BODY_METEL\14K Rose Gold\14K_Rose_Gold_2.jpg
# Labels for 14K_Rose_Gold_2.jpg: engagement ring, natural material, gemstone, ring, pre-engagement ring, wedding ring, diamond, wedding ceremony supply, triangle, crystal
# Image saved: BODY_METEL\14K Rose Gold\14K_Rose_Gold_3.jpg
# Labels for 14K_Rose_Gold_3.jpg: pink, wedding ring, ring, engagement ring, pre-engagement ring, bangle, wedding ceremony supply, silver, natural material, diamond
# Image saved: BODY_METEL\14K Rose Gold\14K_Rose_Gold_4.jpg
# Labels for 14K_Rose_Gold_4.jpg: ring, engagement ring, wedding ring, wedding ceremony supply, pre-engagement ring, body jewelry, natural material, bangle, copper, diamond
# Image saved: BODY_METEL\14K Rose Gold\14K_Rose_Gold_5.jpg
# Labels for 14K_Rose_Gold_5.jpg: ring, jewellery, body jewelry, wedding ceremony supply, gemstone, pre-engagement ring, wedding ring, engagement ring, natural material, silver
# Image saved: BODY_METEL\14K Rose Gold\14K_Rose_Gold_6.jpg
# Labels for 14K_Rose_Gold_6.jpg: natural material, body jewelry, gemstone, diamond, platinum, pre-engagement ring, ring, wedding ring, wedding ceremony supply
# Image saved: BODY_METEL\14K Rose Gold\14K_Rose_Gold_7.jpg
# Labels for 14K_Rose_Gold_7.jpg: natural material, pre-engagement ring, ring
# Image saved: BODY_METEL\14K Rose Gold\14K_Rose_Gold_8.jpg
# Labels for 14K_Rose_Gold_8.jpg: engagement ring, body jewelry, gemstone, jewellery, pre-engagement ring, ring, wedding ring, heart, natural material, wedding ceremony supply
# Image saved: BODY_METEL\14K Rose Gold\14K_Rose_Gold_9.jpg
# Labels for 14K_Rose_Gold_9.jpg: engagement ring, jewellery, ring, wedding ring, natural material, pre-engagement ring, body jewelry, diamond, wedding ceremony supply, gemstone
# Image saved: BODY_METEL\14K Rose Gold\14K_Rose_Gold_10.jpg
# Labels for 14K_Rose_Gold_10.jpg: engagement ring, jewellery, body jewelry, gemstone, ring, brown, diamond, pre-engagement ring, wedding ring, natural material
# Fetching images for 14K Yellow Gold...
# Image saved: BODY_METEL\14K Yellow Gold\14K_Yellow_Gold_1.jpg
# Labels for 14K_Yellow_Gold_1.jpg: natural material, bangle, wedding ceremony supply
# Image saved: BODY_METEL\14K Yellow Gold\14K_Yellow_Gold_2.jpg
# Labels for 14K_Yellow_Gold_2.jpg: jewellery, engagement ring, body jewelry, ring, wedding ring, pre-engagement ring, natural material, diamond, gemstone, gold
# Image saved: BODY_METEL\14K Yellow Gold\14K_Yellow_Gold_3.jpg
# Labels for 14K_Yellow_Gold_3.jpg: engagement ring, gemstone, pre-engagement ring, diamond, body jewelry, wedding ring, ring, wedding ceremony supply
# Image saved: BODY_METEL\14K Yellow Gold\14K_Yellow_Gold_4.jpg
# Labels for 14K_Yellow_Gold_4.jpg: engagement ring, jewellery, ring, body jewelry, gemstone, diamond, wedding ring, wedding ceremony supply, pre-engagement ring, metal
# Image saved: BODY_METEL\14K Yellow Gold\14K_Yellow_Gold_5.jpg
# Labels for 14K_Yellow_Gold_5.jpg: jewellery, ring, natural material, pre-engagement ring, body jewelry, engagement ring, wedding ring
# Image saved: BODY_METEL\14K Yellow Gold\14K_Yellow_Gold_6.jpg
# Labels for 14K_Yellow_Gold_6.jpg: jewellery, engagement ring, ring, body jewelry, wedding ring, gemstone, diamond, wedding ceremony supply, pre-engagement ring, metal
# Image saved: BODY_METEL\14K Yellow Gold\14K_Yellow_Gold_7.jpg
# Labels for 14K_Yellow_Gold_7.jpg: diamond, wedding ceremony supply, gemstone, pre-engagement ring, ring, engagement ring, wedding ring, body jewelry
# Image saved: BODY_METEL\14K Yellow Gold\14K_Yellow_Gold_8.jpg
# Labels for 14K_Yellow_Gold_8.jpg: engagement ring, ring, gemstone, brown, wedding ring, pre-engagement ring, diamond, body jewelry, natural material, metal
# Image saved: BODY_METEL\14K Yellow Gold\14K_Yellow_Gold_9.jpg
# Labels for 14K_Yellow_Gold_9.jpg: wedding ring, metal, natural material, ring, silver, pre-engagement ring, engagement ring, gold, bangle, wedding ceremony supply
# Image saved: BODY_METEL\14K Yellow Gold\14K_Yellow_Gold_10.jpg
# Labels for 14K_Yellow_Gold_10.jpg: pre-engagement ring, natural material, engagement ring, wedding ring, gemstone, ring, wedding ceremony supply
# Fetching images for 18K White Gold...
# Image saved: BODY_METEL\18K White Gold\18K_White_Gold_1.jpg
# Labels for 18K_White_Gold_1.jpg: body jewelry, gemstone, ring, wedding ceremony supply, jewellery, diamond, natural material, silver, pre-engagement ring, engagement ring
# Image saved: BODY_METEL\18K White Gold\18K_White_Gold_2.jpg
# Labels for 18K_White_Gold_2.jpg: body jewelry, ring, natural material, pre-engagement ring, engagement ring
# Image saved: BODY_METEL\18K White Gold\18K_White_Gold_3.jpg
# Labels for 18K_White_Gold_3.jpg: silver, watch, metal, natural material, titanium, platinum, analog watch, silver, nickel, titanium ring
# Image saved: BODY_METEL\18K White Gold\18K_White_Gold_4.jpg
# Labels for 18K_White_Gold_4.jpg: ring, pre-engagement ring, engagement ring, natural material, silver, wedding ring, body jewelry, diamond, wedding ceremony supply, platinum
# Image saved: BODY_METEL\18K White Gold\18K_White_Gold_5.jpg
# Labels for 18K_White_Gold_5.jpg: gemstone, engagement ring, diamond, body jewelry, wedding ring, ring, pre-engagement ring, crystal, jewellery, silver
# Image saved: BODY_METEL\18K White Gold\18K_White_Gold_6.jpg
# Labels for 18K_White_Gold_6.jpg: silver, metal, jewellery, ring, natural material, nickel, titanium, platinum, body jewelry, wedding ring
# Image saved: BODY_METEL\18K White Gold\18K_White_Gold_7.jpg
# Labels for 18K_White_Gold_7.jpg: jewellery, ring, engagement ring, wedding ring, pre-engagement ring, metal, natural material, diamond, silver, body jewelry
# Image saved: BODY_METEL\18K White Gold\18K_White_Gold_8.jpg
# Labels for 18K_White_Gold_8.jpg: ring, bangle, engagement ring, pre-engagement ring, body jewelry, wedding ring, natural material, wedding ceremony supply, silver, platinum
# Image saved: BODY_METEL\18K White Gold\18K_White_Gold_9.jpg
# Labels for 18K_White_Gold_9.jpg: ring, jewellery, engagement ring, wedding ring, wedding ceremony supply, diamond, pre-engagement ring, bangle, body jewelry, bracelet
# Image saved: BODY_METEL\18K White Gold\18K_White_Gold_10.jpg
# Labels for 18K_White_Gold_10.jpg: red, gemstone, engagement ring, jewellery, pink, ring, ruby, diamond, body jewelry, wedding ceremony supply
# Fetching images for 18K Rose Gold...
# Image saved: BODY_METEL\18K Rose Gold\18K_Rose_Gold_1.jpg
# Labels for 18K_Rose_Gold_1.jpg: engagement ring, jewellery, ring, body jewelry, gemstone, wedding ring, pre-engagement ring, diamond, natural material, wedding ceremony supply
# Image saved: BODY_METEL\18K Rose Gold\18K_Rose_Gold_2.jpg
# Labels for 18K_Rose_Gold_2.jpg: wedding ring, ring, natural material, pre-engagement ring, engagement ring
# Image saved: BODY_METEL\18K Rose Gold\18K_Rose_Gold_3.jpg
# Labels for 18K_Rose_Gold_3.jpg: ring, body jewelry, engagement ring, jewellery, pre-engagement ring, wedding ring, natural material, gemstone, diamond, wedding ceremony supply
# Image saved: BODY_METEL\18K Rose Gold\18K_Rose_Gold_4.jpg
# Labels for 18K_Rose_Gold_4.jpg: ring, jewellery, engagement ring, fashion, body jewelry, wedding ring, wedding ceremony supply, pre-engagement ring, bangle, metal
# Image saved: BODY_METEL\18K Rose Gold\18K_Rose_Gold_5.jpg
# Labels for 18K_Rose_Gold_5.jpg: brown, natural material
# Image saved: BODY_METEL\18K Rose Gold\18K_Rose_Gold_6.jpg
# Labels for 18K_Rose_Gold_6.jpg: silver, watch, metal, natural material, titanium, platinum, analog watch, silver, nickel, titanium ring
# Image saved: BODY_METEL\18K Rose Gold\18K_Rose_Gold_7.jpg
# Labels for 18K_Rose_Gold_7.jpg: ring, engagement ring, body jewelry, jewellery, gemstone, wedding ring, pre-engagement ring, natural material, wedding ceremony supply, silver
# Image saved: BODY_METEL\18K Rose Gold\18K_Rose_Gold_8.jpg
# Labels for 18K_Rose_Gold_8.jpg: wedding ceremony supply, diamond, gemstone, body jewelry, engagement ring, pre-engagement ring, ring
# Image saved: BODY_METEL\18K Rose Gold\18K_Rose_Gold_9.jpg
# Labels for 18K_Rose_Gold_9.jpg: jewellery, ring, engagement ring, body jewelry, wedding ring, pre-engagement ring, natural material, metal, diamond, gemstone
# Error downloading or verifying image: HTTPSConnectionPool(host='magento.verragio.com', port=443): Max retries exceeded with url: /media/catalog/product/s/t/style-image-rose-2210-1708553110-196-ENG-0490W-2_5-(W)-Rose-Pics-S_00000.jpg (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1147)'))) - URL: https://magento.verragio.com/media/catalog/product/s/t/style-image-rose-2210-1708553110-196-ENG-0490W-2_5-(W)-Rose-Pics-S_00000.jpg
# Fetching images for 18K Yellow Gold...
# Image saved: BODY_METEL\18K Yellow Gold\18K_Yellow_Gold_1.jpg
# Labels for 18K_Yellow_Gold_1.jpg: bangle, ring, natural material, wedding ceremony supply, gold, body jewelry, wedding ring, glitter
# Image saved: BODY_METEL\18K Yellow Gold\18K_Yellow_Gold_2.jpg
# Labels for 18K_Yellow_Gold_2.jpg: wedding ring, metal, natural material, ring, silver, pre-engagement ring, engagement ring, gold, bangle, wedding ceremony supply
# Image saved: BODY_METEL\18K Yellow Gold\18K_Yellow_Gold_3.jpg
# Labels for 18K_Yellow_Gold_3.jpg: jewellery, engagement ring, body jewelry, ring, wedding ring, pre-engagement ring, natural material, diamond, gemstone, gold
# Image saved: BODY_METEL\18K Yellow Gold\18K_Yellow_Gold_4.jpg
# Labels for 18K_Yellow_Gold_4.jpg: ring, wedding ring, bangle, pre-engagement ring, engagement ring, wedding ceremony supply, metal, gold, natural material, brass
# Image saved: BODY_METEL\18K Yellow Gold\18K_Yellow_Gold_5.jpg
# Labels for 18K_Yellow_Gold_5.jpg: blue, gemstone, sapphire, natural material, diamond, engagement ring, pre-engagement ring, wedding ceremony supply, gold, crystal
# Image saved: BODY_METEL\18K Yellow Gold\18K_Yellow_Gold_6.jpg
# Labels for 18K_Yellow_Gold_6.jpg: ring, wedding ring, engagement ring, diamond, natural material, pre-engagement ring, gold, wedding ceremony supply, silver, gemstone
# Image saved: BODY_METEL\18K Yellow Gold\18K_Yellow_Gold_7.jpg
# Labels for 18K_Yellow_Gold_7.jpg: ring, wedding ring, pre-engagement ring, engagement ring, metal, titanium ring, natural material, wedding ceremony supply, titanium, silver
# Image saved: BODY_METEL\18K Yellow Gold\18K_Yellow_Gold_8.jpg
# Labels for 18K_Yellow_Gold_8.jpg: body jewelry, gemstone, ring, wedding ceremony supply, jewellery, diamond, natural material, silver, pre-engagement ring, engagement ring
# Image saved: BODY_METEL\18K Yellow Gold\18K_Yellow_Gold_9.jpg
# Labels for 18K_Yellow_Gold_9.jpg: bangle, ring, natural material, gold, silver, wedding ring, body jewelry, wedding ceremony supply, brass, pre-engagement ring
# Image saved: BODY_METEL\18K Yellow Gold\18K_Yellow_Gold_10.jpg
# Labels for 18K_Yellow_Gold_10.jpg: natural material, pre-engagement ring, diamond
# Fetching images for Platinum...
# Image saved: BODY_METEL\Platinum\Platinum_1.jpg
# Labels for Platinum_1.jpg: ring, body jewelry, engagement ring, jewellery, wedding ring, pre-engagement ring, gemstone, natural material, wedding ceremony supply, diamond
# Image saved: BODY_METEL\Platinum\Platinum_2.jpg
# Labels for Platinum_2.jpg: white, metal, diamond, natural material, silver, mineral, pre-engagement ring, platinum, titanium, watch
# Image saved: BODY_METEL\Platinum\Platinum_3.jpg
# Labels for Platinum_3.jpg: jewellery, ring, engagement ring, wedding ceremony supply, wedding ring, pre-engagement ring, diamond, natural material, body jewelry, platinum
# Image saved: BODY_METEL\Platinum\Platinum_4.jpg
# Labels for Platinum_4.jpg: jewellery, ring, body jewelry, wedding ring, bracelet, engagement ring, wedding ceremony supply, pre-engagement ring, titanium ring, bangle
# Image saved: BODY_METEL\Platinum\Platinum_5.jpg
# Labels for Platinum_5.jpg: ring, jewellery, wedding ceremony supply, pre-engagement ring, wedding ring, natural material, silver, engagement ring, titanium ring, titanium
# Image saved: BODY_METEL\Platinum\Platinum_6.jpg
# Labels for Platinum_6.jpg: silver, natural material, metal, ring, pre-engagement ring, platinum, titanium, titanium ring, body jewelry, silver
# Image saved: BODY_METEL\Platinum\Platinum_7.jpg
# Labels for Platinum_7.jpg: jewellery, ring, engagement ring, wedding ring, body jewelry, pre-engagement ring, wedding ceremony supply, diamond, metal, titanium ring
# c:\Users\TechAir\anaconda3\envs\webscrapping\lib\site-packages\PIL\Image.py:1045: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Image saved: BODY_METEL\Platinum\Platinum_8.jpg
# Labels for Platinum_8.jpg: ring, wedding ceremony supply, wedding ring, jewellery, engagement ring, pre-engagement ring, body jewelry, bangle, titanium ring, silver
# Image saved: BODY_METEL\Platinum\Platinum_9.jpg
# Labels for Platinum_9.jpg: engagement ring, ring, jewellery, wedding ring, wedding ceremony supply, diamond, pre-engagement ring, bangle, titanium ring, body jewelry
# Image saved: BODY_METEL\Platinum\Platinum_10.jpg
# Labels for Platinum_10.jpg: silver, natural material, titanium ring, pre-engagement ring, wedding ring, titanium, ring, silver
# Fetching images for 925 Sterling Silver...
# Image saved: BODY_METEL\925 Sterling Silver\925_Sterling_Silver_1.jpg
# Labels for 925_Sterling_Silver_1.jpg: engagement ring, ring, wedding ring, pre-engagement ring, jewellery, body jewelry, titanium ring, diamond, natural material, platinum
# Image saved: BODY_METEL\925 Sterling Silver\925_Sterling_Silver_2.jpg
# Labels for 925_Sterling_Silver_2.jpg: engagement ring, gemstone, diamond, ring, crystal, body jewelry, jewellery, wedding ring, pre-engagement ring, natural material
# Image saved: BODY_METEL\925 Sterling Silver\925_Sterling_Silver_3.jpg
# Labels for 925_Sterling_Silver_3.jpg: engagement ring, diamond, body jewelry, silver, natural material, gemstone, pre-engagement ring, platinum, wedding ring, ring
# Image saved: BODY_METEL\925 Sterling Silver\925_Sterling_Silver_4.jpg
# Labels for 925_Sterling_Silver_4.jpg: diamond, natural material, gemstone, silver, crystal, mineral
# Image saved: BODY_METEL\925 Sterling Silver\925_Sterling_Silver_5.jpg
# Labels for 925_Sterling_Silver_5.jpg: engagement ring, diamond, gemstone, jewellery, pre-engagement ring, body jewelry, wedding ring, silver, natural material, platinum
# Image saved: BODY_METEL\925 Sterling Silver\925_Sterling_Silver_6.jpg
# Labels for 925_Sterling_Silver_6.jpg: engagement ring, heart, ring, gemstone, wedding ring, body jewelry, jewellery, pre-engagement ring, diamond, wedding ceremony supply
# Image saved: BODY_METEL\925 Sterling Silver\925_Sterling_Silver_7.jpg
# Labels for 925_Sterling_Silver_7.jpg: engagement ring, ring, wedding ring, pre-engagement ring, diamond, silver, metal, body jewelry, natural material, titanium ring
# Image saved: BODY_METEL\925 Sterling Silver\925_Sterling_Silver_8.jpg
# Labels for 925_Sterling_Silver_8.jpg: engagement ring, jewellery, ring, body jewelry, gemstone, diamond, wedding ring, natural material, pre-engagement ring, silver
# Image saved: BODY_METEL\925 Sterling Silver\925_Sterling_Silver_9.jpg
# Labels for 925_Sterling_Silver_9.jpg: blue, diamond, gemstone, natural material, engagement ring, pre-engagement ring, mineral, sapphire, crystal, platinum
# Image saved: BODY_METEL\925 Sterling Silver\925_Sterling_Silver_10.jpg
# Labels for 925_Sterling_Silver_10.jpg: engagement ring, ring, jewellery, wedding ring, diamond, pre-engagement ring, platinum, body jewelry, silver, wedding ceremony supply
# Fetching images for 18K Gold Plated...
# Image saved: BODY_METEL\18K Gold Plated\18K_Gold_Plated_1.jpg
# Labels for 18K_Gold_Plated_1.jpg: white, engagement ring, diamond, pre-engagement ring, gemstone, wedding ring, gold, natural material, ring, crystal
# Image saved: BODY_METEL\18K Gold Plated\18K_Gold_Plated_2.jpg
# Labels for 18K_Gold_Plated_2.jpg: engagement ring, silver, diamond, natural material, gemstone, pre-engagement ring, ring, wedding ceremony supply, wedding ring, platinum
# Image saved: BODY_METEL\18K Gold Plated\18K_Gold_Plated_3.jpg
# Labels for 18K_Gold_Plated_3.jpg: watch, fashion, engagement ring, diamond, gemstone, mineral, crystal, natural material, silver, platinum
# Image saved: BODY_METEL\18K Gold Plated\18K_Gold_Plated_4.jpg
# Labels for 18K_Gold_Plated_4.jpg: engagement ring, ring, white, jewellery, wedding ceremony supply, gemstone, wedding ring, body jewelry, diamond, pre-engagement ring
# Image saved: BODY_METEL\18K Gold Plated\18K_Gold_Plated_5.jpg
# Labels for 18K_Gold_Plated_5.jpg: ring, jewellery, wedding ring, engagement ring, wedding ceremony supply, body jewelry, diamond, pre-engagement ring, metal, gemstone
# Image saved: BODY_METEL\18K Gold Plated\18K_Gold_Plated_6.jpg
# Labels for 18K_Gold_Plated_6.jpg: jewellery, body jewelry, gemstone, engagement ring, diamond, ring, natural material, pre-engagement ring, crystal, platinum
# Image saved: BODY_METEL\18K Gold Plated\18K_Gold_Plated_7.jpg
# Labels for 18K_Gold_Plated_7.jpg: engagement ring, white, watch, ring, diamond, wedding ring, mineral, gemstone, pre-engagement ring, jewellery
# Image saved: BODY_METEL\18K Gold Plated\18K_Gold_Plated_8.jpg
# Labels for 18K_Gold_Plated_8.jpg: jewellery, ring, metal, pre-engagement ring, wedding ring, natural material, wedding ceremony supply, body jewelry, gold, engagement ring
# Image saved: BODY_METEL\18K Gold Plated\18K_Gold_Plated_9.jpg
# Labels for 18K_Gold_Plated_9.jpg: yellow, engagement ring, diamond, pre-engagement ring, wedding ring, gemstone, natural material, gold, ring, wedding ceremony supply
# Image saved: BODY_METEL\18K Gold Plated\18K_Gold_Plated_10.jpg
# Labels for 18K_Gold_Plated_10.jpg: jewellery, engagement ring, gemstone, ring, fashion, body jewelry, nail care, nail polish, crystal, finger
# Fetching images for Two Tone 14K White & Yellow Gold...
# Image saved: BODY_METEL\Two Tone 14K White & Yellow Gold\Two_Tone_14K_White_&_Yellow_Gold_1.jpg
# Labels for Two_Tone_14K_White_&_Yellow_Gold_1.jpg: ring, pre-engagement ring, wedding ring, natural material, body jewelry, wedding ceremony supply, bangle, engagement ring, gold, gemstone
# Image saved: BODY_METEL\Two Tone 14K White & Yellow Gold\Two_Tone_14K_White_&_Yellow_Gold_2.jpg
# Labels for Two_Tone_14K_White_&_Yellow_Gold_2.jpg: metal, natural material, silver, pre-engagement ring, gold, ring, wedding ring, silver, wedding ceremony supply, titanium
# Image saved: BODY_METEL\Two Tone 14K White & Yellow Gold\Two_Tone_14K_White_&_Yellow_Gold_3.jpg
# Labels for Two_Tone_14K_White_&_Yellow_Gold_3.jpg: wedding ring, silver, pre-engagement ring, ring, titanium ring, wedding ceremony supply
# Image saved: BODY_METEL\Two Tone 14K White & Yellow Gold\Two_Tone_14K_White_&_Yellow_Gold_4.jpg
# Labels for Two_Tone_14K_White_&_Yellow_Gold_4.jpg: metal, natural material, silver, pre-engagement ring, silver, titanium, nickel, titanium ring, platinum, wedding ring
# Image saved: BODY_METEL\Two Tone 14K White & Yellow Gold\Two_Tone_14K_White_&_Yellow_Gold_5.jpg
# Labels for Two_Tone_14K_White_&_Yellow_Gold_5.jpg: ring, jewellery, body jewelry, engagement ring, wedding ring, wedding ceremony supply, bangle, metal, pre-engagement ring, natural material
# Image saved: BODY_METEL\Two Tone 14K White & Yellow Gold\Two_Tone_14K_White_&_Yellow_Gold_6.jpg
# Labels for Two_Tone_14K_White_&_Yellow_Gold_6.jpg: natural material, ring, pre-engagement ring, titanium ring, wedding ring
# Image saved: BODY_METEL\Two Tone 14K White & Yellow Gold\Two_Tone_14K_White_&_Yellow_Gold_7.jpg
# Labels for Two_Tone_14K_White_&_Yellow_Gold_7.jpg: silver, metal, natural material, ring, diamond, pre-engagement ring, wedding ring, bangle, silver, titanium
# Image saved: BODY_METEL\Two Tone 14K White & Yellow Gold\Two_Tone_14K_White_&_Yellow_Gold_8.jpg
# Labels for Two_Tone_14K_White_&_Yellow_Gold_8.jpg: engagement ring, wedding ring, wedding ceremony supply, pre-engagement ring, ring, natural material, diamond, body jewelry, bangle, gold
# Image saved: BODY_METEL\Two Tone 14K White & Yellow Gold\Two_Tone_14K_White_&_Yellow_Gold_9.jpg
# Labels for Two_Tone_14K_White_&_Yellow_Gold_9.jpg: natural material, staple food, pre-engagement ring
# Image saved: BODY_METEL\Two Tone 14K White & Yellow Gold\Two_Tone_14K_White_&_Yellow_Gold_10.jpg
# Labels for Two_Tone_14K_White_&_Yellow_Gold_10.jpg: natural material, silver, pre-engagement ring, ring, wedding ring, diamond, engagement ring, silver
# Fetching images for Two Tone 14K White & Rose Gold...
# Image saved: BODY_METEL\Two Tone 14K White & Rose Gold\Two_Tone_14K_White_&_Rose_Gold_1.jpg
# Labels for Two_Tone_14K_White_&_Rose_Gold_1.jpg: ring, engagement ring, wedding ring, pre-engagement ring, natural material, metal, wedding ceremony supply, platinum, diamond, body jewelry
# Image saved: BODY_METEL\Two Tone 14K White & Rose Gold\Two_Tone_14K_White_&_Rose_Gold_2.jpg
# Labels for Two_Tone_14K_White_&_Rose_Gold_2.jpg: natural material, copper, wedding ring, pre-engagement ring, ring, engagement ring, diamond
# Image saved: BODY_METEL\Two Tone 14K White & Rose Gold\Two_Tone_14K_White_&_Rose_Gold_3.jpg
# Labels for Two_Tone_14K_White_&_Rose_Gold_3.jpg: ring, engagement ring, wedding ring, wedding ceremony supply, brown, pre-engagement ring, natural material, metal, diamond, silver
# Image saved: BODY_METEL\Two Tone 14K White & Rose Gold\Two_Tone_14K_White_&_Rose_Gold_4.jpg
# Labels for Two_Tone_14K_White_&_Rose_Gold_4.jpg: engagement ring, ring, jewellery, body jewelry, wedding ring, pre-engagement ring, gemstone, diamond, natural material, wedding ceremony supply
# Image saved: BODY_METEL\Two Tone 14K White & Rose Gold\Two_Tone_14K_White_&_Rose_Gold_5.jpg
# Labels for Two_Tone_14K_White_&_Rose_Gold_5.jpg: copper
# Image saved: BODY_METEL\Two Tone 14K White & Rose Gold\Two_Tone_14K_White_&_Rose_Gold_6.jpg
# Labels for Two_Tone_14K_White_&_Rose_Gold_6.jpg: pre-engagement ring, natural material, engagement ring, wedding ceremony supply, ring, wedding ring, body jewelry, mineral, gemstone
# Image saved: BODY_METEL\Two Tone 14K White & Rose Gold\Two_Tone_14K_White_&_Rose_Gold_7.jpg
# Labels for Two_Tone_14K_White_&_Rose_Gold_7.jpg: natural material, pre-engagement ring, wedding ring, platinum, ring, titanium ring
# Image saved: BODY_METEL\Two Tone 14K White & Rose Gold\Two_Tone_14K_White_&_Rose_Gold_8.jpg
# Labels for Two_Tone_14K_White_&_Rose_Gold_8.jpg: natural material
# Image saved: BODY_METEL\Two Tone 14K White & Rose Gold\Two_Tone_14K_White_&_Rose_Gold_9.jpg
# Labels for Two_Tone_14K_White_&_Rose_Gold_9.jpg: ring, jewellery, engagement ring, metal, natural material, diamond, wedding ceremony supply, copper, pre-engagement ring, body jewelry
# Image saved: BODY_METEL\Two Tone 14K White & Rose Gold\Two_Tone_14K_White_&_Rose_Gold_10.jpg
# Labels for Two_Tone_14K_White_&_Rose_Gold_10.jpg: gemstone, natural material, body jewelry, pre-engagement ring
