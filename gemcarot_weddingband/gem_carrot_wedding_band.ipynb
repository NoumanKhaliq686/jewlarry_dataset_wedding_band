# %%
import os
import requests
from google.cloud import vision
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError
from PIL import Image
from io import BytesIO

# Ensure the image storage directory exists
IMAGE_DIR = "gem_carot_wedding_band"
os.makedirs(IMAGE_DIR, exist_ok=True)

# List of shink design for which we will fetch images
gem_carrot=[
  "0.5 Carat",
"1 Carat",
"2 Carat",
"2.5 Carat",
"3 Carat",
"4 Carat",
"5 Carat",
"3.8 carat TW or 0.5 Carat x 7, 0.025 x 32 pcs, 0.05 x 50pcs",
"Totlall Approx 0.25 Carat",
"Totlall Approx 0.5 Carat",
"Totlall Approx 0.75 Carat",
"Totlall Approx 1 Carat",
"Totlall Approx 2 Carat",
"Totlall Approx 3 Carat"
 
 ]


def search_image(query, api_key, cse_id):
    """Search for images using Google Custom Search JSON API."""
    try:
        # Format query to avoid invalid characters
        formatted_query = query.replace(" ", "+").replace("-", "_").replace(".", "")  # Remove dots
        
        service = build("customsearch", "v1", developerKey=api_key)
        res = service.cse().list(
            q=formatted_query + "wedding+band+diamond",
            cx=cse_id,
            searchType="image",
            num=10 # Reduced to 10 as per Google API limits
        ).execute()

        if "items" in res:
            return [item["link"] for item in res["items"]]
        else:
            print(f"No images found for query: {query}")
    except HttpError as e:
        print(f"Google Search API Error: {e}")
    return []

def analyze_image(image_url):
    """Analyze image using Google Cloud Vision API."""
    try:
        client = vision.ImageAnnotatorClient()
        image = vision.Image()
        image.source.image_uri = image_url
        response = client.label_detection(image=image)
        labels = [label.description.lower() for label in response.label_annotations]
        return labels
    except Exception as e:
        print(f"Vision API Error: {e}")
        return []

def download_image(image_url, save_path):
    """Download and save an image if it's valid."""
    try:
        response = requests.get(image_url, timeout=10)
        if response.status_code == 200:
            img = Image.open(BytesIO(response.content))
            img.verify()  # Ensure it's a valid image
            img = Image.open(BytesIO(response.content))  # Reopen after verification
            img = img.convert("RGB")  # Convert to standard format
            img.save(save_path, format="JPEG")  # Save as JPEG
            return save_path
        else:
            print(f"Failed to download image: {image_url} (Status Code: {response.status_code})")
    except Exception as e:
        print(f"Error downloading or verifying image: {e} - URL: {image_url}")
    return None

def create_folder_structure():
    """Create subfolders for each gem color."""
    for cat in gem_carrot:
        folder_path = os.path.join(IMAGE_DIR, cat)
        os.makedirs(folder_path, exist_ok=True)

def fetch_and_save_images(api_key, cse_id):
    """Fetch and save images for each gem color, using Google Custom Search and Vision API."""
    for cat in gem_carrot:
        print(f"Fetching images for {cat}...")

        # Create subfolder for the current gem color
        color_folder = os.path.join(IMAGE_DIR, cat)
        
        # Search for images related to the gem color
        image_urls = search_image(cat, api_key, cse_id)

        if image_urls:
            downloaded_images = 0  # Track successfully downloaded images

            for image_url in image_urls:
                if downloaded_images >= 20:  # Stop if we have downloaded 20 images
                    break
                
                # Generate unique file name for each image
                image_filename = f"{cat.replace(' ', '_')}_{downloaded_images + 1}.jpg"
                image_path = os.path.join(color_folder, image_filename)

                # Attempt to download and save the image
                saved_image = download_image(image_url, image_path)

                if saved_image:
                    print(f"Image saved: {saved_image}")

                    # Analyze image with Vision API and get labels
                    labels = analyze_image(image_url)
                    print(f"Labels for {image_filename}: {', '.join(labels)}")
                    
                    downloaded_images += 1
        else:
            print(f"No images found for {cat}")

# Google API credentials (Replace these with your actual credentials)
API_KEY = "AIzaSyAo5M5HXAXSkVxBzHRG0bUMRJf3RltEhJw"  # Replace with your actual API key
CSE_ID = "d63ff1141028241de"  # Replace with your actual CSE ID

# Set Google Cloud credentials
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = r"C:/Users/TechAir\Desktop/GEMCAROT_WEDDINGBAND/jewelry-449211-b1561756ae8d.json"  

# Create the folder structure for Gem Color categories
create_folder_structure()

# Fetch and save images for each gem color
fetch_and_save_images(API_KEY, CSE_ID)
# Out:
# Fetching images for 0.5 Carat...
# Image saved: gem_carot_wedding_band\0.5 Carat\0.5_Carat_1.jpg
# Labels for 0.5_Carat_1.jpg: green, gemstone, natural material, ring, emerald
# Image saved: gem_carot_wedding_band\0.5 Carat\0.5_Carat_2.jpg
# Labels for 0.5_Carat_2.jpg: engagement ring, jewellery, white, ring, wedding ring, diamond, body jewelry, gemstone, pre-engagement ring, wedding ceremony supply
# Image saved: gem_carot_wedding_band\0.5 Carat\0.5_Carat_3.jpg
# Labels for 0.5_Carat_3.jpg: ring, wedding ceremony supply, pre-engagement ring, gemstone, body jewelry, wedding ring
# Image saved: gem_carot_wedding_band\0.5 Carat\0.5_Carat_4.jpg
# Labels for 0.5_Carat_4.jpg: engagement ring, jewellery, ring, fashion, gemstone, body jewelry, finger, wedding ring, wedding ceremony supply, diamond
# Image saved: gem_carot_wedding_band\0.5 Carat\0.5_Carat_5.jpg
# Labels for 0.5_Carat_5.jpg: engagement ring, ring, jewellery, wedding ring, diamond, body jewelry, gemstone, pre-engagement ring, wedding ceremony supply, silver
# Image saved: gem_carot_wedding_band\0.5 Carat\0.5_Carat_6.jpg
# Labels for 0.5_Carat_6.jpg: engagement ring, ring, finger, jewellery, body jewelry, wedding ring, gemstone, nail, pre-engagement ring, diamond
# Image saved: gem_carot_wedding_band\0.5 Carat\0.5_Carat_7.jpg
# Labels for 0.5_Carat_7.jpg: gemstone, jewellery, ring, body jewelry, natural material, pre-engagement ring, jewelry making
# Image saved: gem_carot_wedding_band\0.5 Carat\0.5_Carat_8.jpg
# Labels for 0.5_Carat_8.jpg: jewellery, ring, body jewelry, finger, engagement ring, natural material, wedding ring, bracelet, nail, pre-engagement ring
# Image saved: gem_carot_wedding_band\0.5 Carat\0.5_Carat_9.jpg
# Labels for 0.5_Carat_9.jpg: ring, jewellery, body jewelry, gemstone, bangle, wedding ceremony supply, sapphire, pre-engagement ring, engagement ring, bracelet
# Image saved: gem_carot_wedding_band\0.5 Carat\0.5_Carat_10.jpg
# Labels for 0.5_Carat_10.jpg: fashion, engagement ring, diamond, silver, gemstone, natural material, ring, wedding ring, pre-engagement ring, mineral
# Fetching images for 1 Carat...
# Image saved: gem_carot_wedding_band\1 Carat\1_Carat_1.jpg
# Labels for 1_Carat_1.jpg: jewellery, ring, fashion, engagement ring, body jewelry, wedding ring, wedding ceremony supply, pre-engagement ring, natural material, diamond
# Image saved: gem_carot_wedding_band\1 Carat\1_Carat_2.jpg
# Labels for 1_Carat_2.jpg: engagement ring, white, ring, body jewelry, gemstone, jewellery, wedding ceremony supply, diamond, wedding ring, pre-engagement ring
# Image saved: gem_carot_wedding_band\1 Carat\1_Carat_3.jpg
# Labels for 1_Carat_3.jpg: engagement ring, jewellery, white, ring, wedding ring, diamond, body jewelry, gemstone, pre-engagement ring, wedding ceremony supply
# Image saved: gem_carot_wedding_band\1 Carat\1_Carat_4.jpg
# Labels for 1_Carat_4.jpg: engagement ring, ring, jewellery, body jewelry, gemstone, wedding ring, wedding ceremony supply, pre-engagement ring, diamond, natural material
# Image saved: gem_carot_wedding_band\1 Carat\1_Carat_5.jpg
# Labels for 1_Carat_5.jpg: body jewelry, ring, gemstone, natural material, diamond, silver, engagement ring, pre-engagement ring, wedding ring
# Image saved: gem_carot_wedding_band\1 Carat\1_Carat_6.jpg
# Labels for 1_Carat_6.jpg: engagement ring, jewellery, ring, body jewelry, gemstone, wedding ring, pre-engagement ring, diamond, wedding ceremony supply, natural material
# Image saved: gem_carot_wedding_band\1 Carat\1_Carat_7.jpg
# Labels for 1_Carat_7.jpg: jewellery, body jewelry, engagement ring, ring, gemstone, natural material, wedding ceremony supply, diamond, wedding ring, pre-engagement ring
# Image saved: gem_carot_wedding_band\1 Carat\1_Carat_8.jpg
# Labels for 1_Carat_8.jpg: jewellery, ring, engagement ring, body jewelry, gemstone, fashion, wedding ring, finger, wedding ceremony supply, diamond
# Failed to download image: https://www.zales.com/productimages/processed/V-20278869_1_800.jpg?pristine=true (Status Code: 403)
# Image saved: gem_carot_wedding_band\1 Carat\1_Carat_9.jpg
# Labels for 1_Carat_9.jpg: engagement ring, ring, gemstone, wedding ring, body jewelry, jewellery, diamond, wedding ceremony supply, pre-engagement ring, crystal
# Fetching images for 2 Carat...
# Image saved: gem_carot_wedding_band\2 Carat\2_Carat_1.jpg
# Labels for 2_Carat_1.jpg: jewellery, ring, engagement ring, body jewelry, gemstone, fashion, wedding ring, finger, wedding ceremony supply, diamond
# Image saved: gem_carot_wedding_band\2 Carat\2_Carat_2.jpg
# Labels for 2_Carat_2.jpg: jewellery, body jewelry, engagement ring, ring, gemstone, natural material, wedding ceremony supply, diamond, wedding ring, pre-engagement ring
# Failed to download image: https://www.jeenjewels.com/7522-30161-thickbox/antique-princess-2-carat-wedding-ring-set-for-her-in-white-gold.jpg (Status Code: 406)
# Image saved: gem_carot_wedding_band\2 Carat\2_Carat_3.jpg
# Labels for 2_Carat_3.jpg: engagement ring, ring, jewellery, wedding ring, diamond, body jewelry, gemstone, pre-engagement ring, wedding ceremony supply, silver
# Image saved: gem_carot_wedding_band\2 Carat\2_Carat_4.jpg
# Labels for 2_Carat_4.jpg: ring, carbon fibers
# Image saved: gem_carot_wedding_band\2 Carat\2_Carat_5.jpg
# Labels for 2_Carat_5.jpg: engagement ring, ring, diamond, wedding ring, pre-engagement ring, metal, natural material, wedding ceremony supply, titanium ring, gold
# Failed to download image: https://www.zalesoutlet.com/productimages/processed/V-20059905_2_800.jpg (Status Code: 403)
# Image saved: gem_carot_wedding_band\2 Carat\2_Carat_6.jpg
# Labels for 2_Carat_6.jpg: natural material, ring, gemstone, diamond, gold, silver, engagement ring, wedding ring, pre-engagement ring, crystal
# Image saved: gem_carot_wedding_band\2 Carat\2_Carat_7.jpg
# Labels for 2_Carat_7.jpg: gemstone, crystal, diamond, engagement ring, body jewelry, natural material, ring, pre-engagement ring, silver, mineral
# Image saved: gem_carot_wedding_band\2 Carat\2_Carat_8.jpg
# Labels for 2_Carat_8.jpg: white, engagement ring, gemstone, body jewelry, diamond, crystal, jewellery, pre-engagement ring, natural material, wedding ring
# Fetching images for 2.5 Carat...
# Image saved: gem_carot_wedding_band\2.5 Carat\2.5_Carat_1.jpg
# Labels for 2.5_Carat_1.jpg: body jewelry, gemstone, diamond, crystal, jewellery, engagement ring, natural material, wedding ceremony supply, ring, silver
# Image saved: gem_carot_wedding_band\2.5 Carat\2.5_Carat_2.jpg
# Labels for 2.5_Carat_2.jpg: gemstone, natural material, engagement ring, diamond, crystal, body jewelry, ring, pre-engagement ring, wedding ring, wedding ceremony supply
# Image saved: gem_carot_wedding_band\2.5 Carat\2.5_Carat_3.jpg
# Labels for 2.5_Carat_3.jpg: white, gemstone, engagement ring, crystal, diamond, body jewelry, jewellery, wedding ring, ring, pre-engagement ring
# Image saved: gem_carot_wedding_band\2.5 Carat\2.5_Carat_4.jpg
# Labels for 2.5_Carat_4.jpg: white, gemstone, body jewelry, diamond, engagement ring, jewellery, crystal, natural material, silver, pre-engagement ring
# Image saved: gem_carot_wedding_band\2.5 Carat\2.5_Carat_5.jpg
# Labels for 2.5_Carat_5.jpg: white, gemstone, crystal, diamond, engagement ring, body jewelry, ring, wedding ring, natural material, pre-engagement ring
# Image saved: gem_carot_wedding_band\2.5 Carat\2.5_Carat_6.jpg
# Labels for 2.5_Carat_6.jpg: engagement ring, gemstone, fashion, ring, jewellery, body jewelry, diamond, wedding ring, wedding ceremony supply, pink
# Image saved: gem_carot_wedding_band\2.5 Carat\2.5_Carat_7.jpg
# Labels for 2.5_Carat_7.jpg: ring, engagement ring, pre-engagement ring, wedding ring, wedding ceremony supply
# Image saved: gem_carot_wedding_band\2.5 Carat\2.5_Carat_8.jpg
# Labels for 2.5_Carat_8.jpg: gemstone, body jewelry, ring, diamond, jewellery, engagement ring, pre-engagement ring, wedding ceremony supply, wedding ring, natural material
# Image saved: gem_carot_wedding_band\2.5 Carat\2.5_Carat_9.jpg
# Labels for 2.5_Carat_9.jpg: gemstone, wedding ceremony supply, diamond, ring, crystal, ruby, natural material, engagement ring, platinum, pre-engagement ring
# Image saved: gem_carot_wedding_band\2.5 Carat\2.5_Carat_10.jpg
# Labels for 2.5_Carat_10.jpg: gemstone, engagement ring, natural material, diamond, crystal, body jewelry, ring, pre-engagement ring, wedding ring, wedding ceremony supply
# Fetching images for 3 Carat...
# Image saved: gem_carot_wedding_band\3 Carat\3_Carat_1.jpg
# Labels for 3_Carat_1.jpg: engagement ring, white, ring, body jewelry, gemstone, jewellery, wedding ceremony supply, diamond, wedding ring, pre-engagement ring
# Image saved: gem_carot_wedding_band\3 Carat\3_Carat_2.jpg
# Labels for 3_Carat_2.jpg: gemstone, ring, engagement ring, body jewelry, diamond, wedding ring, pre-engagement ring, emerald, crystal, natural material
# Image saved: gem_carot_wedding_band\3 Carat\3_Carat_3.jpg
# Labels for 3_Carat_3.jpg: engagement ring, ring, jewellery, body jewelry, gemstone, wedding ring, wedding ceremony supply, pre-engagement ring, diamond, natural material
# Image saved: gem_carot_wedding_band\3 Carat\3_Carat_4.jpg
# Labels for 3_Carat_4.jpg: gemstone, engagement ring, jewellery, diamond, body jewelry, crystal, wedding ring, pre-engagement ring, ring, natural material
# Image saved: gem_carot_wedding_band\3 Carat\3_Carat_5.jpg
# Labels for 3_Carat_5.jpg: engagement ring, jewellery, ring, body jewelry, gemstone, wedding ring, pre-engagement ring, diamond, wedding ceremony supply, natural material
# Image saved: gem_carot_wedding_band\3 Carat\3_Carat_6.jpg
# Labels for 3_Carat_6.jpg: red, gemstone, natural material, diamond, pre-engagement ring, engagement ring, ruby, platinum, titanium, silver
# Image saved: gem_carot_wedding_band\3 Carat\3_Carat_7.jpg
# Labels for 3_Carat_7.jpg: white, body jewelry, diamond, natural material, gemstone, silver, engagement ring, platinum, ring, wedding ceremony supply
# Image saved: gem_carot_wedding_band\3 Carat\3_Carat_8.jpg
# Labels for 3_Carat_8.jpg: wedding ceremony supply, engagement ring, wedding ring, ring, diamond, gemstone, pre-engagement ring, natural material, silver, gold
# Image saved: gem_carot_wedding_band\3 Carat\3_Carat_9.jpg
# Labels for 3_Carat_9.jpg: gemstone, body jewelry, diamond, natural material, wedding ceremony supply, engagement ring, pre-engagement ring, gold, ring, wedding ring
# Image saved: gem_carot_wedding_band\3 Carat\3_Carat_10.jpg
# Labels for 3_Carat_10.jpg: yellow, wedding ceremony supply, diamond, gemstone, engagement ring, wedding ring, natural material, ring, pre-engagement ring, gold
# Fetching images for 4 Carat...
# Image saved: gem_carot_wedding_band\4 Carat\4_Carat_1.jpg
# Labels for 4_Carat_1.jpg: engagement ring, ring, jewellery, body jewelry, wedding ceremony supply, wedding ring, diamond, pre-engagement ring, silver, gemstone
# Image saved: gem_carot_wedding_band\4 Carat\4_Carat_2.jpg
# Labels for 4_Carat_2.jpg: crystal, diamond, gemstone, natural material, gold, jewelry making, ring, body jewelry, wedding ceremony supply
# Image saved: gem_carot_wedding_band\4 Carat\4_Carat_3.jpg
# Labels for 4_Carat_3.jpg: jewellery, engagement ring, gemstone, fashion, body jewelry, crystal, diamond, ring, mineral, watch
# Image saved: gem_carot_wedding_band\4 Carat\4_Carat_4.jpg
# Labels for 4_Carat_4.jpg: white, engagement ring, ring, gemstone, crystal, body jewelry, diamond, wedding ring, jewellery, jewelry making
# Image saved: gem_carot_wedding_band\4 Carat\4_Carat_5.jpg
# Labels for 4_Carat_5.jpg: white, gemstone, body jewelry, diamond, engagement ring, jewellery, crystal, natural material, silver, pre-engagement ring
# Image saved: gem_carot_wedding_band\4 Carat\4_Carat_6.jpg
# Labels for 4_Carat_6.jpg: gemstone, crystal, diamond, engagement ring, ring, natural material, body jewelry, wedding ring, pre-engagement ring, jewelry making
# Image saved: gem_carot_wedding_band\4 Carat\4_Carat_7.jpg
# Labels for 4_Carat_7.jpg: engagement ring, ring, gemstone, wedding ring, natural material, diamond, pre-engagement ring, body jewelry, silver, wedding ceremony supply
# Image saved: gem_carot_wedding_band\4 Carat\4_Carat_8.jpg
# Labels for 4_Carat_8.jpg: yellow, natural material, diamond, gemstone, gold, wedding ceremony supply, crystal
# Image saved: gem_carot_wedding_band\4 Carat\4_Carat_9.jpg
# Labels for 4_Carat_9.jpg: jewellery, finger, ring, body jewelry, nail, engagement ring, natural material, nail care, thumb, silver
# Image saved: gem_carot_wedding_band\4 Carat\4_Carat_10.jpg
# Labels for 4_Carat_10.jpg: ring, engagement ring, gemstone, body jewelry, diamond, wedding ring, crystal, pre-engagement ring, natural material, wedding ceremony supply
# Fetching images for 5 Carat...
# Image saved: gem_carot_wedding_band\5 Carat\5_Carat_1.jpg
# Labels for 5_Carat_1.jpg: engagement ring, ring, jewellery, wedding ring, diamond, body jewelry, gemstone, pre-engagement ring, wedding ceremony supply, silver
# Image saved: gem_carot_wedding_band\5 Carat\5_Carat_2.jpg
# Labels for 5_Carat_2.jpg: body jewelry, diamond, silver, jewellery, natural material, ring, engagement ring, crystal, wedding ring, wedding ceremony supply
# Image saved: gem_carot_wedding_band\5 Carat\5_Carat_3.jpg
# Labels for 5_Carat_3.jpg: green, gemstone, natural material, ring, emerald
# Image saved: gem_carot_wedding_band\5 Carat\5_Carat_4.jpg
# Labels for 5_Carat_4.jpg: crystal, gemstone, engagement ring, ring, jewellery, diamond, wedding ring, natural material, silver, body jewelry
# Image saved: gem_carot_wedding_band\5 Carat\5_Carat_5.jpg
# Labels for 5_Carat_5.jpg: ring, wedding ceremony supply, pre-engagement ring, gemstone, body jewelry, wedding ring
# Image saved: gem_carot_wedding_band\5 Carat\5_Carat_6.jpg
# Labels for 5_Carat_6.jpg: jewellery, engagement ring, body jewelry, gemstone, diamond, ring, pre-engagement ring, silver, wedding ring, natural material
# Image saved: gem_carot_wedding_band\5 Carat\5_Carat_7.jpg
# Labels for 5_Carat_7.jpg: gemstone, jewellery, ring, body jewelry, natural material, pre-engagement ring, jewelry making
# Image saved: gem_carot_wedding_band\5 Carat\5_Carat_8.jpg
# Labels for 5_Carat_8.jpg:
# Image saved: gem_carot_wedding_band\5 Carat\5_Carat_9.jpg
# Labels for 5_Carat_9.jpg: ring, jewellery, body jewelry, gemstone, bangle, wedding ceremony supply, sapphire, pre-engagement ring, engagement ring, bracelet
# Image saved: gem_carot_wedding_band\5 Carat\5_Carat_10.jpg
# Labels for 5_Carat_10.jpg: engagement ring, diamond, gemstone, jewellery, ring, silver, wedding ring, wedding ceremony supply, body jewelry, crystal
# Fetching images for 3.8 carat TW or 0.5 Carat x 7, 0.025 x 32 pcs, 0.05 x 50pcs...
# No images found for query: 3.8 carat TW or 0.5 Carat x 7, 0.025 x 32 pcs, 0.05 x 50pcs
# No images found for 3.8 carat TW or 0.5 Carat x 7, 0.025 x 32 pcs, 0.05 x 50pcs
# Fetching images for Totlall Approx 0.25 Carat...
# Image saved: gem_carot_wedding_band\Totlall Approx 0.25 Carat\Totlall_Approx_0.25_Carat_1.jpg
# Labels for Totlall_Approx_0.25_Carat_1.jpg: jewellery, ring, engagement ring, diamond, pre-engagement ring, wedding ring, body jewelry, gemstone, natural material, wedding ceremony supply
# Failed to download image: https://images.jtv.com/jewelry/JTV-BJH235-1-medium.jpg (Status Code: 403)
# Image saved: gem_carot_wedding_band\Totlall Approx 0.25 Carat\Totlall_Approx_0.25_Carat_2.jpg
# Labels for Totlall_Approx_0.25_Carat_2.jpg: jewellery, ring, engagement ring, gemstone, body jewelry, fashion, wedding ring, diamond, wedding ceremony supply, crystal
# Image saved: gem_carot_wedding_band\Totlall Approx 0.25 Carat\Totlall_Approx_0.25_Carat_3.jpg
# Labels for Totlall_Approx_0.25_Carat_3.jpg: engagement ring, diamond, gemstone, body jewelry, crystal, natural material, silver, ring, platinum, pre-engagement ring
# Error downloading or verifying image: HTTPSConnectionPool(host='www.fabioferro.eu', port=443): Max retries exceeded with url: /wp-content/uploads/anello-fabio-ferro-di-fidanzamento-in-oro-bianco-e-diamanti-m.10339-1.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x00000244EFFB8FA0>, 'Connection to www.fabioferro.eu timed out. (connect timeout=10)')) - URL: https://www.fabioferro.eu/wp-content/uploads/anello-fabio-ferro-di-fidanzamento-in-oro-bianco-e-diamanti-m.10339-1.jpg
# Image saved: gem_carot_wedding_band\Totlall Approx 0.25 Carat\Totlall_Approx_0.25_Carat_4.jpg
# Labels for Totlall_Approx_0.25_Carat_4.jpg: jewellery, engagement ring, body jewelry, ring, gemstone, pre-engagement ring, natural material, wedding ring, diamond, wedding ceremony supply
# Image saved: gem_carot_wedding_band\Totlall Approx 0.25 Carat\Totlall_Approx_0.25_Carat_5.jpg
# Labels for Totlall_Approx_0.25_Carat_5.jpg: body jewelry, natural material, gemstone, silver, ring, diamond, engagement ring, pre-engagement ring, wedding ring, wedding ceremony supply
# Image saved: gem_carot_wedding_band\Totlall Approx 0.25 Carat\Totlall_Approx_0.25_Carat_6.jpg
# Labels for Totlall_Approx_0.25_Carat_6.jpg: jewellery, engagement ring, white, ring, body jewelry, wedding ring, wedding ceremony supply, diamond, pre-engagement ring, gemstone
# Image saved: gem_carot_wedding_band\Totlall Approx 0.25 Carat\Totlall_Approx_0.25_Carat_7.jpg
# Labels for Totlall_Approx_0.25_Carat_7.jpg: ring, engagement ring, jewellery, body jewelry, wedding ring, pre-engagement ring, diamond, wedding ceremony supply, natural material, gemstone
# Image saved: gem_carot_wedding_band\Totlall Approx 0.25 Carat\Totlall_Approx_0.25_Carat_8.jpg
# Labels for Totlall_Approx_0.25_Carat_8.jpg: jewellery, engagement ring, ring, body jewelry, fashion, gemstone, wedding ring, pre-engagement ring, natural material, wedding ceremony supply
# Fetching images for Totlall Approx 0.5 Carat...
# Image saved: gem_carot_wedding_band\Totlall Approx 0.5 Carat\Totlall_Approx_0.5_Carat_1.jpg
# Labels for Totlall_Approx_0.5_Carat_1.jpg: jewellery, ring, engagement ring, gemstone, body jewelry, fashion, wedding ring, diamond, wedding ceremony supply, crystal
# Image saved: gem_carot_wedding_band\Totlall Approx 0.5 Carat\Totlall_Approx_0.5_Carat_2.jpg
# Labels for Totlall_Approx_0.5_Carat_2.jpg: silver, diamond, natural material, body jewelry, wedding ceremony supply, ring, platinum, pre-engagement ring, wedding ring, engagement ring
# Image saved: gem_carot_wedding_band\Totlall Approx 0.5 Carat\Totlall_Approx_0.5_Carat_3.jpg
# Labels for Totlall_Approx_0.5_Carat_3.jpg: engagement ring, jewellery, ring, fashion, gemstone, body jewelry, finger, wedding ring, wedding ceremony supply, diamond
# Image saved: gem_carot_wedding_band\Totlall Approx 0.5 Carat\Totlall_Approx_0.5_Carat_4.jpg
# Labels for Totlall_Approx_0.5_Carat_4.jpg: engagement ring, diamond, pre-engagement ring, ring, wedding ring, silver, natural material, wedding ceremony supply, platinum, mineral
# Image saved: gem_carot_wedding_band\Totlall Approx 0.5 Carat\Totlall_Approx_0.5_Carat_5.jpg
# Labels for Totlall_Approx_0.5_Carat_5.jpg: engagement ring, ring, diamond, wedding ring, wedding ceremony supply, body jewelry, pre-engagement ring, natural material, silver, gemstone
# Image saved: gem_carot_wedding_band\Totlall Approx 0.5 Carat\Totlall_Approx_0.5_Carat_6.jpg
# Labels for Totlall_Approx_0.5_Carat_6.jpg: ring, engagement ring, jewellery, gemstone, wedding ring, body jewelry, wedding ceremony supply, diamond, crystal, pre-engagement ring
# Image saved: gem_carot_wedding_band\Totlall Approx 0.5 Carat\Totlall_Approx_0.5_Carat_7.jpg
# Labels for Totlall_Approx_0.5_Carat_7.jpg: diamond, engagement ring, ring, silver, pre-engagement ring, natural material, wedding ceremony supply, wedding ring, body jewelry, platinum
# Image saved: gem_carot_wedding_band\Totlall Approx 0.5 Carat\Totlall_Approx_0.5_Carat_8.jpg
# Labels for Totlall_Approx_0.5_Carat_8.jpg: gemstone, crystal, engagement ring, jewellery, diamond, natural material, silver, ring, body jewelry, wedding ring
# Image saved: gem_carot_wedding_band\Totlall Approx 0.5 Carat\Totlall_Approx_0.5_Carat_9.jpg
# Labels for Totlall_Approx_0.5_Carat_9.jpg: jewellery, ring, engagement ring, body jewelry, gemstone, fashion, wedding ring, finger, wedding ceremony supply, diamond
# Image saved: gem_carot_wedding_band\Totlall Approx 0.5 Carat\Totlall_Approx_0.5_Carat_10.jpg
# Labels for Totlall_Approx_0.5_Carat_10.jpg: engagement ring, jewellery, gemstone, wedding ring, ring, diamond, pre-engagement ring, body jewelry, natural material, wedding ceremony supply
# Fetching images for Totlall Approx 0.75 Carat...
# Image saved: gem_carot_wedding_band\Totlall Approx 0.75 Carat\Totlall_Approx_0.75_Carat_1.jpg
# Labels for Totlall_Approx_0.75_Carat_1.jpg: engagement ring, white, fashion, diamond, pre-engagement ring, gemstone, wedding ring, crystal, natural material, mineral
# Image saved: gem_carot_wedding_band\Totlall Approx 0.75 Carat\Totlall_Approx_0.75_Carat_2.jpg
# Labels for Totlall_Approx_0.75_Carat_2.jpg: jewellery, ring, engagement ring, gemstone, body jewelry, fashion, wedding ring, diamond, wedding ceremony supply, crystal
# Image saved: gem_carot_wedding_band\Totlall Approx 0.75 Carat\Totlall_Approx_0.75_Carat_3.jpg
# Labels for Totlall_Approx_0.75_Carat_3.jpg: jewellery, engagement ring, body jewelry, ring, gemstone, pre-engagement ring, natural material, wedding ring, diamond, wedding ceremony supply
# Image saved: gem_carot_wedding_band\Totlall Approx 0.75 Carat\Totlall_Approx_0.75_Carat_4.jpg
# Labels for Totlall_Approx_0.75_Carat_4.jpg: body jewelry, natural material, gemstone, silver, ring, diamond, engagement ring, pre-engagement ring, wedding ring, wedding ceremony supply
# Image saved: gem_carot_wedding_band\Totlall Approx 0.75 Carat\Totlall_Approx_0.75_Carat_5.jpg
# Labels for Totlall_Approx_0.75_Carat_5.jpg: engagement ring, white, fashion, diamond, pre-engagement ring, gemstone, wedding ring, crystal, natural material, mineral
# Failed to download image: https://images.jtv.com/jewelry/JTV-BJH235-1-medium.jpg (Status Code: 403)
# Image saved: gem_carot_wedding_band\Totlall Approx 0.75 Carat\Totlall_Approx_0.75_Carat_6.jpg
# Labels for Totlall_Approx_0.75_Carat_6.jpg: engagement ring, diamond, pre-engagement ring, wedding ring, ring, wedding ceremony supply, silver, platinum, titanium ring, natural material
# Failed to download image: https://www.lippas.com/wp-content/uploads/2023/03/770-14288_hand_top__09389-scaled.jpg (Status Code: 403)
# Image saved: gem_carot_wedding_band\Totlall Approx 0.75 Carat\Totlall_Approx_0.75_Carat_7.jpg
# Labels for Totlall_Approx_0.75_Carat_7.jpg: diamond, natural material, silver, ring, body jewelry, pre-engagement ring, engagement ring, gemstone, wedding ring, platinum
# Image saved: gem_carot_wedding_band\Totlall Approx 0.75 Carat\Totlall_Approx_0.75_Carat_8.jpg
# Labels for Totlall_Approx_0.75_Carat_8.jpg: engagement ring, white, fashion, diamond, pre-engagement ring, gemstone, wedding ring, crystal, natural material, mineral
# Fetching images for Totlall Approx 1 Carat...
# Image saved: gem_carot_wedding_band\Totlall Approx 1 Carat\Totlall_Approx_1_Carat_1.jpg
# Labels for Totlall_Approx_1_Carat_1.jpg: jewellery, ring, engagement ring, body jewelry, gemstone, fashion, wedding ring, finger, wedding ceremony supply, diamond
# Failed to download image: https://www.kayoutlet.com/productimages/processed/V-884608908_0_800.jpg?pristine=true (Status Code: 403)
# Failed to download image: https://www.zalesoutlet.com/productimages/processed/V-20059905_2_800.jpg (Status Code: 403)
# Image saved: gem_carot_wedding_band\Totlall Approx 1 Carat\Totlall_Approx_1_Carat_2.jpg
# Labels for Totlall_Approx_1_Carat_2.jpg: engagement ring, diamond, pre-engagement ring
# Image saved: gem_carot_wedding_band\Totlall Approx 1 Carat\Totlall_Approx_1_Carat_3.jpg
# Labels for Totlall_Approx_1_Carat_3.jpg: wedding ceremony supply, gemstone, body jewelry, natural material, ring, diamond, pre-engagement ring
# Failed to download image: https://www.zales.com/productimages/processed/V-20278869_1_800.jpg?pristine=true (Status Code: 403)
# Image saved: gem_carot_wedding_band\Totlall Approx 1 Carat\Totlall_Approx_1_Carat_4.jpg
# Labels for Totlall_Approx_1_Carat_4.jpg: silver, diamond, natural material, body jewelry, wedding ceremony supply, ring, platinum, pre-engagement ring, wedding ring, engagement ring
# Failed to download image: https://www.zales.com/productimages/processed/V-20560871_6_800.jpg?pristine=true (Status Code: 403)
# Image saved: gem_carot_wedding_band\Totlall Approx 1 Carat\Totlall_Approx_1_Carat_5.jpg
# Labels for Totlall_Approx_1_Carat_5.jpg: ring, engagement ring, jewellery, body jewelry, wedding ring, pre-engagement ring, diamond, wedding ceremony supply, natural material, gemstone
# Failed to download image: https://www.zales.com/productimages/processed/V-20156211_2_800.jpg (Status Code: 403)
# Fetching images for Totlall Approx 2 Carat...
# Image saved: gem_carot_wedding_band\Totlall Approx 2 Carat\Totlall_Approx_2_Carat_1.jpg
# Labels for Totlall_Approx_2_Carat_1.jpg: jewellery, ring, engagement ring, body jewelry, gemstone, fashion, wedding ring, finger, wedding ceremony supply, diamond
# Failed to download image: https://www.kayoutlet.com/productimages/processed/V-884608908_0_800.jpg?pristine=true (Status Code: 403)
# Failed to download image: https://www.zalesoutlet.com/productimages/processed/V-20059905_2_800.jpg (Status Code: 403)
# Failed to download image: https://www.zales.com/productimages/processed/V-20156211_2_800.jpg (Status Code: 403)
# Image saved: gem_carot_wedding_band\Totlall Approx 2 Carat\Totlall_Approx_2_Carat_2.jpg
# Labels for Totlall_Approx_2_Carat_2.jpg: body jewelry, natural material, gemstone, silver, ring, diamond, engagement ring, pre-engagement ring, wedding ring, wedding ceremony supply
# Failed to download image: https://images.jtv.com/jewelry/JTV-BJH235-1-medium.jpg (Status Code: 403)
# Image saved: gem_carot_wedding_band\Totlall Approx 2 Carat\Totlall_Approx_2_Carat_3.jpg
# Labels for Totlall_Approx_2_Carat_3.jpg: ring, body jewelry, wedding ring, engagement ring, silver, pre-engagement ring, natural material, wedding ceremony supply, platinum, bangle
# Failed to download image: https://www.kayoutlet.com/productimages/processed/V-886026400_6_800.jpg?pristine=true (Status Code: 403)
# Image saved: gem_carot_wedding_band\Totlall Approx 2 Carat\Totlall_Approx_2_Carat_4.jpg
# Labels for Totlall_Approx_2_Carat_4.jpg: engagement ring, ring, diamond, wedding ring, wedding ceremony supply, body jewelry, pre-engagement ring, natural material, silver, gemstone
# Image saved: gem_carot_wedding_band\Totlall Approx 2 Carat\Totlall_Approx_2_Carat_5.jpg
# Labels for Totlall_Approx_2_Carat_5.jpg: body jewelry, jewellery, engagement ring, ring, silver, natural material, gemstone, diamond, pre-engagement ring, wedding ring
# Fetching images for Totlall Approx 3 Carat...
# Image saved: gem_carot_wedding_band\Totlall Approx 3 Carat\Totlall_Approx_3_Carat_1.jpg
# Labels for Totlall_Approx_3_Carat_1.jpg: engagement ring, diamond, gemstone, wedding ring, silver, ring, crystal, pre-engagement ring, body jewelry, jewellery
# Failed to download image: https://www.tiktok.com/api/img/?itemId=7396511350211661102&location=0&aid=1988 (Status Code: 403)
# Failed to download image: https://www.zales.com/productimages/processed/V-20560871_6_800.jpg?pristine=true (Status Code: 403)
# Image saved: gem_carot_wedding_band\Totlall Approx 3 Carat\Totlall_Approx_3_Carat_2.jpg
# Labels for Totlall_Approx_3_Carat_2.jpg: jewellery, ring, engagement ring, gemstone, body jewelry, fashion, wedding ring, diamond, wedding ceremony supply, crystal
# Image saved: gem_carot_wedding_band\Totlall Approx 3 Carat\Totlall_Approx_3_Carat_3.jpg
# Labels for Totlall_Approx_3_Carat_3.jpg: engagement ring, fashion, jewellery, gemstone, ring, diamond, body jewelry, wedding ring, crystal, pre-engagement ring
# Image saved: gem_carot_wedding_band\Totlall Approx 3 Carat\Totlall_Approx_3_Carat_4.jpg
# Labels for Totlall_Approx_3_Carat_4.jpg: diamond, engagement ring, ring, silver, pre-engagement ring, natural material, wedding ceremony supply, wedding ring, body jewelry, platinum
# Image saved: gem_carot_wedding_band\Totlall Approx 3 Carat\Totlall_Approx_3_Carat_5.jpg
# Labels for Totlall_Approx_3_Carat_5.jpg: jewellery, ring, engagement ring, body jewelry, gemstone, fashion, wedding ring, finger, wedding ceremony supply, diamond
# Failed to download image: https://www.zales.com/productimages/processed/V-20156258_1_800.jpg (Status Code: 403)
# Failed to download image: https://www.zalesoutlet.com/productimages/processed/V-20059905_2_800.jpg (Status Code: 403)
# Image saved: gem_carot_wedding_band\Totlall Approx 3 Carat\Totlall_Approx_3_Carat_6.jpg
# Labels for Totlall_Approx_3_Carat_6.jpg: engagement ring, diamond, pre-engagement ring
