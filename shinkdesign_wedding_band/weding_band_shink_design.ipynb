# %%
import os
import requests
from google.cloud import vision
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError
from PIL import Image
from io import BytesIO

# Ensure the image storage directory exists
IMAGE_DIR = "shink_design_wedding_band"
os.makedirs(IMAGE_DIR, exist_ok=True)

# List of shink design for which we will fetch images
shink_design=[
"Curved Contour",
"Crown",
"Curved Crown",
"Half Circle",
"V Shaped Chevron",
"Deep V Shaped Chevron",
"Wrap Around",
"Slip under",
"Open",
"Notched",
"Square Notched",
"Scalloped",
"Milgrain",
"Engraved",
"Classic",
"Flat",
"Flat Edge",
"Round Band",
"Wide Band",
"Thick Band",
"Thin Band",
"Knife Edge",
"Modern",
"Euro Shank",
"Tapered",
"Reverse Tapered",
"Split Shank",
"Wide Split Shank",
"Reverse Split Shank",
"Infinity Shank",
"Twisted Shank",
"Bypass",
"Triple band",
"Filigree",
"Vintage",
"Plain Band",
"Flat Court", 
"Concave" ,
'Half Round' ]


def search_image(query, api_key, cse_id):
    """Search for images using Google Custom Search JSON API."""
    try:
        # Format query to avoid invalid characters
        formatted_query = query.replace(" ", "+").replace("-", "_").replace(".", "")  # Remove dots
        
        service = build("customsearch", "v1", developerKey=api_key)
        res = service.cse().list(
            q=formatted_query + "wedding+band+diamond",
            cx=cse_id,
            searchType="image",
            num=10 # Reduced to 10 as per Google API limits
        ).execute()

        if "items" in res:
            return [item["link"] for item in res["items"]]
        else:
            print(f"No images found for query: {query}")
    except HttpError as e:
        print(f"Google Search API Error: {e}")
    return []

def analyze_image(image_url):
    """Analyze image using Google Cloud Vision API."""
    try:
        client = vision.ImageAnnotatorClient()
        image = vision.Image()
        image.source.image_uri = image_url
        response = client.label_detection(image=image)
        labels = [label.description.lower() for label in response.label_annotations]
        return labels
    except Exception as e:
        print(f"Vision API Error: {e}")
        return []

def download_image(image_url, save_path):
    """Download and save an image if it's valid."""
    try:
        response = requests.get(image_url, timeout=10)
        if response.status_code == 200:
            img = Image.open(BytesIO(response.content))
            img.verify()  # Ensure it's a valid image
            img = Image.open(BytesIO(response.content))  # Reopen after verification
            img = img.convert("RGB")  # Convert to standard format
            img.save(save_path, format="JPEG")  # Save as JPEG
            return save_path
        else:
            print(f"Failed to download image: {image_url} (Status Code: {response.status_code})")
    except Exception as e:
        print(f"Error downloading or verifying image: {e} - URL: {image_url}")
    return None

def create_folder_structure():
    """Create subfolders for each gem color."""
    for cat in shink_design:
        folder_path = os.path.join(IMAGE_DIR, cat)
        os.makedirs(folder_path, exist_ok=True)

def fetch_and_save_images(api_key, cse_id):
    """Fetch and save images for each gem color, using Google Custom Search and Vision API."""
    for cat in shink_design:
        print(f"Fetching images for {cat}...")

        # Create subfolder for the current gem color
        color_folder = os.path.join(IMAGE_DIR, cat)
        
        # Search for images related to the gem color
        image_urls = search_image(cat, api_key, cse_id)

        if image_urls:
            downloaded_images = 0  # Track successfully downloaded images

            for image_url in image_urls:
                if downloaded_images >= 20:  # Stop if we have downloaded 20 images
                    break
                
                # Generate unique file name for each image
                image_filename = f"{cat.replace(' ', '_')}_{downloaded_images + 1}.jpg"
                image_path = os.path.join(color_folder, image_filename)

                # Attempt to download and save the image
                saved_image = download_image(image_url, image_path)

                if saved_image:
                    print(f"Image saved: {saved_image}")

                    # Analyze image with Vision API and get labels
                    labels = analyze_image(image_url)
                    print(f"Labels for {image_filename}: {', '.join(labels)}")
                    
                    downloaded_images += 1
        else:
            print(f"No images found for {cat}")

# Google API credentials (Replace these with your actual credentials)
API_KEY = "AIzaSyAo5M5HXAXSkVxBzHRG0bUMRJf3RltEhJw"  # Replace with your actual API key
CSE_ID = "d63ff1141028241de"  # Replace with your actual CSE ID

# Set Google Cloud credentials
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = r"C:/Users/TechAir\Desktop/SHINKDESIGN_WEDDING_BAND/jewelry-449211-b1561756ae8d.json"  

# Create the folder structure for Gem Color categories
create_folder_structure()

# Fetch and save images for each gem color
fetch_and_save_images(API_KEY, CSE_ID)
# Out:
# Fetching images for Curved Contour...
# Image saved: shink_design_wedding_band\Curved Contour\Curved_Contour_1.jpg
# Labels for Curved_Contour_1.jpg: engagement ring, diamond, wedding ring, pre-engagement ring, gemstone, ring, body jewelry, wedding ceremony supply, natural material, silver
# Image saved: shink_design_wedding_band\Curved Contour\Curved_Contour_2.jpg
# Labels for Curved_Contour_2.jpg: engagement ring, ring, jewellery, body jewelry, wedding ring, gemstone, pre-engagement ring, diamond, silver, natural material
# Image saved: shink_design_wedding_band\Curved Contour\Curved_Contour_3.jpg
# Labels for Curved_Contour_3.jpg: natural material, pre-engagement ring, diamond, engagement ring, gemstone, platinum, titanium, sapphire, mineral, wedding ring
# Image saved: shink_design_wedding_band\Curved Contour\Curved_Contour_4.jpg
# Labels for Curved_Contour_4.jpg: engagement ring, ring, gemstone, jewellery, body jewelry, wedding ring, fashion, wedding ceremony supply, diamond, pre-engagement ring
# Image saved: shink_design_wedding_band\Curved Contour\Curved_Contour_5.jpg
# Labels for Curved_Contour_5.jpg: engagement ring, gemstone, fashion, body jewelry, ring, diamond, jewellery, wedding ring, pre-engagement ring, natural material
# Image saved: shink_design_wedding_band\Curved Contour\Curved_Contour_6.jpg
# Labels for Curved_Contour_6.jpg: ring, engagement ring, jewellery, gemstone, body jewelry, wedding ceremony supply, wedding ring, pre-engagement ring, diamond, natural material
# Image saved: shink_design_wedding_band\Curved Contour\Curved_Contour_7.jpg
# Labels for Curved_Contour_7.jpg: engagement ring, ring, jewellery, body jewelry, wedding ring, gemstone, pre-engagement ring, diamond, silver, natural material
# Image saved: shink_design_wedding_band\Curved Contour\Curved_Contour_8.jpg
# Labels for Curved_Contour_8.jpg: engagement ring, ring, jewellery, body jewelry, wedding ring, gemstone, diamond, pre-engagement ring, silver, natural material
# Image saved: shink_design_wedding_band\Curved Contour\Curved_Contour_9.jpg
# Labels for Curved_Contour_9.jpg: engagement ring, body jewelry, ring, gemstone, wedding ceremony supply, diamond, jewellery, wedding ring, silver, pre-engagement ring
# Image saved: shink_design_wedding_band\Curved Contour\Curved_Contour_10.jpg
# Labels for Curved_Contour_10.jpg:
# Fetching images for Crown...
# Image saved: shink_design_wedding_band\Crown\Crown_1.jpg
# Labels for Crown_1.jpg: natural material, wedding ceremony supply, engagement ring, ring
# Image saved: shink_design_wedding_band\Crown\Crown_2.jpg
# Labels for Crown_2.jpg: gemstone, ring, engagement ring, natural material, diamond, metal, body jewelry, silver, pre-engagement ring, wedding ring
# Image saved: shink_design_wedding_band\Crown\Crown_3.jpg
# Labels for Crown_3.jpg: diamond, gemstone, natural material, silver, body jewelry
# Image saved: shink_design_wedding_band\Crown\Crown_4.jpg
# Labels for Crown_4.jpg: jewellery, ring, body jewelry, gemstone, engagement ring, pre-engagement ring, natural material, wedding ring, metal, silver
# Image saved: shink_design_wedding_band\Crown\Crown_5.jpg
# Labels for Crown_5.jpg: engagement ring, gemstone, diamond, ring, body jewelry, crystal, pre-engagement ring, wedding ring, natural material, silver
# Image saved: shink_design_wedding_band\Crown\Crown_6.jpg
# Labels for Crown_6.jpg: engagement ring, gemstone, body jewelry, ring, wedding ring, jewellery, pre-engagement ring, diamond, natural material, wedding ceremony supply
# Image saved: shink_design_wedding_band\Crown\Crown_7.jpg
# Labels for Crown_7.jpg: body jewelry, engagement ring, ring, pre-engagement ring, gemstone, natural material, wedding ring, macro photography, wedding ceremony supply, diamond
# Image saved: shink_design_wedding_band\Crown\Crown_8.jpg
# Labels for Crown_8.jpg: natural material, gemstone, wedding ceremony supply, silver, engagement ring, ring, diamond, body jewelry, platinum, pre-engagement ring
# Image saved: shink_design_wedding_band\Crown\Crown_9.jpg
# Labels for Crown_9.jpg: natural material, diamond, body jewelry, wedding ceremony supply
# Image saved: shink_design_wedding_band\Crown\Crown_10.jpg
# Labels for Crown_10.jpg: engagement ring, ring, jewellery, body jewelry, wedding ring, gemstone, pre-engagement ring, wedding ceremony supply, diamond, natural material
# Fetching images for Curved Crown...
# Image saved: shink_design_wedding_band\Curved Crown\Curved_Crown_1.jpg
# Labels for Curved_Crown_1.jpg: jewellery, ring, body jewelry, gemstone, engagement ring, pre-engagement ring, natural material, wedding ring, diamond, jewelry making
# Image saved: shink_design_wedding_band\Curved Crown\Curved_Crown_2.jpg
# Labels for Curved_Crown_2.jpg: engagement ring, gemstone, diamond, ring, body jewelry, crystal, pre-engagement ring, wedding ring, natural material, silver
# Image saved: shink_design_wedding_band\Curved Crown\Curved_Crown_3.jpg
# Labels for Curved_Crown_3.jpg: body jewelry, engagement ring, ring, pre-engagement ring, gemstone, natural material, wedding ring, macro photography, wedding ceremony supply, diamond
# Image saved: shink_design_wedding_band\Curved Crown\Curved_Crown_4.jpg
# Labels for Curved_Crown_4.jpg: ring, jewellery, body jewelry, engagement ring, gemstone, pre-engagement ring, wedding ring, natural material, diamond, metal
# Image saved: shink_design_wedding_band\Curved Crown\Curved_Crown_5.jpg
# Labels for Curved_Crown_5.jpg: engagement ring, jewellery, ring, gemstone, body jewelry, diamond, crystal, pre-engagement ring, wedding ring, wedding ceremony supply
# Image saved: shink_design_wedding_band\Curved Crown\Curved_Crown_6.jpg
# Labels for Curved_Crown_6.jpg: ring, engagement ring, fashion, jewellery, body jewelry, gemstone, wedding ring, pre-engagement ring, natural material, wedding ceremony supply
# Image saved: shink_design_wedding_band\Curved Crown\Curved_Crown_7.jpg
# Labels for Curved_Crown_7.jpg: engagement ring, jewellery, gemstone, body jewelry, ring, pre-engagement ring, wedding ring, diamond, natural material, wedding ceremony supply
# Image saved: shink_design_wedding_band\Curved Crown\Curved_Crown_8.jpg
# Labels for Curved_Crown_8.jpg: engagement ring, fashion, gemstone, brown, body jewelry, diamond, ring, wedding ceremony supply, wedding ring, jewellery
# Image saved: shink_design_wedding_band\Curved Crown\Curved_Crown_9.jpg
# Labels for Curved_Crown_9.jpg: engagement ring, ring, jewellery, body jewelry, wedding ring, gemstone, pre-engagement ring, wedding ceremony supply, diamond, natural material
# Image saved: shink_design_wedding_band\Curved Crown\Curved_Crown_10.jpg
# Labels for Curved_Crown_10.jpg: ring, gemstone, jewellery, body jewelry, engagement ring, fashion, crystal, diamond, pre-engagement ring, wedding ceremony supply
# Fetching images for Half Circle...
# Image saved: shink_design_wedding_band\Half Circle\Half_Circle_1.jpg
# Labels for Half_Circle_1.jpg: engagement ring, diamond, pre-engagement ring, natural material, gemstone, design, wedding ring, ring, platinum, body jewelry
# Image saved: shink_design_wedding_band\Half Circle\Half_Circle_2.jpg
# Labels for Half_Circle_2.jpg: ring, engagement ring, pre-engagement ring, gemstone, natural material, body jewelry, diamond, wedding ring, wedding ceremony supply, mineral
# Image saved: shink_design_wedding_band\Half Circle\Half_Circle_3.jpg
# Labels for Half_Circle_3.jpg: wedding ceremony supply, engagement ring, natural material, ring, diamond, pre-engagement ring, wedding ring, gemstone, platinum, mineral
# Image saved: shink_design_wedding_band\Half Circle\Half_Circle_4.jpg
# Labels for Half_Circle_4.jpg: body jewelry, diamond, natural material, engagement ring, ring, pre-engagement ring, wedding ring, wedding ceremony supply, platinum, gemstone
# Image saved: shink_design_wedding_band\Half Circle\Half_Circle_5.jpg
# Labels for Half_Circle_5.jpg: gemstone, diamond, natural material, design, wedding ceremony supply, pre-engagement ring, platinum, ring
# Image saved: shink_design_wedding_band\Half Circle\Half_Circle_6.jpg
# Labels for Half_Circle_6.jpg: diamond, natural material, engagement ring, body jewelry, ring, pre-engagement ring, wedding ring, wedding ceremony supply, platinum
# Image saved: shink_design_wedding_band\Half Circle\Half_Circle_7.jpg
# Labels for Half_Circle_7.jpg: blue, gemstone, diamond, natural material, pre-engagement ring, ring, platinum, engagement ring
# Image saved: shink_design_wedding_band\Half Circle\Half_Circle_8.jpg
# Labels for Half_Circle_8.jpg: ring, gemstone, body jewelry, engagement ring, diamond, natural material, pre-engagement ring, silver, wedding ceremony supply, wedding ring
# Image saved: shink_design_wedding_band\Half Circle\Half_Circle_9.jpg
# Labels for Half_Circle_9.jpg: natural material, silver, mineral, diamond, gemstone, pre-engagement ring
# Image saved: shink_design_wedding_band\Half Circle\Half_Circle_10.jpg
# Labels for Half_Circle_10.jpg: engagement ring, ring, jewellery, wedding ring, body jewelry, pre-engagement ring, gemstone, diamond, wedding ceremony supply, natural material
# Fetching images for V Shaped Chevron...
# Image saved: shink_design_wedding_band\V Shaped Chevron\V_Shaped_Chevron_1.jpg
# Labels for V_Shaped_Chevron_1.jpg: engagement ring, ring, jewellery, gemstone, body jewelry, wedding ring, diamond, wedding ceremony supply, pre-engagement ring, natural material
# Image saved: shink_design_wedding_band\V Shaped Chevron\V_Shaped_Chevron_2.jpg
# Labels for V_Shaped_Chevron_2.jpg: body jewelry, fashion, jewellery, ring, gemstone, engagement ring, diamond, pre-engagement ring, natural material, crystal
# Image saved: shink_design_wedding_band\V Shaped Chevron\V_Shaped_Chevron_3.jpg
# Labels for V_Shaped_Chevron_3.jpg: jewellery, engagement ring, gemstone, body jewelry, ring, diamond, wedding ring, crystal, pre-engagement ring, wedding ceremony supply
# Image saved: shink_design_wedding_band\V Shaped Chevron\V_Shaped_Chevron_4.jpg
# Labels for V_Shaped_Chevron_4.jpg: gemstone, body jewelry, natural material, ring, pre-engagement ring, engagement ring, insect, macro photography, diamond, wedding ring
# Image saved: shink_design_wedding_band\V Shaped Chevron\V_Shaped_Chevron_5.jpg
# Labels for V_Shaped_Chevron_5.jpg: body jewelry, heart, engagement ring, gemstone, diamond, jewellery, pre-engagement ring, ring, wedding ceremony supply, natural material
# Image saved: shink_design_wedding_band\V Shaped Chevron\V_Shaped_Chevron_6.jpg
# Labels for V_Shaped_Chevron_6.jpg: jewellery, body jewelry, gemstone, ring, engagement ring, pre-engagement ring, natural material, wedding ring, diamond, wedding ceremony supply
# Image saved: shink_design_wedding_band\V Shaped Chevron\V_Shaped_Chevron_7.jpg
# Labels for V_Shaped_Chevron_7.jpg: natural material, macro photography, gemstone
# Image saved: shink_design_wedding_band\V Shaped Chevron\V_Shaped_Chevron_8.jpg
# Labels for V_Shaped_Chevron_8.jpg: gemstone, engagement ring, natural material, diamond, pre-engagement ring, platinum, wedding ceremony supply, wedding ring, mineral, triangle
# Image saved: shink_design_wedding_band\V Shaped Chevron\V_Shaped_Chevron_9.jpg
# Labels for V_Shaped_Chevron_9.jpg: engagement ring, gemstone, ring, body jewelry, diamond, pre-engagement ring, wedding ceremony supply, wedding ring, natural material, silver
# Image saved: shink_design_wedding_band\V Shaped Chevron\V_Shaped_Chevron_10.jpg
# Labels for V_Shaped_Chevron_10.jpg: body jewelry, ring, jewellery, gemstone, engagement ring, pre-engagement ring, natural material, diamond, wedding ring, macro photography
# Fetching images for Deep V Shaped Chevron...
# Image saved: shink_design_wedding_band\Deep V Shaped Chevron\Deep_V_Shaped_Chevron_1.jpg
# Labels for Deep_V_Shaped_Chevron_1.jpg: engagement ring, gemstone, diamond, body jewelry, pre-engagement ring, natural material, ring, wedding ring, silver, platinum
# Image saved: shink_design_wedding_band\Deep V Shaped Chevron\Deep_V_Shaped_Chevron_2.jpg
# Labels for Deep_V_Shaped_Chevron_2.jpg: jewellery, engagement ring, gemstone, body jewelry, ring, diamond, wedding ring, crystal, pre-engagement ring, wedding ceremony supply
# Image saved: shink_design_wedding_band\Deep V Shaped Chevron\Deep_V_Shaped_Chevron_3.jpg
# Labels for Deep_V_Shaped_Chevron_3.jpg: engagement ring, gemstone, body jewelry, ring, jewellery, pre-engagement ring, wedding ring, diamond, natural material, wedding ceremony supply
# Image saved: shink_design_wedding_band\Deep V Shaped Chevron\Deep_V_Shaped_Chevron_4.jpg
# Labels for Deep_V_Shaped_Chevron_4.jpg: engagement ring, gemstone, fashion, body jewelry, diamond, ring, natural material, wedding ring, pre-engagement ring, wedding ceremony supply
# Image saved: shink_design_wedding_band\Deep V Shaped Chevron\Deep_V_Shaped_Chevron_5.jpg
# Labels for Deep_V_Shaped_Chevron_5.jpg: gemstone, engagement ring, natural material, diamond, pre-engagement ring, platinum, wedding ceremony supply, wedding ring, mineral, triangle
# Image saved: shink_design_wedding_band\Deep V Shaped Chevron\Deep_V_Shaped_Chevron_6.jpg
# Labels for Deep_V_Shaped_Chevron_6.jpg: engagement ring, ring, jewellery, gemstone, body jewelry, diamond, wedding ring, wedding ceremony supply, pre-engagement ring, crystal
# Image saved: shink_design_wedding_band\Deep V Shaped Chevron\Deep_V_Shaped_Chevron_7.jpg
# Labels for Deep_V_Shaped_Chevron_7.jpg: engagement ring, ring, jewellery, gemstone, body jewelry, wedding ring, diamond, wedding ceremony supply, pre-engagement ring, natural material
# Image saved: shink_design_wedding_band\Deep V Shaped Chevron\Deep_V_Shaped_Chevron_8.jpg
# Labels for Deep_V_Shaped_Chevron_8.jpg: engagement ring, jewellery, gemstone, ring, body jewelry, wedding ring, diamond, pre-engagement ring, wedding ceremony supply, crystal
# Image saved: shink_design_wedding_band\Deep V Shaped Chevron\Deep_V_Shaped_Chevron_9.jpg
# Labels for Deep_V_Shaped_Chevron_9.jpg: body jewelry, diamond, gemstone, natural material, engagement ring, ring, pre-engagement ring, crystal, platinum, triangle
# Image saved: shink_design_wedding_band\Deep V Shaped Chevron\Deep_V_Shaped_Chevron_10.jpg
# Labels for Deep_V_Shaped_Chevron_10.jpg: jewellery, engagement ring, ring, gemstone, body jewelry, wedding ring, diamond, pre-engagement ring, wedding ceremony supply, natural material
# Fetching images for Wrap Around...
# Image saved: shink_design_wedding_band\Wrap Around\Wrap_Around_1.jpg
# Labels for Wrap_Around_1.jpg: engagement ring, ring, gemstone, body jewelry, jewellery, diamond, pre-engagement ring, wedding ring, crystal, natural material
# Failed to download image: https://ep7p5awhi5k.exactdn.com/wp-content/uploads/2022/12/V1360_12-02-2022_R1-min.png (Status Code: 403)
# Failed to download image: https://msgjewelers.com/wp-content/uploads/2024/02/20240215_150133-scaled.jpg (Status Code: 403)
# Image saved: shink_design_wedding_band\Wrap Around\Wrap_Around_2.jpg
# Labels for Wrap_Around_2.jpg: jewellery, ring, body jewelry, gemstone, engagement ring, diamond, metal, wedding ring, natural material, pre-engagement ring
# Image saved: shink_design_wedding_band\Wrap Around\Wrap_Around_3.jpg
# Labels for Wrap_Around_3.jpg: jewellery, body jewelry, natural material, ring, metal, silver, gemstone, diamond, engagement ring, crystal
# Image saved: shink_design_wedding_band\Wrap Around\Wrap_Around_4.jpg
# Labels for Wrap_Around_4.jpg: engagement ring, diamond, natural material, ring, silver, metal, pre-engagement ring, gemstone, wedding ring, platinum
# Image saved: shink_design_wedding_band\Wrap Around\Wrap_Around_5.jpg
# Labels for Wrap_Around_5.jpg: body jewelry, jewellery, nail care, nail polish, gemstone, ring, natural material, silver, engagement ring, nail
# Image saved: shink_design_wedding_band\Wrap Around\Wrap_Around_6.jpg
# Labels for Wrap_Around_6.jpg: gemstone, engagement ring, fashion, body jewelry, diamond, crystal, ring, pre-engagement ring, jewellery, wedding ceremony supply
# Image saved: shink_design_wedding_band\Wrap Around\Wrap_Around_7.jpg
# Labels for Wrap_Around_7.jpg: engagement ring, diamond, gemstone, pre-engagement ring, natural material, wedding ring, platinum, wedding ceremony supply, ring, body jewelry
# Image saved: shink_design_wedding_band\Wrap Around\Wrap_Around_8.jpg
# Labels for Wrap_Around_8.jpg: engagement ring, ring, gemstone, body jewelry, diamond, crystal, wedding ring, pre-engagement ring, jewellery, wedding ceremony supply
# Fetching images for Slip under...
# Image saved: shink_design_wedding_band\Slip under\Slip_under_1.jpg
# Labels for Slip_under_1.jpg: engagement ring, ring, gemstone, wedding ring, body jewelry, jewellery, diamond, pre-engagement ring, wedding ceremony supply, crystal
# Image saved: shink_design_wedding_band\Slip under\Slip_under_2.jpg
# Labels for Slip_under_2.jpg: engagement ring, diamond, ring, wedding ring, gemstone, jewellery, pre-engagement ring, silver, wedding ceremony supply, mineral
# Image saved: shink_design_wedding_band\Slip under\Slip_under_3.jpg
# Labels for Slip_under_3.jpg: gemstone, diamond, body jewelry, crystal, wedding ceremony supply, natural material, ring, engagement ring, silver, design
# Failed to download image: https://cdn0.weddingwire.com/vendor/133610/3_2/960/jpg/1539275684-8a2013d8114f2739-Screen_Shot_2018-10-11_at_12.34.12_PM.jpeg (Status Code: 403)
# Image saved: shink_design_wedding_band\Slip under\Slip_under_4.jpg
# Labels for Slip_under_4.jpg: body jewelry, gemstone, diamond, ring, natural material, engagement ring, silver, pre-engagement ring, wedding ring, platinum
# Image saved: shink_design_wedding_band\Slip under\Slip_under_5.jpg
# Labels for Slip_under_5.jpg: engagement ring, diamond, gemstone, ring, silver, pre-engagement ring, wedding ring, platinum, body jewelry, natural material
# Image saved: shink_design_wedding_band\Slip under\Slip_under_6.jpg
# Labels for Slip_under_6.jpg: engagement ring, ring, wedding ring, gemstone, diamond, jewellery, body jewelry, pre-engagement ring, silver, natural material
# Image saved: shink_design_wedding_band\Slip under\Slip_under_7.jpg
# Labels for Slip_under_7.jpg: white, engagement ring, body jewelry, ring, pre-engagement ring, diamond, natural material, silver, platinum, wedding ring
# Error downloading or verifying image: cannot identify image file <_io.BytesIO object at 0x0000016C70CBCA40> - URL: https://lookaside.instagram.com/seo/google_widget/crawler/?media_id=3552001846803290218
# Image saved: shink_design_wedding_band\Slip under\Slip_under_8.jpg
# Labels for Slip_under_8.jpg: white, ring, engagement ring, pre-engagement ring, natural material, silver, body jewelry, diamond, platinum, wedding ring
# Fetching images for Open...
# Image saved: shink_design_wedding_band\Open\Open_1.jpg
# Labels for Open_1.jpg: engagement ring, jewellery, gemstone, body jewelry, diamond, ring, crystal, wedding ring, pre-engagement ring, mineral
# Image saved: shink_design_wedding_band\Open\Open_2.jpg
# Labels for Open_2.jpg: engagement ring, jewellery, ring, fashion, finger, gemstone, wedding ring, body jewelry, pre-engagement ring, nail
# Failed to download image: https://sundayislandjewelry.com/wp-content/uploads/2022/07/Vintage-Inspired-Open-Wedding-Band-Dawn-5.jpg (Status Code: 403)
# Image saved: shink_design_wedding_band\Open\Open_3.jpg
# Labels for Open_3.jpg: jewellery, engagement ring, finger, ring, fashion, body jewelry, gemstone, wedding ring, nail, wedding ceremony supply
# Image saved: shink_design_wedding_band\Open\Open_4.jpg
# Labels for Open_4.jpg: jewellery, engagement ring, gemstone, body jewelry, ring, diamond, wedding ring, pre-engagement ring, natural material, crystal
# Image saved: shink_design_wedding_band\Open\Open_5.jpg
# Labels for Open_5.jpg: engagement ring, ring, body jewelry, jewellery, wedding ring, pre-engagement ring, wedding ceremony supply, gemstone, natural material, nail
# Image saved: shink_design_wedding_band\Open\Open_6.jpg
# Labels for Open_6.jpg: engagement ring, ring, body jewelry, jewellery, wedding ceremony supply, wedding ring, pre-engagement ring, natural material, diamond, silver
# Image saved: shink_design_wedding_band\Open\Open_7.jpg
# Labels for Open_7.jpg: engagement ring, gemstone, ring, jewellery, body jewelry, diamond, wedding ring, pre-engagement ring, wedding ceremony supply, natural material
# Image saved: shink_design_wedding_band\Open\Open_8.jpg
# Labels for Open_8.jpg: engagement ring, gemstone, jewellery, body jewelry, ring, finger, wedding ring, diamond, pre-engagement ring, wedding ceremony supply
# Image saved: shink_design_wedding_band\Open\Open_9.jpg
# Labels for Open_9.jpg: jewellery, engagement ring, ring, body jewelry, gemstone, fashion, crystal, wedding ring, wedding ceremony supply, diamond
# Fetching images for Notched...
# Image saved: shink_design_wedding_band\Notched\Notched_1.jpg
# Labels for Notched_1.jpg: jewellery, engagement ring, ring, gemstone, body jewelry, wedding ring, wedding ceremony supply, diamond, pre-engagement ring, crystal
# Image saved: shink_design_wedding_band\Notched\Notched_2.jpg
# Labels for Notched_2.jpg: engagement ring, body jewelry, gemstone, pre-engagement ring, ring, wedding ring, diamond, natural material, platinum, silver
# Image saved: shink_design_wedding_band\Notched\Notched_3.jpg
# Labels for Notched_3.jpg: body jewelry, engagement ring, jewellery, diamond, ring, gemstone, pre-engagement ring, natural material, wedding ring, platinum
# Image saved: shink_design_wedding_band\Notched\Notched_4.jpg
# Labels for Notched_4.jpg: engagement ring, ring, jewellery, wedding ring, pre-engagement ring, wedding ceremony supply, diamond, gemstone, body jewelry, natural material
# Failed to download image: https://www.kayoutlet.com/productimages/processed/V-994763528_0_800.jpg?pristine=true (Status Code: 403)
# Image saved: shink_design_wedding_band\Notched\Notched_5.jpg
# Labels for Notched_5.jpg: body jewelry, jewellery, engagement ring, diamond, ring, gemstone, pre-engagement ring, natural material, wedding ring, platinum
# Image saved: shink_design_wedding_band\Notched\Notched_6.jpg
# Labels for Notched_6.jpg: jewellery, engagement ring, ring, gemstone, wedding ceremony supply, body jewelry, diamond, wedding ring, pre-engagement ring, silver
# Image saved: shink_design_wedding_band\Notched\Notched_7.jpg
# Labels for Notched_7.jpg: engagement ring, body jewelry, gemstone, ring, wedding ring, pre-engagement ring, jewellery, diamond, natural material, platinum
# Image saved: shink_design_wedding_band\Notched\Notched_8.jpg
# Labels for Notched_8.jpg: jewellery, engagement ring, body jewelry, gemstone, ring, wedding ceremony supply, wedding ring, silver, diamond, natural material
# Image saved: shink_design_wedding_band\Notched\Notched_9.jpg
# Labels for Notched_9.jpg: finger, engagement ring, ring, nail care, body jewelry, nail, jewellery, wedding ring, gemstone, pre-engagement ring
# Fetching images for Square Notched...
# Image saved: shink_design_wedding_band\Square Notched\Square_Notched_1.jpg
# Labels for Square_Notched_1.jpg: gemstone, silver, diamond, natural material, ring, platinum, body jewelry, engagement ring, design, pre-engagement ring
# Image saved: shink_design_wedding_band\Square Notched\Square_Notched_2.jpg
# Labels for Square_Notched_2.jpg: engagement ring, diamond, gemstone, body jewelry, pre-engagement ring, wedding ring, ring, platinum, crystal, natural material
# Image saved: shink_design_wedding_band\Square Notched\Square_Notched_3.jpg
# Labels for Square_Notched_3.jpg: body jewelry, jewellery, engagement ring, diamond, ring, gemstone, pre-engagement ring, natural material, wedding ring, platinum
# Image saved: shink_design_wedding_band\Square Notched\Square_Notched_4.jpg
# Labels for Square_Notched_4.jpg: natural material, diamond
# Image saved: shink_design_wedding_band\Square Notched\Square_Notched_5.jpg
# Labels for Square_Notched_5.jpg: jewellery, engagement ring, pre-engagement ring, ring, diamond, body jewelry, natural material, gemstone, wedding ring, platinum
# Image saved: shink_design_wedding_band\Square Notched\Square_Notched_6.jpg
# Labels for Square_Notched_6.jpg: body jewelry, metal, ring, engagement ring, silver, natural material, platinum, diamond, pre-engagement ring, silver
# Image saved: shink_design_wedding_band\Square Notched\Square_Notched_7.jpg
# Labels for Square_Notched_7.jpg: body jewelry, engagement ring, jewellery, diamond, ring, gemstone, pre-engagement ring, natural material, wedding ring, platinum
# Failed to download image: https://www.kay.com/productimages/processed/V-360622221_3_800.jpg?pristine=true (Status Code: 403)
# Image saved: shink_design_wedding_band\Square Notched\Square_Notched_8.jpg
# Labels for Square_Notched_8.jpg: white, body jewelry, engagement ring, jewellery, diamond, ring, gemstone, pre-engagement ring, platinum, silver
# Image saved: shink_design_wedding_band\Square Notched\Square_Notched_9.jpg
# Labels for Square_Notched_9.jpg: engagement ring, body jewelry, jewellery, ring, pre-engagement ring, silver, natural material, wedding ring, wedding ceremony supply, platinum
# Fetching images for Scalloped...
# Image saved: shink_design_wedding_band\Scalloped\Scalloped_1.jpg
# Labels for Scalloped_1.jpg: engagement ring, ring, jewellery, pre-engagement ring, body jewelry, wedding ceremony supply, wedding ring, gemstone, diamond, natural material
# Image saved: shink_design_wedding_band\Scalloped\Scalloped_2.jpg
# Labels for Scalloped_2.jpg: wedding ceremony supply, gemstone, pre-engagement ring, ring, engagement ring, diamond, natural material, silver, wedding ring, body jewelry
# Image saved: shink_design_wedding_band\Scalloped\Scalloped_3.jpg
# Labels for Scalloped_3.jpg: ring, jewellery, body jewelry, wedding ceremony supply, gemstone, pre-engagement ring, wedding ring, engagement ring, natural material, silver
# Image saved: shink_design_wedding_band\Scalloped\Scalloped_4.jpg
# Labels for Scalloped_4.jpg: engagement ring, ring, fashion, jewellery, gemstone, body jewelry, wedding ring, pre-engagement ring, wedding ceremony supply, diamond
# Image saved: shink_design_wedding_band\Scalloped\Scalloped_5.jpg
# Labels for Scalloped_5.jpg: engagement ring, gemstone, ring, body jewelry, pre-engagement ring, wedding ceremony supply, jewellery, wedding ring, diamond, natural material
# Image saved: shink_design_wedding_band\Scalloped\Scalloped_6.jpg
# Labels for Scalloped_6.jpg: engagement ring, ring, gemstone, fashion, jewellery, body jewelry, wedding ring, wedding ceremony supply, diamond, pre-engagement ring
# Image saved: shink_design_wedding_band\Scalloped\Scalloped_7.jpg
# Labels for Scalloped_7.jpg: dessert, natural material, recipe, comfort food, baking, wedding ceremony supply
# Image saved: shink_design_wedding_band\Scalloped\Scalloped_8.jpg
# Labels for Scalloped_8.jpg: ring, engagement ring, jewellery, gemstone, body jewelry, wedding ring, pre-engagement ring, diamond, crystal, jewelry making
# Image saved: shink_design_wedding_band\Scalloped\Scalloped_9.jpg
# Labels for Scalloped_9.jpg: fashion, jewellery, wedding ceremony supply, ring, engagement ring, body jewelry, gemstone, diamond, natural material, silver
# Image saved: shink_design_wedding_band\Scalloped\Scalloped_10.jpg
# Labels for Scalloped_10.jpg: engagement ring, fashion, gemstone, ring, jewellery, body jewelry, wedding ring, pre-engagement ring, diamond, natural material
# Fetching images for Milgrain...
# Image saved: shink_design_wedding_band\Milgrain\Milgrain_1.jpg
# Labels for Milgrain_1.jpg: gemstone, crystal, body jewelry, engagement ring, diamond, jewellery, ring, pre-engagement ring, sapphire, wedding ceremony supply
# Image saved: shink_design_wedding_band\Milgrain\Milgrain_2.jpg
# Labels for Milgrain_2.jpg: gemstone, ring, diamond, silver, crystal, body jewelry, natural material, engagement ring, wedding ceremony supply, pre-engagement ring
# c:\Users\TechAir\anaconda3\envs\webscrapping\lib\site-packages\PIL\Image.py:1045: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Image saved: shink_design_wedding_band\Milgrain\Milgrain_3.jpg
# Labels for Milgrain_3.jpg: silver, wedding ring, ring, pre-engagement ring, platinum, titanium ring, silver, still life photography, engagement ring, titanium
# Image saved: shink_design_wedding_band\Milgrain\Milgrain_4.jpg
# Labels for Milgrain_4.jpg: pre-engagement ring
# Image saved: shink_design_wedding_band\Milgrain\Milgrain_5.jpg
# Labels for Milgrain_5.jpg:
# Image saved: shink_design_wedding_band\Milgrain\Milgrain_6.jpg
# Labels for Milgrain_6.jpg: ring, wedding ring, silver, metal, pre-engagement ring, natural material, titanium ring, engagement ring, diamond, titanium
# Image saved: shink_design_wedding_band\Milgrain\Milgrain_7.jpg
# Labels for Milgrain_7.jpg:
# Image saved: shink_design_wedding_band\Milgrain\Milgrain_8.jpg
# Labels for Milgrain_8.jpg: bangle, ring, metal, body jewelry, natural material, wedding ring, gold, pre-engagement ring, wedding ceremony supply, bracelet
# Image saved: shink_design_wedding_band\Milgrain\Milgrain_9.jpg
# Labels for Milgrain_9.jpg: ring, wedding ring, pre-engagement ring, silver, engagement ring, metal, body jewelry, titanium ring, platinum, wedding ceremony supply
# Image saved: shink_design_wedding_band\Milgrain\Milgrain_10.jpg
# Labels for Milgrain_10.jpg: ring, engagement ring, wedding ring, pre-engagement ring, body jewelry, wedding ceremony supply, silver, natural material, bangle, diamond
# Fetching images for Engraved...
# Image saved: shink_design_wedding_band\Engraved\Engraved_1.jpg
# Labels for Engraved_1.jpg: ring, engagement ring, jewellery, fashion, wedding ring, wedding ceremony supply, body jewelry, gemstone, diamond, brown
# Image saved: shink_design_wedding_band\Engraved\Engraved_2.jpg
# Labels for Engraved_2.jpg:
# Image saved: shink_design_wedding_band\Engraved\Engraved_3.jpg
# Labels for Engraved_3.jpg: engagement ring, diamond, pre-engagement ring, wedding ring, silver, natural material, platinum, ring, titanium ring, silver
# Image saved: shink_design_wedding_band\Engraved\Engraved_4.jpg
# Labels for Engraved_4.jpg: natural material, wedding ceremony supply, pre-engagement ring, gold, diamond, ring, body jewelry
# Image saved: shink_design_wedding_band\Engraved\Engraved_5.jpg
# Labels for Engraved_5.jpg: ring, engagement ring, jewellery, wedding ring, body jewelry, pre-engagement ring, wedding ceremony supply, gemstone, diamond, natural material
# Image saved: shink_design_wedding_band\Engraved\Engraved_6.jpg
# Labels for Engraved_6.jpg: engagement ring, ring, jewellery, fashion, wedding ring, body jewelry, finger, wedding ceremony supply, gemstone, diamond
# Image saved: shink_design_wedding_band\Engraved\Engraved_7.jpg
# Labels for Engraved_7.jpg: yellow, wedding ring, engagement ring, ring, pre-engagement ring, bangle, gold, gold, metal, diamond
# Image saved: shink_design_wedding_band\Engraved\Engraved_8.jpg
# Labels for Engraved_8.jpg: engagement ring, gemstone, natural material, body jewelry, wedding ring, ring, diamond, pre-engagement ring, wedding ceremony supply, still life photography
# Image saved: shink_design_wedding_band\Engraved\Engraved_9.jpg
# Labels for Engraved_9.jpg: engagement ring, wedding ring, diamond, ring, pre-engagement ring, silver, titanium ring, natural material, gemstone, platinum
# Image saved: shink_design_wedding_band\Engraved\Engraved_10.jpg
# Labels for Engraved_10.jpg: engagement ring, ring, body jewelry, wedding ring, wedding ceremony supply, pre-engagement ring, gemstone, jewellery, diamond, natural material
# Fetching images for Classic...
# Image saved: shink_design_wedding_band\Classic\Classic_1.jpg
# Labels for Classic_1.jpg: ring, jewellery, engagement ring, wedding ring, fashion, wedding ceremony supply, body jewelry, pre-engagement ring, silver, diamond
# Image saved: shink_design_wedding_band\Classic\Classic_2.jpg
# Labels for Classic_2.jpg: yellow, ring, wedding ring, bangle, wedding ceremony supply, jewellery, pre-engagement ring, metal, engagement ring, natural material
# Image saved: shink_design_wedding_band\Classic\Classic_3.jpg
# Labels for Classic_3.jpg: engagement ring, ring, wedding ring, diamond, pre-engagement ring, body jewelry, wedding ceremony supply, gemstone, natural material, gold
# Image saved: shink_design_wedding_band\Classic\Classic_4.jpg
# Labels for Classic_4.jpg: ring, engagement ring, wedding ring, pre-engagement ring, metal, natural material, body jewelry, wedding ceremony supply, bangle, diamond
# Image saved: shink_design_wedding_band\Classic\Classic_5.jpg
# Labels for Classic_5.jpg: jewellery, engagement ring, body jewelry, gemstone, diamond, pre-engagement ring, ring, wedding ring, crystal, natural material
# Image saved: shink_design_wedding_band\Classic\Classic_6.jpg
# Labels for Classic_6.jpg: engagement ring, ring, gemstone, wedding ring, diamond, wedding ceremony supply, pre-engagement ring, jewellery, body jewelry, natural material
# Image saved: shink_design_wedding_band\Classic\Classic_7.jpg
# Labels for Classic_7.jpg: jewellery, engagement ring, body jewelry, gemstone, diamond, ring, pre-engagement ring, wedding ring, natural material, crystal
# Image saved: shink_design_wedding_band\Classic\Classic_8.jpg
# Labels for Classic_8.jpg: ring, natural material, body jewelry, pre-engagement ring, engagement ring, wedding ring, wedding ceremony supply, platinum, titanium ring
# Image saved: shink_design_wedding_band\Classic\Classic_9.jpg
# Labels for Classic_9.jpg: white, engagement ring, diamond, pre-engagement ring, wedding ceremony supply, silver, platinum, natural material, body jewelry, wedding ring
# Image saved: shink_design_wedding_band\Classic\Classic_10.jpg
# Labels for Classic_10.jpg: ring, jewellery, engagement ring, wedding ring, body jewelry, pre-engagement ring, diamond, metal, wedding ceremony supply, gemstone
# Fetching images for Flat...
# Image saved: shink_design_wedding_band\Flat\Flat_1.jpg
# Labels for Flat_1.jpg: engagement ring, ring, jewellery, diamond, wedding ring, pre-engagement ring, wedding ceremony supply, titanium ring, gemstone, natural material
# Image saved: shink_design_wedding_band\Flat\Flat_2.jpg
# Labels for Flat_2.jpg: engagement ring, ring, jewellery, fashion, body jewelry, gemstone, wedding ring, wedding ceremony supply, diamond, pre-engagement ring
# Image saved: shink_design_wedding_band\Flat\Flat_3.jpg
# Labels for Flat_3.jpg: engagement ring, ring, jewellery, wedding ring, fashion, gemstone, body jewelry, diamond, wedding ceremony supply, pre-engagement ring
# Image saved: shink_design_wedding_band\Flat\Flat_4.jpg
# Labels for Flat_4.jpg: engagement ring, ring, jewellery, diamond, wedding ring, pre-engagement ring, wedding ceremony supply, titanium ring, gemstone, natural material
# Image saved: shink_design_wedding_band\Flat\Flat_5.jpg
# Labels for Flat_5.jpg: ring, engagement ring, jewellery, body jewelry, wedding ring, wedding ceremony supply, pre-engagement ring, natural material, gemstone, diamond
# Image saved: shink_design_wedding_band\Flat\Flat_6.jpg
# Labels for Flat_6.jpg: blue, jewellery, gemstone, ring, natural material, body jewelry, pre-engagement ring, diamond, titanium ring, engagement ring
# Image saved: shink_design_wedding_band\Flat\Flat_7.jpg
# Labels for Flat_7.jpg: engagement ring, ring, jewellery, fashion, body jewelry, wedding ring, gemstone, wedding ceremony supply, diamond, pre-engagement ring
# Image saved: shink_design_wedding_band\Flat\Flat_8.jpg
# Labels for Flat_8.jpg: engagement ring, ring, jewellery, wedding ring, diamond, gemstone, body jewelry, pre-engagement ring, natural material, wedding ceremony supply
# Failed to download image: https://www.barkevs.com/themes/bliss/assets/wedding-bands/8121_2mm/shapes/round/8121_2mm-whitegold_platinum_round_default.jpg (Status Code: 403)
# Image saved: shink_design_wedding_band\Flat\Flat_9.jpg
# Labels for Flat_9.jpg: ring, jewellery, engagement ring, wedding ring, diamond, body jewelry, natural material, pre-engagement ring, gemstone, wedding ceremony supply
# Fetching images for Flat Edge...
# Image saved: shink_design_wedding_band\Flat Edge\Flat_Edge_1.jpg
# Labels for Flat_Edge_1.jpg: ring, jewellery, fashion, engagement ring, body jewelry, wedding ring, wedding ceremony supply, pre-engagement ring, natural material, silver
# Image saved: shink_design_wedding_band\Flat Edge\Flat_Edge_2.jpg
# Labels for Flat_Edge_2.jpg: engagement ring, jewellery, ring, wedding ring, pre-engagement ring, wedding ceremony supply, metal, natural material, silver, diamond
# Image saved: shink_design_wedding_band\Flat Edge\Flat_Edge_3.jpg
# Labels for Flat_Edge_3.jpg: engagement ring, ring, wedding ring, pre-engagement ring, wedding ceremony supply, diamond, metal, natural material, silver, titanium ring
# Image saved: shink_design_wedding_band\Flat Edge\Flat_Edge_4.jpg
# Labels for Flat_Edge_4.jpg: ring, engagement ring, jewellery, fashion, wedding ring, body jewelry, wedding ceremony supply, pre-engagement ring, diamond, gemstone
# Image saved: shink_design_wedding_band\Flat Edge\Flat_Edge_5.jpg
# Labels for Flat_Edge_5.jpg: ring, body jewelry, wedding ring, jewellery, engagement ring, pre-engagement ring, bangle, natural material, wedding ceremony supply, silver
# Image saved: shink_design_wedding_band\Flat Edge\Flat_Edge_6.jpg
# Labels for Flat_Edge_6.jpg: jewellery, fashion, ring, engagement ring, body jewelry, bracelet, wedding ring, wedding ceremony supply, natural material, pre-engagement ring
# Image saved: shink_design_wedding_band\Flat Edge\Flat_Edge_7.jpg
# Labels for Flat_Edge_7.jpg: ring, jewellery, fashion, finger, engagement ring, wedding ceremony supply, wedding ring, body jewelry, pre-engagement ring, natural material
# Image saved: shink_design_wedding_band\Flat Edge\Flat_Edge_8.jpg
# Labels for Flat_Edge_8.jpg: ring, engagement ring, wedding ring, jewellery, pre-engagement ring, wedding ceremony supply, body jewelry, natural material, silver, gold
# Image saved: shink_design_wedding_band\Flat Edge\Flat_Edge_9.jpg
# Labels for Flat_Edge_9.jpg: ring, wedding ring, natural material, metal, pre-engagement ring, silver, titanium ring, engagement ring, platinum, silver
# Image saved: shink_design_wedding_band\Flat Edge\Flat_Edge_10.jpg
# Labels for Flat_Edge_10.jpg: ring, wedding ring, wedding ceremony supply, pre-engagement ring, metal, body jewelry, natural material, bangle, silver, gold
# Fetching images for Round Band...
# Image saved: shink_design_wedding_band\Round Band\Round_Band_1.jpg
# Labels for Round_Band_1.jpg:
# Image saved: shink_design_wedding_band\Round Band\Round_Band_2.jpg
# Labels for Round_Band_2.jpg: jewellery, ring, engagement ring, gemstone, body jewelry, fashion, crystal, wedding ring, diamond, wedding ceremony supply
# Image saved: shink_design_wedding_band\Round Band\Round_Band_3.jpg
# Labels for Round_Band_3.jpg: gemstone, ring, natural material, diamond, pre-engagement ring, wedding ceremony supply, engagement ring, body jewelry, wedding ring
# Image saved: shink_design_wedding_band\Round Band\Round_Band_4.jpg
# Labels for Round_Band_4.jpg: wedding ceremony supply, diamond, engagement ring, wedding ring, pre-engagement ring, gemstone, natural material, crystal, gold, ring
# Image saved: shink_design_wedding_band\Round Band\Round_Band_5.jpg
# Labels for Round_Band_5.jpg: engagement ring, body jewelry, gemstone, diamond, pre-engagement ring, natural material, wedding ring, ring, wedding ceremony supply, platinum
# Image saved: shink_design_wedding_band\Round Band\Round_Band_6.jpg
# Labels for Round_Band_6.jpg: yellow, gemstone, diamond, body jewelry, engagement ring, wedding ceremony supply, natural material, pre-engagement ring, wedding ring, ring
# Image saved: shink_design_wedding_band\Round Band\Round_Band_7.jpg
# Labels for Round_Band_7.jpg: wedding ceremony supply, engagement ring, gemstone, diamond, body jewelry, natural material, ring, pre-engagement ring, wedding ring, silver
# Image saved: shink_design_wedding_band\Round Band\Round_Band_8.jpg
# Labels for Round_Band_8.jpg: engagement ring, jewellery, ring, body jewelry, gemstone, diamond, wedding ring, pre-engagement ring, natural material, crystal
# Image saved: shink_design_wedding_band\Round Band\Round_Band_9.jpg
# Labels for Round_Band_9.jpg: jewellery, engagement ring, body jewelry, gemstone, ring, natural material, diamond, wedding ring, wedding ceremony supply, pre-engagement ring
# Image saved: shink_design_wedding_band\Round Band\Round_Band_10.jpg
# Labels for Round_Band_10.jpg: jewellery, ring, engagement ring, gemstone, fashion, wedding ring, body jewelry, wedding ceremony supply, diamond, crystal
# Fetching images for Wide Band...
# Image saved: shink_design_wedding_band\Wide Band\Wide_Band_1.jpg
# Labels for Wide_Band_1.jpg: jewellery, ring, engagement ring, body jewelry, gemstone, wedding ring, wedding ceremony supply, pre-engagement ring, diamond, natural material
# Image saved: shink_design_wedding_band\Wide Band\Wide_Band_2.jpg
# Labels for Wide_Band_2.jpg: ring, engagement ring, jewellery, fashion, wedding ring, gemstone, body jewelry, wedding ceremony supply, diamond, pre-engagement ring
# Image saved: shink_design_wedding_band\Wide Band\Wide_Band_3.jpg
# Labels for Wide_Band_3.jpg: blue, gemstone, ring, engagement ring, body jewelry, jewellery, natural material, watch, pre-engagement ring, diamond
# Image saved: shink_design_wedding_band\Wide Band\Wide_Band_4.jpg
# Labels for Wide_Band_4.jpg: finger, jewellery, fashion, ring, nail, nail care, engagement ring, body jewelry, thumb, wedding ring
# Image saved: shink_design_wedding_band\Wide Band\Wide_Band_5.jpg
# Labels for Wide_Band_5.jpg: engagement ring, diamond, wedding ceremony supply, gemstone, pre-engagement ring, ring, natural material, body jewelry, wedding ring, platinum
# Image saved: shink_design_wedding_band\Wide Band\Wide_Band_6.jpg
# Labels for Wide_Band_6.jpg: fashion, finger, gemstone, engagement ring, diamond, watch, natural material, body jewelry, silver, nail
# Image saved: shink_design_wedding_band\Wide Band\Wide_Band_7.jpg
# Labels for Wide_Band_7.jpg: ring, engagement ring, jewellery, wedding ring, body jewelry, pre-engagement ring, metal, bangle, natural material, gold
# Image saved: shink_design_wedding_band\Wide Band\Wide_Band_8.jpg
# Labels for Wide_Band_8.jpg: ring, engagement ring, jewellery, diamond, wedding ceremony supply, natural material, wedding ring, metal, pre-engagement ring, body jewelry
# Image saved: shink_design_wedding_band\Wide Band\Wide_Band_9.jpg
# Labels for Wide_Band_9.jpg: natural material, pre-engagement ring, diamond, engagement ring, wedding ring, platinum
# Image saved: shink_design_wedding_band\Wide Band\Wide_Band_10.jpg
# Labels for Wide_Band_10.jpg: white, diamond, gemstone, engagement ring, silver, pre-engagement ring, natural material, crystal, platinum, mineral
# Fetching images for Thick Band...
# Image saved: shink_design_wedding_band\Thick Band\Thick_Band_1.jpg
# Labels for Thick_Band_1.jpg: fashion, finger, gemstone, engagement ring, diamond, watch, natural material, body jewelry, silver, nail
# Image saved: shink_design_wedding_band\Thick Band\Thick_Band_2.jpg
# Labels for Thick_Band_2.jpg: jewellery, ring, engagement ring, body jewelry, gemstone, wedding ring, wedding ceremony supply, pre-engagement ring, diamond, natural material
# Image saved: shink_design_wedding_band\Thick Band\Thick_Band_3.jpg
# Labels for Thick_Band_3.jpg: gemstone, diamond, engagement ring, natural material, pre-engagement ring, wedding ceremony supply, crystal, wedding ring, gold, mineral
# Image saved: shink_design_wedding_band\Thick Band\Thick_Band_4.jpg
# Labels for Thick_Band_4.jpg: fashion, finger, beauty, engagement ring, nail polish, nail care, gemstone, nail, diamond, cosmetics
# Image saved: shink_design_wedding_band\Thick Band\Thick_Band_5.jpg
# Labels for Thick_Band_5.jpg: engagement ring, gemstone, diamond, wedding ceremony supply, wedding ring, ring, jewellery, crystal, pre-engagement ring, body jewelry
# Image saved: shink_design_wedding_band\Thick Band\Thick_Band_6.jpg
# Labels for Thick_Band_6.jpg: fashion, finger, beauty, engagement ring, gemstone, nail polish, nail care, nail, diamond, ring
# Image saved: shink_design_wedding_band\Thick Band\Thick_Band_7.jpg
# Labels for Thick_Band_7.jpg: white, engagement ring, ring, diamond, wedding ring, gemstone, pre-engagement ring, jewellery, natural material, platinum
# Image saved: shink_design_wedding_band\Thick Band\Thick_Band_8.jpg
# Labels for Thick_Band_8.jpg: ring, engagement ring, jewellery, fashion, wedding ring, gemstone, body jewelry, wedding ceremony supply, diamond, pre-engagement ring
# Image saved: shink_design_wedding_band\Thick Band\Thick_Band_9.jpg
# Labels for Thick_Band_9.jpg: ring, engagement ring, jewellery, body jewelry, wedding ring, wedding ceremony supply, gemstone, pre-engagement ring, diamond, natural material
# Image saved: shink_design_wedding_band\Thick Band\Thick_Band_10.jpg
# Labels for Thick_Band_10.jpg: ring, engagement ring, jewellery, wedding ring, body jewelry, pre-engagement ring, metal, bangle, natural material, gold
# Fetching images for Thin Band...
# Image saved: shink_design_wedding_band\Thin Band\Thin_Band_1.jpg
# Labels for Thin_Band_1.jpg: blue, natural material, gemstone
# Image saved: shink_design_wedding_band\Thin Band\Thin_Band_2.jpg
# Labels for Thin_Band_2.jpg: gemstone, body jewelry, jewellery, diamond, engagement ring, natural material, pre-engagement ring, ring, wedding ceremony supply, mineral
# Image saved: shink_design_wedding_band\Thin Band\Thin_Band_3.jpg
# Labels for Thin_Band_3.jpg: engagement ring, gemstone, jewellery, body jewelry, fashion, crystal, diamond, ring, wedding ring, pre-engagement ring
# Image saved: shink_design_wedding_band\Thin Band\Thin_Band_4.jpg
# Labels for Thin_Band_4.jpg: natural material, gemstone, body jewelry, titanium, pre-engagement ring
# Image saved: shink_design_wedding_band\Thin Band\Thin_Band_5.jpg
# Labels for Thin_Band_5.jpg: ring, wedding ring, pre-engagement ring, wedding ceremony supply, natural material, silver, engagement ring, body jewelry, copper, hardwood
# Image saved: shink_design_wedding_band\Thin Band\Thin_Band_6.jpg
# Labels for Thin_Band_6.jpg: nail care, finger, fashion, nail polish, engagement ring, jewellery, ring, gemstone, nail, body jewelry
# Image saved: shink_design_wedding_band\Thin Band\Thin_Band_7.jpg
# Labels for Thin_Band_7.jpg:
# Image saved: shink_design_wedding_band\Thin Band\Thin_Band_8.jpg
# Labels for Thin_Band_8.jpg: jewellery, ring, body jewelry, engagement ring, gemstone, wedding ring, pre-engagement ring, diamond, wedding ceremony supply, bangle
# Image saved: shink_design_wedding_band\Thin Band\Thin_Band_9.jpg
# Labels for Thin_Band_9.jpg: blue, gemstone, natural material
# Image saved: shink_design_wedding_band\Thin Band\Thin_Band_10.jpg
# Labels for Thin_Band_10.jpg: engagement ring, fashion, gemstone, body jewelry, ring, wedding ring, diamond, pre-engagement ring, wedding ceremony supply, natural material
# Fetching images for Knife Edge...
# Image saved: shink_design_wedding_band\Knife Edge\Knife_Edge_1.jpg
# Labels for Knife_Edge_1.jpg: natural material, silver, ring, pre-engagement ring, diamond, body jewelry, silver, wedding ring, engagement ring, gemstone
# Image saved: shink_design_wedding_band\Knife Edge\Knife_Edge_2.jpg
# Labels for Knife_Edge_2.jpg: ring, engagement ring, jewellery, wedding ring, wedding ceremony supply, diamond, body jewelry, pre-engagement ring, natural material, bangle
# Image saved: shink_design_wedding_band\Knife Edge\Knife_Edge_3.jpg
# Labels for Knife_Edge_3.jpg: white, engagement ring, jewellery, ring, body jewelry, gemstone, diamond, wedding ring, pre-engagement ring, natural material
# Image saved: shink_design_wedding_band\Knife Edge\Knife_Edge_4.jpg
# Labels for Knife_Edge_4.jpg: ring, wedding ring, pre-engagement ring, body jewelry, engagement ring, watch, natural material, titanium ring, metal, platinum
# Image saved: shink_design_wedding_band\Knife Edge\Knife_Edge_5.jpg
# Labels for Knife_Edge_5.jpg: ring, engagement ring, wedding ring, wedding ceremony supply, pre-engagement ring, bangle, jewellery, diamond, gold, metal
# Image saved: shink_design_wedding_band\Knife Edge\Knife_Edge_6.jpg
# Labels for Knife_Edge_6.jpg: engagement ring, ring, jewellery, wedding ring, gemstone, body jewelry, wedding ceremony supply, pre-engagement ring, diamond, natural material
# Image saved: shink_design_wedding_band\Knife Edge\Knife_Edge_7.jpg
# ...
# Labels for Bypass_5.jpg: engagement ring, ring, gemstone, body jewelry, diamond, pre-engagement ring, wedding ring, jewellery, natural material, metal
# Image saved: shink_design_wedding_band\Bypass\Bypass_6.jpg
# Labels for Bypass_6.jpg: engagement ring, jewellery, fashion, ring, body jewelry, wedding ring, gemstone, diamond, natural material, wedding ceremony supply
# Image saved: shink_design_wedding_band\Bypass\Bypass_7.jpg
# Labels for Bypass_7.jpg: engagement ring, wedding ring, body jewelry, jewellery, diamond, ring, pre-engagement ring, wedding ceremony supply, gemstone, platinum
# Image saved: shink_design_wedding_band\Bypass\Bypass_8.jpg
# Labels for Bypass_8.jpg: engagement ring, ring, wedding ring, pre-engagement ring, wedding ceremony supply, diamond, silver, body jewelry, gemstone, platinum
# Failed to download image: https://www.zales.com/productimages/processed/V-20319318_0_800.jpg?pristine=true (Status Code: 403)
# Image saved: shink_design_wedding_band\Bypass\Bypass_9.jpg
# Labels for Bypass_9.jpg: platinum
# Fetching images for Triple band...
# Image saved: shink_design_wedding_band\Triple band\Triple_band_1.jpg
# Labels for Triple_band_1.jpg: natural material, wedding ceremony supply, pre-engagement ring
# Image saved: shink_design_wedding_band\Triple band\Triple_band_2.jpg
# Labels for Triple_band_2.jpg: engagement ring, gemstone, diamond, crystal, natural material, pre-engagement ring, jewellery, body jewelry, silver, wedding ring
# Image saved: shink_design_wedding_band\Triple band\Triple_band_3.jpg
# Labels for Triple_band_3.jpg: engagement ring, ring, wedding ring, wedding ceremony supply, diamond, pre-engagement ring, jewellery, silver, natural material, gemstone
# Image saved: shink_design_wedding_band\Triple band\Triple_band_4.jpg
# Labels for Triple_band_4.jpg: engagement ring, ring, wedding ring, gemstone, wedding ceremony supply, diamond, pre-engagement ring, silver, natural material, crystal
# Image saved: shink_design_wedding_band\Triple band\Triple_band_5.jpg
# Labels for Triple_band_5.jpg: engagement ring, diamond, silver, natural material, wedding ring, pre-engagement ring, wedding ceremony supply, gemstone, ring, platinum
# Image saved: shink_design_wedding_band\Triple band\Triple_band_6.jpg
# Labels for Triple_band_6.jpg: engagement ring, pre-engagement ring, wedding ring, ring, diamond, natural material, gold, gemstone, wedding ceremony supply, mineral
# Image saved: shink_design_wedding_band\Triple band\Triple_band_7.jpg
# Labels for Triple_band_7.jpg: white, engagement ring, diamond, natural material, silver, pre-engagement ring, gemstone, wedding ring, ring, platinum
# Image saved: shink_design_wedding_band\Triple band\Triple_band_8.jpg
# Labels for Triple_band_8.jpg: jewellery, ring, engagement ring, finger, fashion, body jewelry, gemstone, wedding ring, wedding ceremony supply, nail care
# Image saved: shink_design_wedding_band\Triple band\Triple_band_9.jpg
# Labels for Triple_band_9.jpg: engagement ring, gemstone, fashion, crystal, diamond, jewellery, wedding ring, body jewelry, pre-engagement ring, natural material
# Image saved: shink_design_wedding_band\Triple band\Triple_band_10.jpg
# Labels for Triple_band_10.jpg: ring, jewellery, engagement ring, fashion, body jewelry, diamond, wedding ring, pre-engagement ring, natural material, gemstone
# Fetching images for Filigree...
# Image saved: shink_design_wedding_band\Filigree\Filigree_1.jpg
# Labels for Filigree_1.jpg:
# Image saved: shink_design_wedding_band\Filigree\Filigree_2.jpg
# Labels for Filigree_2.jpg: engagement ring, wedding ring, pre-engagement ring, diamond, ring, silver, body jewelry, natural material, platinum, wedding ceremony supply
# Image saved: shink_design_wedding_band\Filigree\Filigree_3.jpg
# Labels for Filigree_3.jpg: silver, natural material, ring, pre-engagement ring, platinum, silver, wedding ring, diamond, engagement ring, body jewelry
# Failed to download image: https://jewelrydesigns.com/wp-content/uploads/WD321-1-wide-filigree-wedding-ring.jpg (Status Code: 403)
# Image saved: shink_design_wedding_band\Filigree\Filigree_4.jpg
# Labels for Filigree_4.jpg: blue, natural material, silver, pre-engagement ring, diamond, gemstone, platinum, silver
# Failed to download image: https://jewelrydesigns.com/wp-content/uploads/WD268-1-open-heart-filigree-wedding-ring.jpg (Status Code: 403)
# Image saved: shink_design_wedding_band\Filigree\Filigree_5.jpg
# Labels for Filigree_5.jpg: gemstone, ring, body jewelry, diamond, pre-engagement ring, silver, engagement ring, wedding ceremony supply, wedding ring, metal
# Image saved: shink_design_wedding_band\Filigree\Filigree_6.jpg
# Labels for Filigree_6.jpg: natural material
# Failed to download image: https://www.valina.com/media/catalog/product/cache/582b03d09d6ba9e008f339e49594975c/v/a/valina-vintage-milgrain-filigree-accented-diamond-wedding-band-r1164bw.jpg (Status Code: 403)
# Image saved: shink_design_wedding_band\Filigree\Filigree_7.jpg
# Labels for Filigree_7.jpg: body jewelry, brown, jewellery, ring, gemstone, natural material, engagement ring, pre-engagement ring, wedding ring, diamond
# Fetching images for Vintage...
# Image saved: shink_design_wedding_band\Vintage\Vintage_1.jpg
# Labels for Vintage_1.jpg: pre-engagement ring, gemstone, natural material, diamond, engagement ring, body jewelry, ring, wedding ring, mineral
# Image saved: shink_design_wedding_band\Vintage\Vintage_2.jpg
# Labels for Vintage_2.jpg: engagement ring, diamond, wedding ceremony supply, gemstone, pre-engagement ring, wedding ring
# Image saved: shink_design_wedding_band\Vintage\Vintage_3.jpg
# Labels for Vintage_3.jpg: wedding ceremony supply, cake, natural material, pre-engagement ring, dessert, recipe, wedding ring, baking, silver, body jewelry
# Image saved: shink_design_wedding_band\Vintage\Vintage_4.jpg
# Labels for Vintage_4.jpg: engagement ring, jewellery, body jewelry, ring, diamond, pre-engagement ring, wedding ring, natural material, wedding ceremony supply, gemstone
# Image saved: shink_design_wedding_band\Vintage\Vintage_5.jpg
# Labels for Vintage_5.jpg: silver, natural material, design, diamond
# Image saved: shink_design_wedding_band\Vintage\Vintage_6.jpg
# Labels for Vintage_6.jpg: ruins, archaeological site
# Image saved: shink_design_wedding_band\Vintage\Vintage_7.jpg
# Labels for Vintage_7.jpg: wedding ceremony supply, gemstone, natural material, pre-engagement ring, body jewelry, diamond, ring, engagement ring, platinum
# Image saved: shink_design_wedding_band\Vintage\Vintage_8.jpg
# Labels for Vintage_8.jpg: wedding ceremony supply, ring, engagement ring, body jewelry, jewellery, gemstone, diamond, crystal, pre-engagement ring, wedding ring
# Image saved: shink_design_wedding_band\Vintage\Vintage_9.jpg
# Labels for Vintage_9.jpg: engagement ring, diamond, pre-engagement ring, ring, wedding ring, body jewelry, silver, wedding ceremony supply, metal, natural material
# Image saved: shink_design_wedding_band\Vintage\Vintage_10.jpg
# Labels for Vintage_10.jpg: ring, wedding ceremony supply, body jewelry, engagement ring, jewellery, diamond, silver, crystal, pre-engagement ring, metal
# Fetching images for Plain Band...
# Image saved: shink_design_wedding_band\Plain Band\Plain_Band_1.jpg
# Labels for Plain_Band_1.jpg: engagement ring, jewellery, ring, body jewelry, gemstone, diamond, wedding ring, pre-engagement ring, natural material, crystal
# Image saved: shink_design_wedding_band\Plain Band\Plain_Band_2.jpg
# Labels for Plain_Band_2.jpg: engagement ring, ring, finger, jewellery, body jewelry, gemstone, wedding ring, wedding ceremony supply, pre-engagement ring, diamond
# Image saved: shink_design_wedding_band\Plain Band\Plain_Band_3.jpg
# Labels for Plain_Band_3.jpg: heart, pre-engagement ring, engagement ring, ring, diamond, wedding ring, platinum
# Image saved: shink_design_wedding_band\Plain Band\Plain_Band_4.jpg
# Labels for Plain_Band_4.jpg: engagement ring, ring, finger, body jewelry, jewellery, gemstone, wedding ring, wedding ceremony supply, pre-engagement ring, diamond
# Image saved: shink_design_wedding_band\Plain Band\Plain_Band_5.jpg
# Labels for Plain_Band_5.jpg: engagement ring, pre-engagement ring, carbon fibers, ring, diamond, wedding ring, titanium, platinum
# Image saved: shink_design_wedding_band\Plain Band\Plain_Band_6.jpg
# Labels for Plain_Band_6.jpg: ring, engagement ring, jewellery, wedding ring, pre-engagement ring, body jewelry, natural material, wedding ceremony supply, silver, diamond
# Image saved: shink_design_wedding_band\Plain Band\Plain_Band_7.jpg
# Labels for Plain_Band_7.jpg: diamond, pre-engagement ring, engagement ring, ring, carbon fibers, titanium
# Image saved: shink_design_wedding_band\Plain Band\Plain_Band_8.jpg
# Labels for Plain_Band_8.jpg: ring, engagement ring, jewellery, wedding ring, body jewelry, fashion, gemstone, wedding ceremony supply, diamond, pre-engagement ring
# Image saved: shink_design_wedding_band\Plain Band\Plain_Band_9.jpg
# Labels for Plain_Band_9.jpg: engagement ring, ring, gemstone, wedding ring, pre-engagement ring, diamond, natural material, silver, body jewelry, wedding ceremony supply
# Image saved: shink_design_wedding_band\Plain Band\Plain_Band_10.jpg
# Labels for Plain_Band_10.jpg: engagement ring, gemstone, body jewelry, jewellery, diamond, ring, crystal, wedding ring, pre-engagement ring, mineral
# Fetching images for Flat Court...
# Image saved: shink_design_wedding_band\Flat Court\Flat_Court_1.jpg
# Labels for Flat_Court_1.jpg: ring, wedding ring, bangle, pre-engagement ring, wedding ceremony supply, engagement ring, titanium ring, metal, bracelet, silver
# Image saved: shink_design_wedding_band\Flat Court\Flat_Court_2.jpg
# Labels for Flat_Court_2.jpg: jewellery, engagement ring, ring, fashion, wedding ring, body jewelry, gemstone, wedding ceremony supply, pre-engagement ring, diamond
# Image saved: shink_design_wedding_band\Flat Court\Flat_Court_3.jpg
# Labels for Flat_Court_3.jpg: ring, white, engagement ring, fashion, wedding ceremony supply, wedding ring, pre-engagement ring, body jewelry, titanium ring, natural material
# Image saved: shink_design_wedding_band\Flat Court\Flat_Court_4.jpg
# Labels for Flat_Court_4.jpg: ring, jewellery, fashion, engagement ring, wedding ring, body jewelry, pre-engagement ring, wedding ceremony supply, metal, natural material
# Image saved: shink_design_wedding_band\Flat Court\Flat_Court_5.jpg
# Labels for Flat_Court_5.jpg: ring, wedding ring, bangle, pre-engagement ring, metal, wedding ceremony supply, engagement ring, natural material, titanium ring, silver
# Image saved: shink_design_wedding_band\Flat Court\Flat_Court_6.jpg
# Labels for Flat_Court_6.jpg: ring, pre-engagement ring, wedding ring, engagement ring, titanium ring, metal, natural material, silver, wedding ceremony supply, platinum
# Image saved: shink_design_wedding_band\Flat Court\Flat_Court_7.jpg
# Labels for Flat_Court_7.jpg: ring, white, engagement ring, fashion, wedding ceremony supply, wedding ring, pre-engagement ring, body jewelry, titanium ring, natural material
# Image saved: shink_design_wedding_band\Flat Court\Flat_Court_8.jpg
# Labels for Flat_Court_8.jpg: ring, engagement ring, wedding ring, body jewelry, jewellery, pre-engagement ring, diamond, bangle, wedding ceremony supply, metal
# Image saved: shink_design_wedding_band\Flat Court\Flat_Court_9.jpg
# Labels for Flat_Court_9.jpg: jewellery, fashion, ring, engagement ring, body jewelry, wedding ceremony supply, natural material, pre-engagement ring, wedding ring, silver
# Image saved: shink_design_wedding_band\Flat Court\Flat_Court_10.jpg
# Labels for Flat_Court_10.jpg: ring, wedding ring, wedding ceremony supply, pre-engagement ring, engagement ring, metal, gold, natural material, bangle, body jewelry
# Fetching images for Concave...
# Image saved: shink_design_wedding_band\Concave\Concave_1.jpg
# Labels for Concave_1.jpg: ring, wedding ceremony supply, jewellery, wedding ring, pre-engagement ring, metal, titanium ring, silver, engagement ring, natural material
# Image saved: shink_design_wedding_band\Concave\Concave_2.jpg
# Labels for Concave_2.jpg: ring, wedding ceremony supply, metal, silver, natural material, pre-engagement ring, titanium ring, wedding ring, titanium, nickel
# Image saved: shink_design_wedding_band\Concave\Concave_3.jpg
# Labels for Concave_3.jpg: ring, watch, wedding ring, pre-engagement ring, titanium ring, silver, metal, engagement ring, natural material, titanium
# Image saved: shink_design_wedding_band\Concave\Concave_4.jpg
# Labels for Concave_4.jpg: ring, wedding ring, engagement ring, pre-engagement ring, titanium ring, wedding ceremony supply, body jewelry, silver, titanium, platinum
# Image saved: shink_design_wedding_band\Concave\Concave_5.jpg
# Labels for Concave_5.jpg: titanium ring, pre-engagement ring, wedding ring, silver, ring, platinum, titanium
# Image saved: shink_design_wedding_band\Concave\Concave_6.jpg
# Labels for Concave_6.jpg: silver, metal, ring, pre-engagement ring, titanium ring, wedding ring, natural material, platinum, titanium, silver
# Image saved: shink_design_wedding_band\Concave\Concave_7.jpg
# Labels for Concave_7.jpg: ring, wedding ring, titanium ring, pre-engagement ring, jewellery, silver, engagement ring, metal, natural material, wedding ceremony supply
# Image saved: shink_design_wedding_band\Concave\Concave_8.jpg
# Labels for Concave_8.jpg: silver, ring, pre-engagement ring, wedding ring, titanium ring, natural material, platinum, wedding ceremony supply, titanium, silver
# Image saved: shink_design_wedding_band\Concave\Concave_9.jpg
# Labels for Concave_9.jpg: diamond, gemstone, natural material, engagement ring, gold, wedding ceremony supply, body jewelry, pre-engagement ring
# Image saved: shink_design_wedding_band\Concave\Concave_10.jpg
# Labels for Concave_10.jpg: natural material, silver, metal, watch, ring, titanium, silver, body jewelry, leather, platinum
# Fetching images for Half Round...
# Image saved: shink_design_wedding_band\Half Round\Half_Round_1.jpg
# Labels for Half_Round_1.jpg: ring, silver, metal, natural material, wedding ceremony supply, pre-engagement ring, titanium, wedding ring, platinum, titanium ring
# Image saved: shink_design_wedding_band\Half Round\Half_Round_2.jpg
# Labels for Half_Round_2.jpg: ring, jewellery, metal, body jewelry, wedding ring, natural material, pre-engagement ring, silver, gold, wedding ceremony supply
# Image saved: shink_design_wedding_band\Half Round\Half_Round_3.jpg
# Labels for Half_Round_3.jpg: ring, jewellery, pre-engagement ring, wedding ceremony supply, wedding ring, silver, engagement ring, body jewelry, natural material, metal
# Image saved: shink_design_wedding_band\Half Round\Half_Round_4.jpg
# Labels for Half_Round_4.jpg: engagement ring, ring, wedding ring, diamond, jewellery, gemstone, body jewelry, pre-engagement ring, wedding ceremony supply, mineral
# Image saved: shink_design_wedding_band\Half Round\Half_Round_5.jpg
# Labels for Half_Round_5.jpg: ring, engagement ring, wedding ring, pre-engagement ring, natural material, titanium ring, silver, body jewelry, wedding ceremony supply, platinum
# Image saved: shink_design_wedding_band\Half Round\Half_Round_6.jpg
# Labels for Half_Round_6.jpg: ring, metal, natural material, wedding ceremony supply, silver, gold, pre-engagement ring, body jewelry, brass, wedding ring
# Image saved: shink_design_wedding_band\Half Round\Half_Round_7.jpg
# Labels for Half_Round_7.jpg: jewellery, ring, natural material, silver, engagement ring, wedding ring, pre-engagement ring, body jewelry
# Image saved: shink_design_wedding_band\Half Round\Half_Round_8.jpg
# Labels for Half_Round_8.jpg: jewellery, ring, engagement ring, gemstone, body jewelry, nail care, natural material, pre-engagement ring, nail polish, wedding ring
# Image saved: shink_design_wedding_band\Half Round\Half_Round_9.jpg
# Labels for Half_Round_9.jpg: engagement ring, ring, wedding ring, diamond, jewellery, gemstone, body jewelry, pre-engagement ring, wedding ceremony supply, mineral
# Image saved: shink_design_wedding_band\Half Round\Half_Round_10.jpg
# Labels for Half_Round_10.jpg: silver, natural material, titanium, ring, nickel, silver
